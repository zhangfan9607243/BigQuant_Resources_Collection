# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Tool")
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Factor")
from cn_general_tool import *
from cn_general_factors_vpta import *

# %%
sd, ed = get_sd_ed('2024-11-25', '2024-11-25')

# %%
alpha_vpta_mavg(sd, ed, col="close", n=5, data_base="cc_binance_future_cm_bar1d") # cc_binance_future_cm_bar1m
# Out:
#          date      instrument  alpha_vpta_mavg_close_5
# 0  2024-11-25     EOSUSD_PERP                 0.766800
# 1  2024-11-25     ETCUSD_PERP                28.876000
# 2  2024-11-25    MANAUSD_PERP                 0.551020
# 3  2024-11-25     ENSUSD_PERP                20.732000
# 4  2024-11-25   XRPUSD_241227                 1.426600
# 5  2024-11-25     XLMUSD_PERP                 0.429098
# 6  2024-11-25     BTCUSD_PERP             97269.380000
# 7  2024-11-25   DOTUSD_241227                 7.676400
# 8  2024-11-25    DOGEUSD_PERP                 0.411230
# 9  2024-11-25     UNIUSD_PERP                10.407600
# 10 2024-11-25     WLDUSD_PERP                 2.390580
# 11 2024-11-25   BCHUSD_250328               498.968000
# 12 2024-11-25   LTCUSD_241227                95.404000
# 13 2024-11-25      OPUSD_PERP                 2.202820
# 14 2024-11-25   SOLUSD_250328               263.038000
# 15 2024-11-25   ADAUSD_241227                 0.990060
# 16 2024-11-25   BTCUSD_250328            102257.480000
# 17 2024-11-25     ETHUSD_PERP              3376.132000
# 18 2024-11-25  LINKUSD_241227                17.066800
# 19 2024-11-25     TRXUSD_PERP                 0.204364
# 20 2024-11-25    ALGOUSD_PERP                 0.262580
# 21 2024-11-25     DOTUSD_PERP                 7.640200
# 22 2024-11-25   LTCUSD_250328                99.002000
# 23 2024-11-25     SOLUSD_PERP               251.416000
# 24 2024-11-25     SUIUSD_PERP                 3.450060
# 25 2024-11-25     WIFUSD_PERP                 3.225840
# 26 2024-11-25   ETHUSD_241227              3428.316000
# 27 2024-11-25     AXSUSD_PERP                 6.977800
# 28 2024-11-25    DOGSUSD_PERP                 0.000673
# 29 2024-11-25   THETAUSD_PERP                 1.845600
# 30 2024-11-25     ADAUSD_PERP                 0.975660
# 31 2024-11-25   BNBUSD_250328               662.170000
# 32 2024-11-25     APTUSD_PERP                12.349400
# 33 2024-11-25     XRPUSD_PERP                 1.409520
# 34 2024-11-25     BNBUSD_PERP               641.346000
# 35 2024-11-25   BTCUSD_241227             98677.140000
# 36 2024-11-25     GMTUSD_PERP                 0.195560
# 37 2024-11-25     LTCUSD_PERP                94.222000
# 38 2024-11-25    NEARUSD_PERP                 6.300800
# 39 2024-11-25    RUNEUSD_PERP                 5.525200
# 40 2024-11-25    SANDUSD_PERP                 0.528040
# 41 2024-11-25   XRPUSD_250328                 1.460820
# 42 2024-11-25   BCHUSD_241227               498.544000
# 43 2024-11-25     BCHUSD_PERP               499.176000
# 44 2024-11-25   DOTUSD_250328                 7.753600
# 45 2024-11-25    EGLDUSD_PERP                35.226200
# 46 2024-11-25     FILUSD_PERP                 5.210800
# 47 2024-11-25   SOLUSD_241227               255.524000
# 48 2024-11-25    AVAXUSD_PERP                40.836000
# 49 2024-11-25     FTMUSD_PERP                 0.866420
# 50 2024-11-25    LINKUSD_PERP                16.848000
# 51 2024-11-25    AAVEUSD_PERP               174.248000
# 52 2024-11-25   ADAUSD_250328                 1.025060
# 53 2024-11-25    ATOMUSD_PERP                 7.780600
# 54 2024-11-25   BNBUSD_241227               649.884000
# 55 2024-11-25     CHZUSD_PERP                 0.085940
# 56 2024-11-25   ETHUSD_250328              3541.746000
# 57 2024-11-25  LINKUSD_250328                17.674400
