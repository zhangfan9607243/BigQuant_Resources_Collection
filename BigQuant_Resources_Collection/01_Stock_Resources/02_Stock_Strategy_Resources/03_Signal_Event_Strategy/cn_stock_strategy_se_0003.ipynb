# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Tool")
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Strategy")
from cn_general_tool import *
from cn_stock_strategy_signal_event import *

# %%
sd, ed = get_sd_ed('2020-01-01', '2024-11-25')

# %%
df = cn_stock_strategy_signal_event_pair_df(ins1="601328.SH", ins2="601998.SH", sd=sd, ed=ed)
df
# Out:
#            date instrument  signal_buy  signal_sell
# 12   2020-03-10  601328.SH           1            0
# 13   2020-03-10  601998.SH           0            1
# 20   2020-03-17  601328.SH           1            0
# 21   2020-03-17  601998.SH           0            1
# 50   2020-03-30  601328.SH           1            0
# ...         ...        ...         ...          ...
# 2303 2024-09-30  601328.SH           0            1
# 2326 2022-07-12  601998.SH           1            0
# 2327 2022-07-12  601328.SH           0            1
# 2364 2023-11-10  601998.SH           0            1
# 2365 2023-11-10  601328.SH           1            0
#
# [124 rows x 4 columns]

# %%
cn_stock_strategy_signal_event_backtest(df, capital_base=1000000, holding_days=1)
# Out:
# [2024-11-30 20:07:14] [info     ] bigtrader.v34 开始运行 ..
# [2024-11-30 20:07:14] [info     ] 2020-03-10, 2024-09-30, , , instruments=2
# [2024-11-30 20:07:14] [info     ] bigtrader module V2.2.0
# [2024-11-30 20:07:14] [info     ] bigtrader engine v1.10.10 2024-11-26
# INFO:MAIN:======== bigtrader pid:2215 version 1.10.10 2024-11-26 ========
# INFO:MAIN:bigtrader run_mode:BACKTEST, handle_bar_mode:0, frequency:1d, exchange_mode:BQ2
# INFO:MAIN:> process add account:BACKTEST,0,bkt000
# INFO:ACCT[bkt000]:AccountEngine: self_calc:1, validate_self_trading:0, validate_cash:0, validate_position:1, enable_auto_planed_order:1
# INFO:MAIN:login_account(bkt000)
# INFO:MAIN:> add_strategy setting:{'strategy_name': 'strategy', 'account_id': 'bkt000'}
# INFO:MAIN:init all strategy account_id:...
# INFO:MAIN:stop all strategy account_id:...
# [2024-11-30 20:07:19] [info     ] backtest done, raw_perf_ds:dai.DataSource("_0b7d89cd8ffb4f3e86da33ef3f785948")
# <style>#bigchart7df8ed64be1045a1820e58b016dd6dfa .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigchart7df8ed64be1045a1820e58b016dd6dfa  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigchart7df8ed64be1045a1820e58b016dd6dfa .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigchart7df8ed64be1045a1820e58b016dd6dfa .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigchart7df8ed64be1045a1820e58b016dd6dfa><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigchart2f24fccdd481476d8b7d6f1e6e44995a')>收益概况</button><button class=tablinks onclick=showChart('bigchart1de7e683625e4a4cb6799abc53b1c083')>交易详情</button><button class=tablinks onclick=showChart('bigchart2aed9a299e284fe8b98f8e41f387cdce')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchart5e47798f19a64ef7b5b896400b907a6d')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigchart2f24fccdd481476d8b7d6f1e6e44995a><style>#bigchart57c1812b092342f9898f0e490d1a3819 .value {color: #E74C3C}
# #bigchart57c1812b092342f9898f0e490d1a3819 .positive-True {color: #E74C3C}
# #bigchart57c1812b092342f9898f0e490d1a3819 .positive-False {color: #24BB85}
# #bigchart57c1812b092342f9898f0e490d1a3819 .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchart57c1812b092342f9898f0e490d1a3819 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchart57c1812b092342f9898f0e490d1a3819 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchart57c1812b092342f9898f0e490d1a3819 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchart57c1812b092342f9898f0e490d1a3819 .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchart57c1812b092342f9898f0e490d1a3819 .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchart57c1812b092342f9898f0e490d1a3819 ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchart57c1812b092342f9898f0e490d1a3819 ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchart57c1812b092342f9898f0e490d1a3819><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-True">105.2%</span></li><li><span class=name>年化收益率</span><span class="value positive-True">17.76%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-False">-1.59%</span></li><li><span class=name>阿尔法</span><span class="value positive-True">0.16</span></li><li><span class=name>贝塔</span><span class=value>0.25</span></li><li><span class=name>夏普比率</span><span class="value positive-True">0.94</span></li><li><span class=name>胜率</span><span class=value>0.57</span></li><li><span class=name>盈亏比</span><span class=value>4.48</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">15.42</span></li><li><span class=name>最大回撤</span><span class="value positive-True">17.22</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=7d0be367d9d64ef4a8463d6326e7e9f6></div><script>require([`echarts`,`walden`],(a=>{let e1=73.01,ej=12.09,bt=5,qM=13.91,dn=53.47,EH=`2020-08-20`,GC=`2021-02-25`,vU=8.95,Io=`2021-08-11`,ea=84.13,Lh=`2022-05-23`,KI=`2022-03-24`,e0=74.48,EP=`2020-09-01`,QR=`2023-11-07`,lx=0.22,t2=16.1,qR=18.11,R5=`2023-11-29`,TR=`2024-08-20`,q1=13.74,BR=80.95,l8=1.61,EB=`2020-08-12`,KW=`2022-04-15`,T7=`2024-06-17`,s6=12.14,pn=19.28,Bf=62.42,DG=`2020-05-19`,gE=21.84,JK=`2021-12-20`,tb=25.76,Gu=`2021-02-08`,Nz=`2022-12-22`,zU=50.69,fd=14.39,DB=`2020-05-12`,OF=`2023-04-10`,Tu=`2024-07-18`,tR=20.36,E0=`2020-06-18`,iB=28.15,gF=20.28,M1=`2022-07-29`,SA=`2024-04-23`,Ni=`2022-11-29`,KV=`2022-04-14`,oP=11.03,hI=23.34,j3=18.8,tM=19.78,yN=34.96,qC=15.6,C9=92.05,E4=`2020-06-24`,Tb=`2024-06-21`,m0=0.46,tO=19.87,z3=34.2,jQ=21.56,g8=11.94,j6=20.86,jb=22.84,fl=10.62,hT=23.65,uD=21.54,DP=`2020-06-01`,G=3.96,xI=2.79,ur=20.26,hS=24.79,Np=`2022-12-08`,o8=5.56,Aj=66.65,xM=26.71,rq=4.53,Co=98.9,d3=35.3,Gr=`2021-02-03`,qj=12.32,Tf=`2024-06-27`,oc=8.65,BW=85.84,FW=`2020-12-17`,IL=`2021-09-13`,gg=17.36,xJ=2.97,QL=`2023-10-30`,J0=`2021-10-15`,L4=`2022-04-29`,b1=0.73,nW=5.93,q6=11.08,yp=30.76,H7=`2021-04-14`,GV=`2021-03-24`,FE=`2020-11-23`,NB=`2022-12-26`,nO=5.41,Pi=`2023-06-09`,Q7=`2023-08-25`,wW=6.71,PL=`2023-07-24`,cH=35.08,l7=4.13,Uy=800,lq=1.88,vP=8.21,xR=28.14,OH=`2023-04-12`,p9=18.15,dc=40.9,An=72.58,Oz=`2023-03-30`,UD=`horizontal`,kl=20.37,dE=55.43,lI=7.64,oG=13.45,nT=5.36,PA=`2023-07-07`,SI=`2024-05-08`,rt=3.82,Bi=62.1,MK=`2022-10-10`,Oh=`2023-03-06`,QC=`2023-1
# [2024-11-30 20:07:20] [info     ] bigtrader.v34 运行完成 [6.594s].
#                  date  trading_days  portfolio_value  starting_value  \
# 2020-03-10 2020-03-10             0     1.000002e+06             0.0
# 2020-03-11 2020-03-11             1     9.997019e+05             0.0
# 2020-03-12 2020-03-12             2     9.997019e+05        998976.0
# 2020-03-13 2020-03-13             3     9.940259e+05        998976.0
# 2020-03-16 2020-03-16             4     9.826739e+05        993300.0
# ...               ...           ...              ...             ...
# 2024-09-24 2024-09-24          1104     1.841317e+06       1758526.0
# 2024-09-25 2024-09-25          1105     1.873503e+06       1840454.0
# 2024-09-26 2024-09-26          1106     1.964209e+06       1872640.0
# 2024-09-27 2024-09-27          1107     1.946653e+06       1963346.0
# 2024-09-30 2024-09-30          1108     2.051989e+06       1945790.0
#
#             ending_value  starting_cash   ending_cash   returns  \
# 2020-03-10           0.0   1.000002e+06  1.000002e+06  0.000000
# 2020-03-11      998976.0   1.000002e+06  7.258551e+02 -0.000300
# 2020-03-12      998976.0   7.258551e+02  7.258551e+02  0.000000
# 2020-03-13      993300.0   7.258551e+02  7.258551e+02 -0.005678
# 2020-03-16      981948.0   7.258551e+02  7.258551e+02 -0.011420
# ...                  ...            ...           ...       ...
# 2024-09-24     1840454.0   8.626951e+02  8.626951e+02  0.046566
# 2024-09-25     1872640.0   8.626951e+02  8.626951e+02  0.017480
# 2024-09-26     1963346.0   8.626951e+02  8.626951e+02  0.048415
# 2024-09-27     1945790.0   8.626951e+02  8.626951e+02 -0.008938
# 2024-09-30     2051126.0   8.626951e+02  8.626951e+02  0.054111
#
#             algorithm_period_return  benchmark_period_return  ...  \
# 2020-03-10                 0.000000                 0.000000  ...
# 2020-03-11                -0.000300                -0.013301  ...
# 2020-03-12                -0.000300                -0.032287  ...
# 2020-03-13                -0.005976                -0.045905  ...
# 2020-03-16                -0.017328                -0.086925  ...
# ...                             ...                      ...  ...
# 2024-09-24                 0.841314                -0.179003  ...
# 2024-09-25                 0.873500                -0.166849  ...
# 2024-09-26                 0.964206                -0.131630  ...
# 2024-09-27                 0.946650                -0.092841  ...
# 2024-09-30                 1.051986                -0.015891  ...
#
#             today_sell_balance  commission  capital_changed  \
# 2020-03-10                 0.0        0.00              0.0
# 2020-03-11                 0.0      299.69              0.0
# 2020-03-12                 0.0        0.00              0.0
# 2020-03-13                 0.0        0.00              0.0
# 2020-03-16                 0.0        0.00              0.0
# ...                        ...         ...              ...
# 2024-09-24                 0.0        0.00              0.0
# 2024-09-25                 0.0        0.00              0.0
# 2024-09-26                 0.0        0.00              0.0
# 2024-09-27                 0.0        0.00              0.0
# 2024-09-30                 0.0        0.00              0.0
#
#                                                        orders  \
# 2020-03-10  [{'id': '', 'order_time': '15:00:00', 'dt': 20...
# 2020-03-11  [{'symbol': '601328.SH', 'id': '202003100001',...
# 2020-03-12                                                 []
# 2020-03-13                                                 []
# 2020-03-16                                                 []
# ...                                                       ...
# 2024-09-24                                                 []
# 2024-09-25                                                 []
# 2024-09-26                                                 []
# 2024-09-27                                                 []
# 2024-09-30  [{'id': '', 'order_time': '15:00:00', 'dt': 20...
#
#                                                  transactions  \
# 2020-03-10                                                 []
# 2020-03-11  [{'symbol': '601328.SH', 'dt': 2020-03-11 15:0...
# 2020-03-12                                                 []
# 2020-03-13                                                 []
# 2020-03-16                                                 []
# ...                                                       ...
# 2024-09-24                                                 []
# 2024-09-25                                                 []
# 2024-09-26                                                 []
# 2024-09-27                                                 []
# 2024-09-30                                                 []
#
#                                                     positions  POS_FAC  \
# 2020-03-10                                                 []       {}
# 2020-03-11  [{'symbol': '601328.SH', 'direction': '1', 'cu...       {}
# 2020-03-12  [{'symbol': '601328.SH', 'direction': '1', 'cu...       {}
# 2020-03-13  [{'symbol': '601328.SH', 'direction': '1', 'cu...       {}
# 2020-03-16  [{'symbol': '601328.SH', 'direction': '1', 'cu...       {}
# ...                                                       ...      ...
# 2024-09-24  [{'symbol': '601998.SH', 'direction': '1', 'cu...       {}
# 2024-09-25  [{'symbol': '601998.SH', 'direction': '1', 'cu...       {}
# 2024-09-26  [{'symbol': '601998.SH', 'direction': '1', 'cu...       {}
# 2024-09-27  [{'symbol': '601998.SH', 'direction': '1', 'cu...       {}
# 2024-09-30  [{'symbol': '601998.SH', 'direction': '1', 'cu...       {}
#
#                 TRA_FAC                                                LOG  \
# 2020-03-10  {'LOG': []}  [{'level': 'INFO', 'msg': 'order[15:00:00][id:...
# 2020-03-11  {'LOG': []}  [{'level': 'INFO', 'msg': 'order[15:00:00][id:...
# 2020-03-12  {'LOG': []}                                                 []
# 2020-03-13  {'LOG': []}                                                 []
# 2020-03-16  {'LOG': []}                                                 []
# ...                 ...                                                ...
# 2024-09-24  {'LOG': []}                                                 []
# 2024-09-25  {'LOG': []}                                                 []
# 2024-09-26  {'LOG': []}                                                 []
# 2024-09-27  {'LOG': []}                                                 []
# 2024-09-30  {'LOG': []}  [{'level': 'INFO', 'msg': 'order[15:00:00][id:...
#
#             benchmark_returns
# 2020-03-10           0.000000
# 2020-03-11          -0.013301
# 2020-03-12          -0.019243
# 2020-03-13          -0.014072
# 2020-03-16          -0.042993
# ...                       ...
# 2024-09-24           0.043310
# 2024-09-25           0.014805
# 2024-09-26           0.042271
# 2024-09-27           0.044669
# 2024-09-30           0.084826
#
# [1109 rows x 39 columns]
