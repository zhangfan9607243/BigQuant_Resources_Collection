# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Tool")
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Strategy")
from cn_general_tool import *
from cn_stock_strategy_signal_event import *

# %%
sd, ed = get_sd_ed('2020-01-01', '2024-11-25')

# %%
instrument_list = ['000001.SZ', '000002.SZ', '600519.SH']

# %%
strategy_sql =  f"""
SELECT
    date,
    instrument,
    m_ta_macd_dea(close)  AS macd,
    m_ta_macd_dif(close)  AS sig,
    IF(macd < sig AND m_lag(macd,1) > m_lag(sig, 1), 1, 0) AS signal_buy,
    IF(macd > sig AND m_lag(macd,1) < m_lag(sig, 1), 1, 0) AS signal_sell,
FROM cn_stock_prefactors
"""

# %%
df = cn_stock_strategy_signal_event_df(strategy_sql, sd, ed, instrument_list)
df
# Out:
#           date instrument  signal_buy  signal_sell
# 0   2020-01-03  600519.SH           0            1
# 1   2020-01-08  000002.SZ           0            1
# 2   2020-01-14  000001.SZ           0            1
# 3   2020-01-16  600519.SH           1            0
# 4   2020-01-20  600519.SH           0            1
# ..         ...        ...         ...          ...
# 272 2024-10-17  600519.SH           0            1
# 273 2024-10-22  000002.SZ           0            1
# 274 2024-10-23  000001.SZ           0            1
# 275 2024-11-07  600519.SH           1            0
# 276 2024-11-13  600519.SH           0            1
#
# [277 rows x 4 columns]

# %%
cn_stock_strategy_signal_event_backtest(df, capital_base=1000000, holding_days=3)
# Out:
# [2024-11-30 01:08:31] [info     ] bigtrader.v34 开始运行 ..
# [2024-11-30 01:08:31] [info     ] 2020-01-03, 2024-11-13, , , instruments=3
# [2024-11-30 01:08:32] [info     ] bigtrader module V2.2.0
# [2024-11-30 01:08:32] [info     ] bigtrader engine v1.10.10 2024-11-26
# [2024-11-30 01:08:39] [info     ] backtest done, raw_perf_ds:dai.DataSource("_1cfd6ffa11e841de945bc4abf4a166bb")
# <style>#bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigchart40bbb3cfc8eb4e9aabe167fba6b46f94 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigchart40bbb3cfc8eb4e9aabe167fba6b46f94><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigcharta2a16b7e5d604469b4d331d1957df53b')>收益概况</button><button class=tablinks onclick=showChart('bigchart7b22eb714fbd484e8e43a43d46e970d9')>交易详情</button><button class=tablinks onclick=showChart('bigchart0eccf1b5ea70485f821855a717784341')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchartc183d6a0786d4306ad375e9a05810c76')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigcharta2a16b7e5d604469b4d331d1957df53b><style>#bigchart3b802c26c0a5415e9e975700d765b9d5 .value {color: #E74C3C}
# #bigchart3b802c26c0a5415e9e975700d765b9d5 .positive-True {color: #E74C3C}
# #bigchart3b802c26c0a5415e9e975700d765b9d5 .positive-False {color: #24BB85}
# #bigchart3b802c26c0a5415e9e975700d765b9d5 .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchart3b802c26c0a5415e9e975700d765b9d5 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchart3b802c26c0a5415e9e975700d765b9d5 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchart3b802c26c0a5415e9e975700d765b9d5 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchart3b802c26c0a5415e9e975700d765b9d5 .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchart3b802c26c0a5415e9e975700d765b9d5 .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchart3b802c26c0a5415e9e975700d765b9d5 ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchart3b802c26c0a5415e9e975700d765b9d5 ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchart3b802c26c0a5415e9e975700d765b9d5><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-False">-11.61%</span></li><li><span class=name>年化收益率</span><span class="value positive-False">-2.61%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-False">-0.82%</span></li><li><span class=name>阿尔法</span><span class="value positive-False">-0.03</span></li><li><span class=name>贝塔</span><span class=value>0.31</span></li><li><span class=name>夏普比率</span><span class="value positive-False">-0.2</span></li><li><span class=name>胜率</span><span class=value>0.38</span></li><li><span class=name>盈亏比</span><span class=value>1.01</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">19.01</span></li><li><span class=name>最大回撤</span><span class="value positive-True">43.79</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=6013ba19551b41f598eaa2de4e67966a></div><script>require([`echarts`,`walden`],(a=>{let ED=`2020-08-20`,Gy=`2021-02-25`,qf=5,Ik=`2021-08-11`,Ld=`2022-05-23`,Qa=`2023-09-05`,QN=`2023-11-07`,R1=`2023-11-29`,Rq=`2024-01-04`,sV=19.6,KE=`2022-03-24`,TN=`2024-08-20`,EL=`2020-09-01`,wF=0.22,ro=18.11,ez=13.74,KS=`2022-04-15`,a3=6.38,fb=4.4,lZ=23.09,cJ=32.79,iR=2.48,ss=12.14,rQ=23.29,sT=19.28,DC=`2020-05-19`,cS=33.67,Ex=`2020-08-12`,JG=`2021-12-20`,pH=3.26,T3=`2024-06-17`,Gq=`2021-02-08`,Nv=`2022-12-22`,OB=`2023-04-10`,zo=14.39,Dx=`2020-05-12`,Tq=`2024-07-18`,pS=2.02,Ur=`2024-10-28`,rI=20.36,Ar=101.58,DY=`2020-06-18`,gc=15.02,c0=30.81,qB=7.79,mr=20.28,LZ=`2022-07-29`,hd=15.94,Ne=`2022-11-29`,tg=7.56,KR=`2022-04-14`,lj=23.34,kk=19.78,Sw=`2024-04-23`,jI=15.6,oz=8.34,E0=`2020-06-24`,AI=86.17,T7=`2024-06-21`,iQ=0.46,sg=15.29,t1=19.87,ck=21.56,nH=11.94,zt=15.91,lc=21.54,d7=23.65,dd=25.74,tH=4.18,DL=`2020-06-01`,fe=3.96,wR=2.79,s_=20.26,zQ=99.81,kL=32.33,Nl=`2022-12-08`,vL=5.56,mu=19.99,y8=4.53,Gn=`2021-02-03`,bk=12.32,Tb=`2024-06-27`,FS=`2020-12-17`,lf=23.3,IH=`2021-09-13`,fA=2.97,l4=24.16,QH=`2023-10-30`,ny=15.01,cb=26.07,AQ=86.37,eZ=5.93,la=18.91,aY=1.89,pn=11.08,nd=18.04,zi=2.95,GR=`2021-03-24`,FA=`2020-11-23`,H3=`2021-04-14`,IY=`2021-10-15`,d9=27.84,L0=`2022-04-29`,f_=6.71,Nx=`2022-12-26`,Pe=`2023-06-09`,PH=`2023-07-24`,k7=22.25,Q3=`2023-08-25`,qs=5.16,fG=4.13,yz=1.56,x_=3.95,oT=1.88,OD=`2023-04-12`,UV=800,Ov=`2023-03-30`,ci=21.09,js=15.08,w9=1.85,BN=101.62,U_=`horizontal`,pC=7.64,Pw=`2023-07-07`,hl=0.44,iu=5.36,SE=`2024-05-08`
# [2024-11-30 01:08:43] [info     ] bigtrader.v34 运行完成 [12.113s].
#                  date  trading_days  portfolio_value  starting_value  \
# 2020-01-03 2020-01-03             0     1.000008e+06             0.0
# 2020-01-06 2020-01-06             1     1.000008e+06             0.0
# 2020-01-07 2020-01-07             2     1.000008e+06             0.0
# 2020-01-08 2020-01-08             3     1.000008e+06             0.0
# 2020-01-09 2020-01-09             4     1.000008e+06             0.0
# ...               ...           ...              ...             ...
# 2024-11-07 2024-11-07          1172     8.998572e+05             0.0
# 2024-11-08 2024-11-08          1173     8.996157e+05             0.0
# 2024-11-11 2024-11-11          1174     8.936357e+05        804985.0
# 2024-11-12 2024-11-12          1175     8.832307e+05        799005.0
# 2024-11-13 2024-11-13          1176     8.838807e+05        788600.0
#
#             ending_value  starting_cash   ending_cash   returns  \
# 2020-01-03           0.0   1.000008e+06  1.000008e+06  0.000000
# 2020-01-06           0.0   1.000008e+06  1.000008e+06  0.000000
# 2020-01-07           0.0   1.000008e+06  1.000008e+06  0.000000
# 2020-01-08           0.0   1.000008e+06  1.000008e+06  0.000000
# 2020-01-09           0.0   1.000008e+06  1.000008e+06  0.000000
# ...                  ...            ...           ...       ...
# 2024-11-07           0.0   8.998572e+05  8.998572e+05  0.000000
# 2024-11-08      804985.0   8.998572e+05  9.463074e+04 -0.000268
# 2024-11-11      799005.0   9.463074e+04  9.463074e+04 -0.006647
# 2024-11-12      788600.0   9.463074e+04  9.463074e+04 -0.011643
# 2024-11-13      789250.0   9.463074e+04  9.463074e+04  0.000736
#
#             algorithm_period_return  benchmark_period_return  ...  \
# 2020-01-03                 0.000000                 0.000000  ...
# 2020-01-06                 0.000000                -0.003780  ...
# 2020-01-07                 0.000000                 0.003682  ...
# 2020-01-08                 0.000000                -0.007876  ...
# 2020-01-09                 0.000000                 0.004682  ...
# ...                             ...                      ...  ...
# 2024-11-07                -0.100150                 0.000176  ...
# 2024-11-08                -0.100391                -0.009872  ...
# 2024-11-11                -0.106371                -0.003337  ...
# 2024-11-12                -0.116776                -0.014288  ...
# 2024-11-13                -0.116126                -0.008221  ...
#
#             today_sell_balance  commission  capital_changed  \
# 2020-01-03                 0.0         0.0              0.0
# 2020-01-06                 0.0         0.0              0.0
# 2020-01-07                 0.0         0.0              0.0
# 2020-01-08                 0.0         0.0              0.0
# 2020-01-09                 0.0         0.0              0.0
# ...                        ...         ...              ...
# 2024-11-07                 0.0         0.0              0.0
# 2024-11-08                 0.0       241.5              0.0
# 2024-11-11                 0.0         0.0              0.0
# 2024-11-12                 0.0         0.0              0.0
# 2024-11-13                 0.0         0.0              0.0
#
#                                                        orders  \
# 2020-01-03                                                 []
# 2020-01-06                                                 []
# 2020-01-07                                                 []
# 2020-01-08                                                 []
# 2020-01-09                                                 []
# ...                                                       ...
# 2024-11-07  [{'id': '', 'order_time': '15:00:00', 'dt': 20...
# 2024-11-08  [{'symbol': '600519.SH', 'id': '202411070001',...
# 2024-11-11                                                 []
# 2024-11-12                                                 []
# 2024-11-13  [{'id': '', 'order_time': '15:00:00', 'dt': 20...
#
#                                                  transactions  \
# 2020-01-03                                                 []
# 2020-01-06                                                 []
# 2020-01-07                                                 []
# 2020-01-08                                                 []
# 2020-01-09                                                 []
# ...                                                       ...
# 2024-11-07                                                 []
# 2024-11-08  [{'symbol': '600519.SH', 'dt': 2024-11-08 15:0...
# 2024-11-11                                                 []
# 2024-11-12                                                 []
# 2024-11-13                                                 []
#
#                                                     positions  POS_FAC  \
# 2020-01-03                                                 []       {}
# 2020-01-06                                                 []       {}
# 2020-01-07                                                 []       {}
# 2020-01-08                                                 []       {}
# 2020-01-09                                                 []       {}
# ...                                                       ...      ...
# 2024-11-07                                                 []       {}
# 2024-11-08  [{'symbol': '600519.SH', 'direction': '1', 'cu...       {}
# 2024-11-11  [{'symbol': '600519.SH', 'direction': '1', 'cu...       {}
# 2024-11-12  [{'symbol': '600519.SH', 'direction': '1', 'cu...       {}
# 2024-11-13  [{'symbol': '600519.SH', 'direction': '1', 'cu...       {}
#
#                 TRA_FAC                                                LOG  \
# 2020-01-03  {'LOG': []}                                                 []
# 2020-01-06  {'LOG': []}                                                 []
# 2020-01-07  {'LOG': []}                                                 []
# 2020-01-08  {'LOG': []}                                                 []
# 2020-01-09  {'LOG': []}                                                 []
# ...                 ...                                                ...
# 2024-11-07  {'LOG': []}  [{'level': 'INFO', 'msg': 'order[15:00:00][id:...
# 2024-11-08  {'LOG': []}  [{'level': 'INFO', 'msg': 'order[15:00:00][id:...
# 2024-11-11  {'LOG': []}                                                 []
# 2024-11-12  {'LOG': []}                                                 []
# 2024-11-13  {'LOG': []}  [{'level': 'INFO', 'msg': 'order[15:00:00][id:...
#
#             benchmark_returns
# 2020-01-03           0.000000
# 2020-01-06          -0.003780
# 2020-01-07           0.007491
# 2020-01-08          -0.011516
# 2020-01-09           0.012658
# ...                       ...
# 2024-11-07           0.030170
# 2024-11-08          -0.010046
# 2024-11-11           0.006599
# 2024-11-12          -0.010987
# 2024-11-13           0.006155
#
# [1177 rows x 39 columns]
