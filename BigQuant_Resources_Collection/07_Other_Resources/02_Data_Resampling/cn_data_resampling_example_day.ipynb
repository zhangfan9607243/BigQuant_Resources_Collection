# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Tool")
from cn_general_tool import *

from bigcharts import Kline

# %%
sd, ed, = get_sd_ed('2020-01-01', '2024-11-28')

# %%
def get_data_d(sql, sd, ed, freq, instruments=[]):

    date_obj = datetime.strptime(sd, '%Y-%m-%d %H:%M:%S.%f')
    
    if freq == "week":
        start_of_week = date_obj - timedelta(days=date_obj.weekday())
        sd = start_of_week.strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "fortnight":
        days_since_year_start = (date_obj - datetime(date_obj.year, 1, 1)).days
        fortnight_start = days_since_year_start - (days_since_year_start % 14)
        sd = (datetime(date_obj.year, 1, 1) + timedelta(days=fortnight_start)).strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "month":
        start_of_month = datetime(year=date_obj.year, month=date_obj.month, day=1)
        sd = start_of_month.strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "bimonthly":
        bimonthly_start_month = (date_obj.month - 1) // 2 * 2 + 1
        start_of_bimonthly = datetime(year=date_obj.year, month=bimonthly_start_month, day=1)
        sd = start_of_bimonthly.strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "quarter":
        quarter_start_month = 3 * ((date_obj.month - 1) // 3) + 1
        start_of_quarter = datetime(year=date_obj.year, month=quarter_start_month, day=1)
        sd = start_of_quarter.strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "quadmonthly":
        quadmonthly_start_month = 4 * ((date_obj.month - 1) // 4) + 1
        start_of_quadmonthly = datetime(year=date_obj.year, month=quadmonthly_start_month, day=1)
        sd = start_of_quadmonthly.strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "semiannual":
        semiannual_start_month = 1 if date_obj.month <= 6 else 7
        start_of_semiannual = datetime(year=date_obj.year, month=semiannual_start_month, day=1)
        sd = start_of_semiannual.strftime('%Y-%m-%d 00:00:00.000')
    
    elif freq == "year":
        sd = datetime(year=date_obj.year, month=1, day=1).strftime('%Y-%m-%d 00:00:00.000')

    else:
        sd = sd

    sql_all = f"""
    WITH
    data_all AS (
        {sql}
    )
    SELECT *
    FROM data_all
    """

    if instruments == []:
        return dai.query(sql_all, filters={'date':[sd, ed]}).df()
    else:
        return dai.query(sql_all, filters={'date':[sd, ed], 'instrument':instruments}).df()

# %% [markdown]
# ### Day

# %%
sql_day = """
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    volume,
    amount,
    turn,
    deal_number,
FROM cn_stock_bar1d
ORDER BY date
"""

df_day = get_data_d(sql_day, sd, ed, freq="day", instruments=['600519.SH'])
df_day
# Out:
#            date instrument          open         close          high  \
# 0    2020-01-02  600519.SH   8255.352493   8269.989643   8380.207381
# 1    2020-01-03  600519.SH   8174.848169   7893.522150   8174.848169
# 2    2020-01-06  600519.SH   7837.169123   7889.350562   7998.470514
# 3    2020-01-07  600519.SH   7885.764461   8010.399791   8043.113821
# 4    2020-01-08  600519.SH   7941.019701   7963.634098   8017.498809
11523.843939670738,iE=14,ig=11276.812763903854,bN=15378.188807964325,a5=12438.785362243652,fh=13235.564322471619,cM=12219.582996368408,dG=15246.452178955078,fw=13732.854311466217,a4=12498.017673492432,bJ=14808.077812194824,f8=13137.089104652405,R=9792.25322341919,ds=13228.539390563965,eX=11029.413509368896,iD=10,dL=14558.867080688477,Z=9749.073631477355,cH=12331.689262390137,hf=12894.501920700073,i8=11469.30458917675,bL=14586.030685400963,hA=13318.819667464757,h3=13236.777843475342,bP=14548.936450481415,cJ=13303.351638755797,bM=15000.582823753357,dX=13206.11813735962,hR=11870.329225161951,cp=14715.815853118896,hx=13350.2490940094,cg=15052.134651184082,dI=16060.194195251466,fk=14038.878920078278,eB=14474.216632843018,ek=15146.557593345642,dY=13430.330669403076,ei=14036.37714351654,de=13639.595699310303,bI=15104.23936843872,cF=13041.695613861084,$=10216.730567932129,cI=12705.376815795898,g=0,f=`cubicOut`,bl=15459.633235931396,hW=11389.099661979712,eo=14338.237562179565,c1=16436.966371536255,cQ=12443.720790901185,hV=11573.570994532904,fS=13701.333776779176,hg=12870.928791046143,gK=13958.741536417008,ix=12392.703915996275,aN=12668.310568332672,iK=`solid`,aE=12816.39134645462,h$=11669.816907169352,gS=12894.983110427856,fz=13985.324613571167,n=8123.618144989014,I=7633.273626327515,eV=12449.639358520508,db=13781.596969604492,hd=13303.102834701538,D=8606.644088745117,dV=13706.85945892334,cG=12339.163013458252,hE=13161.665453099393,bx=16222.24924325943,gg=13640.717073440552,et=14277.802419662476,gO=13863.272053027154,ac=12808.320944046975,ir=12287.394846586561,eA=14579.978132247925,eL=13786.76688671112,e_=10862.914691734315,fV=13182.010015964508,gb=13275.540473427773,b4=12591.45664448738,dQ=14521.4983253479,a0=10428.969240188599,dg=13191.170635223389,U=9733.704624176025,iB=12102.92351403337,ej=14723.289604187012,h7=13122.375507354736,hj=12800.20940208435,gv=14029.12017917633,c_=13901.176986694336,h=`Kline`,dE=15216.557174682617,ht=13318.818254470825,iH=`auto`,bD=16770.14812231064,dZ=13243.486892700195,d5=14282.338291168213,bt=15858.636892580986,ck=14685.92084884643 ...

# %% [markdown]
# ### Week

# %%
sql_week = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CONCAT(CAST(year(date) AS CHAR), CAST(week(date) AS CHAR)) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_week = get_data_d(sql_week, sd, ed, freq="week", instruments=['600519.SH'])
df_week
# Out:
#           date instrument          open         close          high  \
# 0   2019-12-30  600519.SH   8564.196354   8657.874113   8749.356299
# 1   2020-01-02  600519.SH   8255.352493   7893.522150   8380.207381
# 2   2020-01-06  600519.SH   7837.169123   8141.914582   8167.456409
# 3   2020-01-13  600519.SH   8141.914582   8105.321708   8264.134783
# 4   2020-01-20  600519.SH   8137.230694   7704.995660   8137.230694
# ..         ...        ...           ...           ...           ...
# 247 2024-10-28  600519.SH  12511.968643  12301.430709  12672.378497
# 248 2024-11-04  600519.SH  12391.099817  12912.752664  13371.043618
# 249 2024-11-11  600519.SH  12752.583424  12503.948150  13017.259684
# 250 2024-11-18  600519.SH  12528.009628  12093.459333  12640.216321
# 251 2024-11-25  600519.SH  12118.964499  12175.107949  12287.394847
#
#               low        amount    volume      turn deal_number
# 0     8564.196354  7.494387e+09   6334947  0.005043       38984
# 1     7881.373316  3.096322e+10  27841794  0.022164      151616
# 2     7811.114997  2.289939e+10  20965836  0.016690      124459
# 3     8057.824157  1.630883e+10  14635391  0.011651       91317
# 4     7589.362177  1.691491e+10  15793382  0.012572       98018
# ..            ...           ...       ...       ...         ...
# 247  12191.148934  2.687558e+10  17453419  0.013894      136328
# 248  12255.794105  3.949372e+10  24787474  0.019732      184098
# 249  12455.825194  2.930881e+10  18521083  0.014744      146710
# 250  12093.459333  2.058693e+10  13340107  0.010619      109677
# 251  11941.551201  1.644329e+10  10881655  0.008662       86182
#
# [252 rows x 10 columns]

# %%
Kline(df_week)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=a19793d7b7544c148242b3e4e95e0c85></div><script>require([`echarts`],(a=>{let ad=11573.570994532904,aj=5,a1=13533.938315868378,N=12929.589347839355,G=13676.964454650879,ar=`solid`,F=13079.06436920166,B=14993.91918873787,T=13378.829674720764,a8=13475.972452163696,aa=12540.904975891113,m=8401.431248397828,Q=13198.644386291504,Y=13388.576626777649,
# %% [markdown]
# ### Fortnight

# %%
sql_fortnight = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CONCAT(CAST(year(date) AS CHAR), CAST(FLOOR((week(date)-1) / 2) AS CHAR)) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_fortnight = get_data_d(sql_fortnight, sd, ed, freq="fortnight", instruments=['600519.SH'])
df_fortnight
# Out:
#           date instrument          open         close          high  \
# 0   2020-01-02  600519.SH   8255.352493   8141.914582   8380.207381
# 1   2020-01-13  600519.SH   8141.914582   7704.995660   8264.134783
# 2   2020-02-03  600519.SH   7208.796282   7874.786598   7882.105173
# 3   2020-02-10  600519.SH   7772.326550   8144.695641   8226.078194
# 4   2020-02-24  600519.SH   8090.684558   8456.613303   8606.644089
# ..         ...        ...           ...           ...           ...
# 124 2024-09-23  600519.SH  10169.984769  14019.821274  14115.104728
# 125 2024-10-08  600519.SH  15319.141095  12359.579281  15319.141095
# 126 2024-10-21  600519.SH  12361.263585  12301.430709  12672.378497
# 127 2024-11-04  600519.SH  12391.099817  12503.948150  13371.043618
# 128 2024-11-18  600519.SH  12528.009628  12175.107949  12640.216321
#
#               low        amount    volume      turn deal_number
# 0     7811.114997  5.386261e+10  48807630  0.038853      276075
# 1     7589.362177  3.322374e+10  30428773  0.024223      189335
# 2     7172.203407  3.212196e+10  31193522  0.024832      169463
# 3     7737.197390  3.575924e+10  32670909  0.026008      192227
# 4     7684.284093  4.966309e+10  44981544  0.035808      255735
# ..            ...           ...       ...       ...         ...
# 124  10111.114352  8.482945e+10  56240944  0.044771      396250
# 125  11861.987913  1.113749e+11  67455114  0.053698      481277
# 126  12191.148934  5.322917e+10  34456756  0.027429      262970
# 127  12255.794105  6.880253e+10  43308557  0.034476      330808
# 128  11941.551201  3.703022e+10  24221762  0.019282      195859
#
# [129 rows x 10 columns]

# %%
Kline(df_fortnight)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=4081601db21847b1ba673673de074de6></div><script>require([`echarts`],(a=>{let G=5,i=8141.914582252502,r=12929.589347839355,O=`solid`,p=15326.42131538391,P=`blank`,C=12778.462178707123,n=13079.06436920166,E=12953.04323352937,e=`4081601db21847b1ba673673de074de6`,I=14,t=13400.435665130615,j=8401.431248397828,y=13388.576626777649,l=12623.886334896088,s=13228.539390563965,H=10,h=`Kline`,L=`auto`,w=14605.02444601059,o=13818.965724945068,D=13673.964379291534,k=10106.951944351196,B=14748.287369756697,x=13847.61353969574,v=14436.710911273956,J=`end`,q=13378.01441192627,A=13717.553081035614,z=14138.336917877197,N=1,M=100,F=15319.14109463468,m=12533.260898685456,K=15,g=0,f=`cubicOut`,u=13588.841794967651;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[8255.352493286133,i,7811.114996528625,8380.20738117218],[i,7704.99566040039,7589.362176895142,8264.134783172607],[7208.796281814575,7874.786598205566,7172.203407287598,7882.105173110962],[7772.326549530029,8144.6956407165535,7737.197389984131,8226.07819366455],[8090.684557914734,8456.61330318451,7684.284093418121,8606.644088745117],[8306.582517623901,7576.774228057861,7026.563766670227,8559.658837852478],[7318.574905395508,8341.638491420745,7256.513390197753,j],[8503.81811132431,8972.572834014893,j,9035.219835205078],[8935.979959487915,9263.120257759094,8731.05986213684,9513.708262519836],[9155.53720664978,9609.288850784302,9148.218631744385,9792.25322341919],[9558.058826446533,10001.5644657135,9551.69166627884,10040.792027206422],[k,10365.809938755034,k,10502.154989242554],[10260.642017364502,10809.970843291283,k,10852.173865056038],[10721.048336029053,12689.41207921505,10639.677948451043,12918.715164136886],[12695.557431507112,11811.663266897202,11735.401666164398,13231.017525196075],[11965.00091264248,12075.98745584488,11835.356191396713,l],[12053.553217959405,12409.169206619263,11885.33345401287,12734.946918487549],[12586.8661403656,13105.14886379242,12520.303830599785,13534.58312034607],[13031.108474731445,12549.845945835114,12105.67765185833,13164.307134652137],[m,12353.638914823532,12002.095147562028,m],[12527.633829116821,12675.71460723877,12498.017673492432,12961.65858979225],[12771.967113018036,12364.8930539608,11846.46224975586,12939.224351906776],[12401.765167713165,l,12379.553050994873,13160.67915558815],[12668.310568332672,12867.479214906693,12443.22778558731,13400.570016145706],[12846.00750207901,13475.35080909729,12689.856321549416,13882.572948932648],[13532.880191397668,13549.391198158264,13290.397917222977,14113.578962802887],[13524.217465877533,14793.26973438263,13520.14524447918,14800.525692510604],[14807.929731416702,15415.209002494812,14678.210969781876,16091.419875788688],[15260.168427801133,15668.27905230522,14678.50713133812,16192.63308763504],[15770.602869987488,19257.90519475937,15511.461508274078,19259.38600254059],[19161.50460820198,15717.145709085466,15306.369630575182,19456.925760555267],[16133.400776386261,15000.582823753357,14069.006648588182,16140.804815292358],[15178.279757499695,14904.33031797409,14414.182942390442,15447.490612125397],[15127.932292938232,14956.158590316772,14808.077812194824,16029.744231700897],[14889.522240161896,15614.673810625076,14734.03742313385,15763.19883108139],[15785.410947799683,14089.886038303375,14075.07796049118,15807.623064517975],[14067.673921585083,15119.787850141525,13 ...

# %% [markdown]
# ### Month

# %%
sql_month = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CONCAT(CAST(year(date) AS CHAR), CAST(month(date) AS CHAR)) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_month = get_data_d(sql_month, sd, ed, freq="month", instruments=['600519.SH'])
df_month
# Out:
#          date instrument          open         close          high  \
# 0  2020-01-02  600519.SH   8255.352493   7704.995660   8380.207381
# 1  2020-02-03  600519.SH   7208.796282   7735.733675   8226.078194
# 2  2020-03-02  600519.SH   7685.308694   8130.936720   8606.644089
# 3  2020-04-01  600519.SH   8174.848169   9263.120258   9513.708263
# 4  2020-05-06  600519.SH   9155.537207  10001.564466  10040.792027
# 5  2020-06-01  600519.SH  10106.951944  10831.220435  10876.385072
# 6  2020-07-01  600519.SH  10869.129114  12425.310011  13231.017525
# 7  2020-08-03  600519.SH  12489.725150  13227.315506  13445.734653
# 8  2020-09-01  600519.SH  13268.037720  12353.638915  13534.583120
# 9  2020-10-09  600519.SH  12527.633829  12364.893054  12961.658590
# 10 2020-11-02  600519.SH  12401.765168  12689.856322  13400.570016
# 11 2020-12-01  600519.SH  12779.371152  14793.269734  14800.525693
# 12 2021-01-04  600519.SH  14807.929731  15668.279052  16192.633088
# 13 2021-02-01  600519.SH  15770.602870  15717.145709  19456.925761
# 14 2021-03-01  600519.SH  16133.400776  14874.714162  16140.804815
# 15 2021-04-01  600519.SH  14963.562629  14858.277196  16029.744232
# 16 2021-05-06  600519.SH  14808.077812  16422.158294  17177.370262
# 17 2021-06-01  600519.SH  16451.774449  15371.263822  16940.441017
# 18 2021-07-01  600519.SH  15395.702988  12548.353306  15769.614754
# 19 2021-08-02  600519.SH  12436.321777  11644.104164  13474.276326
# 20 2021-09-01  600519.SH  11651.577915  13676.964455  13926.587740
# 21 2021-10-08  600519.SH  13620.313422  13647.667350  14573.440895
# 22 2021-11-01  600519.SH  13303.276901  14430.094350  14872.764626
# 23 2021-12-01  600519.SH  14573.814583  15321.189690  16569.007168
# 24 2022-01-04  600519.SH  15358.558445  14102.968266  15462.817272
# 25 2022-02-07  600519.SH  14207.526043  13381.003912  14301.471094
# 26 2022-03-01  600519.SH  13467.699425  12847.378086  13927.858278
# 27 2022-04-01  600519.SH  12929.140923  13664.856978  13818.965725
# 28 2022-05-05  600519.SH  13676.964455  13482.871139  13975.914497
# 29 2022-06-01  600519.SH  13467.699425  15448.733306  15690.473876
# 30 2022-07-01  600519.SH  15524.277234  14341.561495  15620.746830
# 31 2022-08-01  600519.SH  14277.877964  14534.651775  14651.744864
# 32 2022-09-01  600519.SH  14445.132221  14145.600545  14474.216633
# 33 2022-10-10  600519.SH  14277.802420  10198.430300  14285.356812
# 34 2022-11-01  600519.SH  10266.419835  12079.474111  12117.246075
# 35 2022-12-01  600519.SH  12540.292072  13212.612477  13718.777351
# 36 2023-01-03  600519.SH  13244.745061  14121.199540  14803.940442
# 37 2023-02-01  600519.SH  14191.738212  13876.226841  14436.710911
# 26  11905.685452  1.745857e+11  101300439  0.080641      725660
# 27  12705.376816  1.156229e+11   65067625  0.051797      477976
# 28  12742.820309  9.591588e+10   54057347  0.043033      406573
# 29  13138.854378  1.310913e+11   68527543  0.054552      508417
# 30  14187.905145  9.783988e+10   49856830  0.039689      369492
# 31  13983.181100  9.440402e+10   49792725  0.039638      376998
# 32  13681.080931  9.277785e+10   49850719  0.039684      382981
# 33  10070.005622  1.581078e+11  101008970  0.080408      730246
# 34  10266.419835  1.565041e+11  103833876  0.082657      764926
# 35  12247.181631  1.105898e+11   64213759  0.051118      483737
# 36  13052.026063  8.153112e+10   44202953  0.035188      333278
# 37  13465.082779  9.643295e+10   52847305  0.042069      404753
# 38  13189.431113  8.348217e+10   46865651  0.037308      371873
# 39  12883.712529  7.908363e+10   45270884  0.036038      348523
# 40  12445.026252  8.124542e+10   47550660  0.037853      373507
# 41  12378.695418  7.502610e+10   43912652  0.034957      332158
# 42  13128.024974  7.917457e+10   44514216  0.035436      339580
# 43  13750.091388  9.041343e+10   49027320  0.039028      380812
# 44  13772.774129  6.782971e+10   37160992  0.029582      291805
# 45  12555.130393  8.108917e+10   47867377  0.038105      365283
# 46  13490.482752  8.549447e+10   47932606  0.038157      356725
# 47  12700.781558  9.388035e+10   55601980  0.044262      435573
# 48  12223.060611  1.072367e+11   65687435  0.052291      516932
# 49  12423.039328  9.118269e+10   54455207  0.043349      432013
# 50  13096.287911  8.836643e+10   51940560  0.041347      416393
# 51  12839.735045  9.590474e+10   57007757  0.045381      450972
# 52  12953.043234  8.732924e+10   51091654  0.040672      398773
# 53  11341.056911  1.129376e+11   73418973  0.058445      583355
# 54  10918.296739  1.076448e+11   73996170  0.058905      601257
# 55  11016.948800  6.997590e+10   49400988  0.039326      401002
# 56   9992.170445  1.395714e+11   97301165  0.077457      718527
# 57  11861.987913  1.596498e+11   98683478  0.078557      719117
# 58  11941.551201  1.107871e+11   70758711  0.056328      551797

# %%
Kline(df_month)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=236210bba58845c6b67c0983460345a3></div><script>require([`echarts`],(a=>{let r=5,k=13676.964454650879,s=10,h=`Kline`,w=`auto`,z=`solid`,i=10106.951944351196,o=14370.914912223816,e=`236210bba58845c6b67c0983460345a3`,A=`blank`,l=13467.699424743652,u=`end`,j=14963.56262922287,p=12953.04323352937,t=14,m=10266.419835090637,y=1,x=100,q=15319.14109463468,n=12378.69541835785,v=15,g=0,f=`cubicOut`;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_bimonth = get_data_d(sql_bimonth, sd, ed, freq="bimonth", instruments=['600519.SH'])
df_bimonth
# Out:
#          date instrument          open         close          high  \
# 0  2020-01-02  600519.SH   8255.352493   7735.733675   8380.207381
# 1  2020-03-02  600519.SH   7685.308694   9263.120258   9513.708263
# 2  2020-05-06  600519.SH   9155.537207  10831.220435  10876.385072
# 3  2020-07-01  600519.SH  10869.129114  13227.315506  13445.734653
# 4  2020-09-01  600519.SH  13268.037720  12364.893054  13534.583120
# 5  2020-11-02  600519.SH  12401.765168  14793.269734  14800.525693
# 6  2021-01-04  600519.SH  14807.929731  15717.145709  19456.925761
# 7  2021-03-01  600519.SH  16133.400776  14858.277196  16140.804815
# 8  2021-05-06  600519.SH  14808.077812  15371.263822  17177.370262
# 9  2021-07-01  600519.SH  15395.702988  11644.104164  15769.614754
# 10 2021-09-01  600519.SH  11651.577915  13647.667350  14573.440895
# 11 2021-11-01  600519.SH  13303.276901  15321.189690  16569.007168
# 12 2022-01-04  600519.SH  15358.558445  13381.003912  15462.817272
# 13 2022-03-01  600519.SH  13467.699425  13664.856978  13927.858278
# 14 2022-05-05  600519.SH  13676.964455  15448.733306  15690.473876
# 15 2022-07-01  600519.SH  15524.277234  14534.651775  15620.746830
# 16 2022-09-01  600519.SH  14445.132221  10198.430300  14474.216633
# 17 2022-11-01  600519.SH  10266.419835  13212.612477  13718.777351
# 18 2023-01-03  600519.SH  13244.745061  13876.226841  14803.940442
# 19 2023-03-01  600519.SH  13870.565385  13469.061099  14138.336918
# 20 2023-05-04  600519.SH  13533.938316  13135.793036  13771.107388
# 21 2023-07-03  600519.SH  13197.937533  14347.610726  15031.200192
# 22 2023-09-01  600519.SH  14392.898528  13085.922077  14603.490692
# 23 2023-11-01  600519.SH  14370.914912  13562.407261  14370.914912
# 24 2024-01-02  600519.SH  13475.972452  13318.818254  13656.149740
# 25 2024-03-01  600519.SH  13279.529705  13397.396775  13743.920359
# 26 2024-05-06  600519.SH  13625.034654  11769.190812  13969.438115
# 27 2024-07-01  600519.SH  11781.141346  11575.094888  12271.193451
# 28 2024-09-02  600519.SH  11469.304589  12253.628572  15319.141095
# 29 2024-11-01  600519.SH  12199.169427  12175.107949  13371.043618
#
#              low        amount     volume      turn deal_number
# 0    7172.203407  1.770468e+11  163605015  0.130238      939836
# 1    7026.563767  1.971369e+11  175655142  0.139831     1027632
# 2    9148.218632  1.393701e+11  101000419  0.080402      651508
# 3   10839.661039  3.014573e+11  180691494  0.143840     1121247
# 4   11846.462250  1.928262e+11  113308907  0.090200      736104
# 5   12379.553051  2.569005e+11  143279965  0.114059      884454
# 6   14678.210970  3.636830e+11  165553251  0.131789     1077415
# 7   14069.006649  3.701823e+11  181494122  0.144479     1240002
# 8   13816.010639  2.762600e+11  131406144  0.104606      917687
# 9   11401.207254  3.923210e+11  223135195  0.177627     1559928
# 10  11443.060260  2.647757e+11  150680636  0.119950     1070458
# 11  12966.958103  3.169608e+11  160545454  0.127803     1132140
# 12  13064.864242  2.121396e+11  111765122  0.088971      828296
# 13  11905.685452  2.902085e+11  166368064  0.132438     1203636
# 14  12742.820309  2.270072e+11  122584890  0.097584      914990
# 15  13983.181100  1.922439e+11   99649555  0.079326      746490
# 16  10070.005622  2.508856e+11  150859689  0.120092     1113227
# 17  10266.419835  2.670939e+11  168047635  0.133775     1248663
# 18  13052.026063  1.779641e+11   97050258  0.077257      738031
# 19  12883.712529  1.625658e+11   92136535  0.073346      720396
# 20  12378.695418  1.562715e+11   91463312  0.072810      705665
# 21  13128.024974  1.695880e+11   93541536  0.074464      720392
# 22  12555.130393  1.489189e+11   85028369  0.067687      657088
# 23  12700.781558  1.793748e+11  103534586  0.082419      792298
# 24  12223.060611  1.984194e+11  120142642  0.095640      948945
# 25  12839.735045  1.842712e+11  108948317  0.086729      867365
# 26  11341.056911  2.002668e+11  124510627  0.099117      982128
# 27  10918.296739  1.776207e+11  123397158  0.098231     1002259
# 28   9992.170445  2.992212e+11  195984643  0.156014     1437644
# 29  11941.551201  1.107871e+11   70758711  0.056328      551797

# %%
Kline(df_bimonth)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=f5547513b9304a51b040508779dbaab0></div><script>require([`echarts`],(a=>{let k=5,l=10,h=`Kline`,p=`auto`,s=`solid`,j=14370.914912223816,r=1,e=`f5547513b9304a51b040508779dbaab0`,q=100,o=15,g=0,t=`blank`,f=`cubicOut`,n=`end`,m=14,i=10266.419835090637;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.get
# %% [markdown]
# ### Quarter

# %%
sql_quarter = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CONCAT(CAST(year(date) AS CHAR), CAST(FLOOR((month(date)-1) / 3) AS CHAR)) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_quarter = get_data_d(sql_quarter, sd, ed, freq="quarter", instruments=['600519.SH'])
df_quarter
# Out:
#          date instrument          open         close          high  \
# 0  2020-01-02  600519.SH   8255.352493   8130.936720   8606.644089
# 1  2020-04-01  600519.SH   8174.848169  10831.220435  10876.385072
# 2  2020-07-01  600519.SH  10869.129114  12353.638915  13534.583120
# 3  2020-10-09  600519.SH  12527.633829  14793.269734  14800.525693
# 4  2021-01-04  600519.SH  14807.929731  14874.714162  19456.925761
# 5  2021-04-01  600519.SH  14963.562629  15371.263822  17177.370262
# 6  2021-07-01  600519.SH  15395.702988  13676.964455  15769.614754
# 7  2021-10-08  600519.SH  13620.313422  15321.189690  16569.007168
# 8  2022-01-04  600519.SH  15358.558445  12847.378086  15462.817272
# 9  2022-04-01  600519.SH  12929.140923  15448.733306  15690.473876
# 10 2022-07-01  600519.SH  15524.277234  14145.600545  15620.746830
# 11 2022-10-10  600519.SH  14277.802420  13212.612477  14285.356812
# 12 2023-01-03  600519.SH  13244.745061  13924.119692  14803.940442
# 13 2023-04-03  600519.SH  13962.372768  13135.793036  13983.564972
# 14 2023-07-03  600519.SH  13197.937533  13971.248116  15031.200192
# 15 2023-10-09  600519.SH  13958.741536  13562.407261  14370.914912
# 16 2024-01-02  600519.SH  13475.972452  13380.894163  13743.920359
# 17 2024-04-01  600519.SH  13436.605326  11769.190812  13969.438115
# 18 2024-07-01  600519.SH  11781.141346  14019.821274  14115.104728
# 19 2024-10-08  600519.SH  15319.141095  12175.107949  15319.141095
#
#              low        amount     volume      turn deal_number
# 0    7026.563767  3.000018e+11  277396329  0.220822     1590546
# 1    8072.388121  2.135521e+11  162864247  0.129649     1028430
# 2   10839.661039  4.142098e+11  246736746  0.196416     1553731
# 3   11846.462250  3.369742e+11  190543620  0.151683     1188074
# 4   14069.006649  5.853278e+11  274816165  0.218768     1818844
# 5   13816.010639  4.247975e+11  203637352  0.162106     1416260
# 6   11401.207254  5.521871e+11  317298148  0.252586     2236793
# 7   12966.958103  4.218704e+11  217063137  0.172794     1525733
# 8   11905.685452  3.867253e+11  213065561  0.169611     1553956
# 9   12705.376816  3.426301e+11  187652515  0.149381     1392966
# 10  13681.080931  2.850218e+11  149500274  0.119010     1129471
# 11  10070.005622  4.252017e+11  269056605  0.214183     1978909
# 12  13052.026063  2.614462e+11  143915909  0.114565     1109904
# 13  12378.695418  2.353552e+11  136734196  0.108848     1054188
# 14  13128.024974  2.374177e+11  130702528  0.104046     1012197
# 15  12555.130393  2.604640e+11  151401963  0.120524     1157581
# 16  12223.060611  2.867858e+11  172083202  0.136987     1365338
# 17  11341.056911  2.961716e+11  181518384  0.144498     1433100
# 18   9992.170445  3.171921e+11  220698323  0.175688     1720786
# 19  11861.987913  2.704369e+11  169442189  0.134885     1270914

# %%
Kline(df_quarter)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=9a6dc639b14e4bd7abf0728ffc793cd2></div><script>require([`echarts`],(a=>{let j=5,k=10,h=`Kline`,o=`auto`,r=`solid`,q=1,p=100,i=15319.14109463468,n=15,s=`blank`,g=0,f=`cubicOut`,e=`9a6dc639b14e4bd7abf0728ffc793cd2`,m=`end`,l=14;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[8255.352493286133,8130.936719894409,7026.563766670227,8606.644088745117],[8174.848169326782,10831.220434951783,8072.388120651245,10876
sql_quadmonth = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CONCAT(CAST(year(date) AS CHAR), CAST(FLOOR((month(date)-1) / 4) AS CHAR)) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_quadmonth = get_data_d(sql_quadmonth, sd, ed, freq="quadmonth", instruments=['600519.SH'])
df_quadmonth
# Out:
#          date instrument          open         close          high  \
# 0  2020-01-02  600519.SH   8255.352493   9263.120258   9513.708263
# 1  2020-05-06  600519.SH   9155.537207  13227.315506  13445.734653
# 2  2020-09-01  600519.SH  13268.037720  14793.269734  14800.525693
# 3  2021-01-04  600519.SH  14807.929731  14858.277196  19456.925761
# 4  2021-05-06  600519.SH  14808.077812  11644.104164  17177.370262
# 5  2021-09-01  600519.SH  11651.577915  15321.189690  16569.007168
# 6  2022-01-04  600519.SH  15358.558445  13664.856978  15462.817272
# 7  2022-05-05  600519.SH  13676.964455  14534.651775  15690.473876
# 8  2022-09-01  600519.SH  14445.132221  13212.612477  14474.216633
# 9  2023-01-03  600519.SH  13244.745061  13469.061099  14803.940442
# 10 2023-05-04  600519.SH  13533.938316  14347.610726  15031.200192
# 11 2023-09-01  600519.SH  14392.898528  13562.407261  14603.490692
# 12 2024-01-02  600519.SH  13475.972452  13397.396775  13743.920359
# 13 2024-05-06  600519.SH  13625.034654  11575.094888  13969.438115
# 14 2024-09-02  600519.SH  11469.304589  12175.107949  15319.141095
#
#              low        amount     volume      turn deal_number
# 0    7026.563767  3.741837e+11  339260157  0.270069     1967468
# 1    9148.218632  4.408274e+11  281691913  0.224242     1772755
# 2   11846.462250  4.497267e+11  256588872  0.204259     1620558
# 3   14069.006649  7.338654e+11  347047373  0.276268     2317417
# 4   11401.207254  6.685810e+11  354541339  0.282234     2477615
# 5   11443.060260  5.817365e+11  311226090  0.247752     2202598
# 6   11905.685452  5.023481e+11  278133186  0.221409     2031932
# 7   12742.820309  4.192511e+11  222234445  0.176910     1661480
# 8   10070.005622  5.179796e+11  318907324  0.253867     2361890
# 9   12883.712529  3.405299e+11  189186793  0.150603     1458427
# 10  12378.695418  3.258595e+11  185004848  0.147274     1426057
# 11  12555.130393  3.282937e+11  188562955  0.150106     1449386
# 12  12223.060611  3.826905e+11  229090959  0.182369     1816310
# 13  10918.296739  3.778875e+11  247907785  0.197348     1984387
# 14   9992.170445  4.100083e+11  266743354  0.212342     1989441

# %%
Kline(df_quadmonth)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=9a21bf1bdc2a438c9149c026fd2c7be6></div><script>require([`echarts`],(a=>{let i=5,j=10,h=`Kline`,n=`auto`,q=`solid`,p=1,o=100,m=15,r=`blank`,g=0,f=`cubicOut`,l=`end`,e=`9a21bf1bdc2a438c9149c026fd2c7be6`,k=14;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[8255.352493286133,9263.120257759094,7026.563766670227,9513.708262519836],[9155.53720664978,13227.315505743027,9148.218631744385,13445.7346534729],[13268.037719726563,14793.26973438263,11846.46224975586,14800.525692510604],[14807.929731416702,14858.277195978164,14069.006648588182,19456.925760555267],[14808.077812194824,11644.104164123535,11401.20725440979,17177.370262145996],[11651.57791519165,15321.18968963623,11443.060260391234,16569.00716796875],[15358.558444976807,13664.856977920534,11905.685451507568,15462.817272377013],[13676.964454650879,14534.651775360107,12742.820308647155,15690.47387599945],[14445.132220506668,13212.612476825714,10070.005621910095,14474.216632843018],[13244.745060729982,13469.061098842622,12883.712528719901,14803.940441608429],[13533.938315868378,14347.61072587967,12378.69541835785,15031.20019197464],[14392.89852800846,13562.407260894775,12555.13039290905,14603.490691938401],[13475.972452163696,13397.39677464744,12223.06061105728,13743.92035923004],[13625.034654155674,11575.094888149648,10918.296739333084,13969.438114937373],[11469.30458917675,12175.107948510706,9992.17044498886,15319.14109463468]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":i,"itemGap":j,"itemWidth":25,"itemHeight":k,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":i,"pageButtonPosition":l,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":m,"animationDurationUpdate":800,"selector":!1,"selectorPosition":n,"selectorItemGap":7,"selectorButtonGap":j,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":o,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":k},"borderWidth":g,"padding":i,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":l,"nameGap":m,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":i,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":p,"opacity":p,"curveness":g,"type":q}},"data":[`2020-01-02T00:00:00`,`2020-05-06T00:00:00`,`2020-09-01T00:00:00`,`2021-01-04T00:00:00`,`2021-05-06T00:00:00`,`2021-09-01T00:00:00`,`2022-01-04T00:00:00`,`2022-05-05T00:00:00`,`2022-09-01T00:00:00`,`2023-01-03T00:00:00`,`2023-05-04T00:00:00`,`2023-09-01T00:00:00`,`2024-01-02T00:00:00`,`2024-05-06T00:00:00`,`2024-09-02T00:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":l,"nameGap":m,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":i,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":p,"opacity":p,"curveness":g,"type":q}}}],"title":[{"show":!0,"target":r,"subtarget":r,"padding":i,"itemGap":j,"textAlign":n,"textVerticalAlign":n,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":o,"orient":`horizontal`,"xAxisIndex":[g,p],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### Semiannual

# %%
sql_semiannual = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CONCAT(CAST(year(date) AS CHAR), CAST(FLOOR((month(date)-1) / 6) AS CHAR)) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_semiannual = get_data_d(sql_semiannual, sd, ed, freq="semiannual", instruments=['600519.SH'])
df_semiannual
# Out:
#         date instrument          open         close          high  \
# 0 2020-01-02  600519.SH   8255.352493  10831.220435  10876.385072
# 1 2020-07-01  600519.SH  10869.129114  14793.269734  14800.525693
# 2 2021-01-04  600519.SH  14807.929731  15371.263822  19456.925761
# 3 2021-07-01  600519.SH  15395.702988  15321.189690  16569.007168
# 4 2022-01-04  600519.SH  15358.558445  15448.733306  15690.473876
# 5 2022-07-01  600519.SH  15524.277234  13212.612477  15620.746830
# 6 2023-01-03  600519.SH  13244.745061  13135.793036  14803.940442
# 7 2023-07-03  600519.SH  13197.937533  13562.407261  15031.200192
# 8 2024-01-02  600519.SH  13475.972452  11769.190812  13969.438115
# 9 2024-07-01  600519.SH  11781.141346  12175.107949  15319.141095
#
#             low        amount     volume      turn deal_number
# 0   7026.563767  5.135538e+11  440260576  0.350471     2618976
# 1  10839.661039  7.511840e+11  437280366  0.348099     2741805
# 2  13816.010639  1.010125e+12  478453517  0.380874     3235104
# 3  11401.207254  9.740575e+11  534361285  0.425380     3762526
# 4  11905.685452  7.293553e+11  400718076  0.318993     2946922
# 5  10070.005622  7.102235e+11  418556879  0.333193     3108380
# 6  12378.695418  4.968014e+11  280650105  0.223412     2164092
# 7  12555.130393  4.978817e+11  282104491  0.224570     2169778
# 8  11341.056911  5.829574e+11  353601586  0.281486     2798438
# 9   9992.170445  5.876290e+11  390140512  0.310573     2991700

# %%
Kline(df_semiannual)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=0619bc681eee4f9d87d2b8befa333381></div><script>require([`echarts`],(a=>{let g=0,i=5,r=`blank`,f=`cubicOut`,e=`0619bc681eee4f9d87d2b8befa333381`,l=`end`,j=10,h=`Kline`,n=`auto`,q=`solid`,p=1,o=100,k=14,m=15;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[8255.352493286133,10831.220434951783,7026.563766670227,10876.385072278976],[10869.129114151001,14793.26973438263,10839.661039304734,14800.525692510604],[14807.929731416702,15371.263821792601,13816.010639166832,19456.925760555267],[15395.702987785338,15321.18968963623,11401.20725440979,16569.00716796875],[15358.558444976807,15448.733305931091,11905.685451507568,15690.47387599945],[15524.277234077454,13212.612476825714,10070.005621910095,15620.746830320359],[13244.745060729982,13135.79303598404,12378.69541835785,14803.940441608429],[13197.937532901764,13562.407260894775,12555.13039290905,15031.20019197464],[13475.972452163696,11769.190811966486,11341.056910588684,13969.438114937373],[11781.141346118844,12175.107948510706,9992.17044498886,15319.14109463468]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":i,"itemGap":j,"itemWidth":25,"itemHeight":k,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":i,"pageButtonPosition":l,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":m,"animationDurationUpdate":800,"selector":!1,"selectorPosition":n,"selectorItemGap":7,"selectorButtonGap":j,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":o,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":k},"borderWidth":g,"padding":i,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":l,"nameGap":m,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":i,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":p,"opacity":p,"curveness":g,"type":q}},"data":[`2020-01-02T00:00:00`,`2020-07-01T00:00:00`,`2021-01-04T00:00:00`,`2021-07-01T00:00:00`,`2022-01-04T00:00:00`,`2022-07-01T00:00:00`,`2023-01-03T00:00:00`,`2023-07-03T00:00:00`,`2024-01-02T00:00:00`,`2024-07-01T00:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":l,"nameGap":m,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":i,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":p,"opacity":p,"curveness":g,"type":q}}}],"title":[{"show":!0,"target":r,"subtarget":r,"padding":i,"itemGap":j,"textAlign":n,"textVerticalAlign":n,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":o,"orient":`horizontal`,"xAxisIndex":[g,p],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### Year

# %%
sql_year = """
WITH 
data_orgn AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
        turn,
        volume / turn AS turn_base,
        deal_number,
    FROM cn_stock_bar1d
),
data_freq AS (
    WITH 
    data1 AS (
        SELECT
            instrument,
            CAST(year(date) AS CHAR) AS period,
            FIRST_VALUE(date) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS date,
            FIRST_VALUE(open) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
            LAST_VALUE(close) OVER (PARTITION BY period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
            MAX(high)         OVER (PARTITION BY period, instrument) AS high,
            MIN(low)          OVER (PARTITION BY period, instrument) AS low,
            SUM(amount)       OVER (PARTITION BY period, instrument) AS amount,
            SUM(volume)       OVER (PARTITION BY period, instrument) AS volume,
            AVG(turn_base)    OVER (PARTITION BY period, instrument) AS turn_base,
            SUM(deal_number)  OVER (PARTITION BY period, instrument) AS deal_number,
            ROW_NUMBER()      OVER (PARTITION BY period, instrument ORDER BY date DESC) AS rn
        FROM data_orgn
    ),
    data2 AS (
        SELECT
            date,
            instrument,
            open,
            close,
            high,
            low,
            amount,
            volume,
            turn_base,
            deal_number,
        FROM data1
        WHERE rn = 1 
    )
    SELECT 
        date,
        instrument,
        open,
        close,
        high,
        low,
        amount,
        volume,
        volume / turn_base AS turn,
        deal_number,
    FROM data2
)
SELECT
    date,
    instrument,
    open,
    close,
    high,
    low,
    amount,
    volume,
    turn,
    deal_number,
FROM data_freq
ORDER BY date, instrument
"""

df_year = get_data_d(sql_year, sd, ed, freq="year", instruments=['600519.SH'])
df_year
# Out:
#         date instrument          open         close          high  \
# 0 2020-01-02  600519.SH   8255.352493  14793.269734  14800.525693
# 1 2021-01-04  600519.SH  14807.929731  15321.189690  19456.925761
# 2 2022-01-04  600519.SH  15358.558445  13212.612477  15690.473876
# 3 2023-01-03  600519.SH  13244.745061  13562.407261  15031.200192
# 4 2024-01-02  600519.SH  13475.972452  12175.107949  15319.141095
#
#             low        amount      volume      turn deal_number
# 0   7026.563767  1.264738e+12   877540942  0.698569     5360781
# 1  11401.207254  1.984183e+12  1012814802  0.806254     6997630
# 2  10070.005622  1.439579e+12   819274955  0.652186     6055302
# 3  12378.695418  9.946831e+11   562754596  0.447982     4333870
# 4   9992.170445  1.170586e+12   743742098  0.592058     5790138

# %%
Kline(df_year)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=34d4b5e358c741878b263572d33c5dab></div><script>require([`echarts`],(a=>{let g=0,i=5,f=`cubicOut`,l=`end`,j=10,e=`34d4b5e358c741878b263572d33c5dab`,h=`Kline`,n=`auto`,q=`solid`,p=1,o=100,k=14,m=15,r=`blank`;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[8255.352493286133,14793.26973438263,7026.563766670227,14800.525692510604],[14807.929731416702,15321.18968963623,11401.20725440979,19456.925760555267],[15358.558444976807,13212.612476825714,10070.005621910095,15690.47387599945],[13244.745060729982,13562.407260894775,12378.69541835785,15031.20019197464],[13475.972452163696,12175.107948510706,9992.17044498886,15319.14109463468]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":i,"itemGap":j,"itemWidth":25,"itemHeight":k,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":i,"pageButtonPosition":l,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":m,"animationDurationUpdate":800,"selector":!1,"selectorPosition":n,"selectorItemGap":7,"selectorButtonGap":j,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":o,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":k},"borderWidth":g,"padding":i,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":l,"nameGap":m,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":i,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":p,"opacity":p,"curveness":g,"type":q}},"data":[`2020-01-02T00:00:00`,`2021-01-04T00:00:00`,`2022-01-04T00:00:00`,`2023-01-03T00:00:00`,`2024-01-02T00:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":l,"nameGap":m,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":i,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":p,"opacity":p,"curveness":g,"type":q}}}],"title":[{"show":!0,"target":r,"subtarget":r,"padding":i,"itemGap":j,"textAlign":n,"textVerticalAlign":n,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":o,"orient":`horizontal`,"xAxisIndex":[g,p],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>
