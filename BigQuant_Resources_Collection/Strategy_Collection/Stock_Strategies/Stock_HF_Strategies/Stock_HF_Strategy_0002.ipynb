# %% [markdown]
# # Stock Strayegy - High Frequency 0002 - Intraday Stock Timing Strategy

# %% [markdown]
# # 1. Import Library

# %%
import dai
import random
import pandas as pd

# %% [markdown]
# # 2. Prepare Strategy Data

# %%
sd = "2026-02-01 00:00:00.000"
ed = "2026-02-13 23:59:59.000"

# %%
instrument_list = ['600519.SH']

# %%
sql = f"""
WITH 
data_origin AS (
    SELECT
        date,
        instrument,
        make_date(year(date), month(date),  day(date)) AS day,
        AVG(close) OVER (PARTITION BY instrument, day ROWS BETWEEN  9 PRECEDING AND CURRENT ROW) AS ma_short,
        AVG(close) OVER (PARTITION BY instrument, day ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma_long,
        IF(ma_short > ma_long AND m_lag(ma_short,1) < m_lag(ma_long,1), 1, 0) AS signal_buy,
        IF(ma_short < ma_long AND m_lag(ma_short,1) > m_lag(ma_long,1), 1, 0) AS signal_sell,
    FROM cn_stock_bar1m_c
)
SELECT
    date,
    instrument,
    signal_buy,
    signal_sell
FROM data_origin
QUALIFY (signal_buy = 1 OR signal_sell = 1)
ORDER BY date, instrument
"""

# %%
df = dai.query(sql, filters={"date":[sd, ed], "instrument":instrument_list}).df()
df
# Out:
#                    date instrument  signal_buy  signal_sell
# 0   2026-02-02 09:49:00  600519.SH           1            0
# 1   2026-02-02 10:24:00  600519.SH           1            0
# 2   2026-02-02 10:30:00  600519.SH           0            1
# 3   2026-02-02 10:32:00  600519.SH           1            0
# 4   2026-02-02 10:36:00  600519.SH           0            1
# ..                  ...        ...         ...          ...
# 134 2026-02-13 13:26:00  600519.SH           0            1
# 135 2026-02-13 14:38:00  600519.SH           1            0
# 136 2026-02-13 14:42:00  600519.SH           0            1
# 137 2026-02-13 14:48:00  600519.SH           1            0
# 138 2026-02-13 14:51:00  600519.SH           0            1
#
# [139 rows x 4 columns]

# %%
def filter_signals(df):

    df_new = df.copy()

    df_new["date"] = pd.to_datetime(df_new["date"])
    df_new["day"] = df_new["date"].dt.date

    df_new["sig"] = None
    df_new.loc[df_new["signal_sell"] == 1, "sig"] = "sell"
    df_new.loc[(df_new["signal_buy"] == 1) & (df_new["sig"].isna()), "sig"] = "buy"

    df_new = df_new[df_new["sig"].notna()].sort_values(["instrument", "day", "date"])

    def pick_group(g: pd.DataFrame) -> pd.DataFrame:
        first_sig = g.iloc[0]["sig"]

        if first_sig == "buy":
            return g[g["sig"] == "buy"].head(1)

        first_sell = g[g["sig"] == "sell"].head(1)

        t0 = first_sell.iloc[0]["date"]
        next_buy = g[(g["sig"] == "buy") & (g["date"] > t0)].head(1)

        return pd.concat([first_sell, next_buy], axis=0)

    out = (
        df_new.groupby(["instrument", "day"], group_keys=False)
           .apply(pick_group)
           .sort_values(["date", "instrument"])
           .reset_index(drop=True)
    )

    return out[["date", "instrument", "signal_buy", "signal_sell"]]

# %%
df_filtered = filter_signals(df)
df_filtered
# Out:
#                   date instrument  signal_buy  signal_sell
# 0  2026-02-02 09:49:00  600519.SH           1            0
# 1  2026-02-03 09:35:00  600519.SH           1            0
# 2  2026-02-04 09:31:00  600519.SH           1            0
# 3  2026-02-05 09:33:00  600519.SH           1            0
# 4  2026-02-06 09:57:00  600519.SH           0            1
# 5  2026-02-06 11:11:00  600519.SH           1            0
# 6  2026-02-09 09:46:00  600519.SH           1            0
# 7  2026-02-10 09:25:00  600519.SH           1            0
# 8  2026-02-11 09:33:00  600519.SH           0            1
# 9  2026-02-11 09:39:00  600519.SH           1            0
# 10 2026-02-12 09:31:00  600519.SH           1            0
# 11 2026-02-13 09:38:00  600519.SH           0            1
# 12 2026-02-13 09:52:00  600519.SH           1            0

# %% [markdown]
# ## 3. Backtest Strategy

# %%
from bigmodule import M

def BigTrader_Initialize(context):
    from bigtrader.finance.commission import PerOrder
    context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))
    context.holding_days = 1
    context.weight = 1 / len(df['instrument'].unique())

def BigTrader_Before_Trading(context, data):
    context.subscribe_bar(context.instruments, '1m')

def BigTrader_Handle_Tick(context, tick):
    pass

def BigTrader_Handle_Data(context, data):

    dt_now = data.current_dt.strftime("%Y-%m-%d %H:%M:%S")
    df_now = context.data[context.data["date"] == dt_now]

    if dt_now[11:] == "09:25:00":
        for instrument in set(context.get_account_positions().keys()):
            time_diff_days = (data.current_dt - context.get_position(instrument).last_sale_date).days
            if time_diff_days >= context.holding_days:
                context.order_target_percent(instrument, 0)

    if len(df_now) == 0:
        return

    instruments_hold = set(context.get_account_positions().keys())
    instruments_buy  = set(df_now[df_now["signal_buy"]  == 1]["instrument"])
    instruments_sell = set(df_now[df_now["signal_sell"] == 1]["instrument"])

    for instrument in instruments_sell:
        context.order_target_percent(instrument, 0)

    for instrument in instruments_buy:
        context.order_target_percent(instrument, context.weight)
        
def BigTrader_Handle_Trade(context, trade):
    pass

def BigTrader_Handle_Order(context, order):
    pass

def BigTrader_After_Trading(context, data):
    pass

BigTrader = M.bigtrader.v34(
    
    data = df_filtered,
    
    start_date = """""",
    end_date   = """""",
    
    initialize           = BigTrader_Initialize,
    before_trading_start = BigTrader_Before_Trading,
    handle_tick          = BigTrader_Handle_Tick,
    handle_data          = BigTrader_Handle_Data,
    handle_trade         = BigTrader_Handle_Trade,
    handle_order         = BigTrader_Handle_Order,
    after_trading        = BigTrader_After_Trading,
    
    capital_base = 1000000  + random.uniform(0, 10),
    frequency="""minute""",
    product_type="""自动""",
    rebalance_period_type="""交易日""",
    rebalance_period_days="""1""",
    rebalance_period_roll_forward=True,
    backtest_engine_mode="""标准模式""",
    before_start_days=0,
    volume_limit=1,
    order_price_field_buy="""open""",
    order_price_field_sell="""open""",
    benchmark="""沪深300指数""",
    
    plot_charts=True,
    debug=False,
    backtest_only=False,
    m_name="""BigTrader"""
)
# Out:
# [2026-02-19 12:59:27] [info     ] bigtrader.v34 开始运行 ..
# [2026-02-19 12:59:27] [info     ] 2026-02-02, 2026-02-13, , , instruments=1
# [2026-02-19 12:59:27] [info     ] bigtrader module V2.2.0
# [2026-02-19 12:59:27] [info     ] bigtrader engine v0.1.0.post9+g7a244b6 2026-02-10
# [2026-02-19 12:59:28] [info     ] backtest done, raw_perf_ds:dai.DataSource("_69fd7264ad6444e08923468fd391389e")
# <style>#bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigchart653cb6b4b0254e6aa583fb83cc0f9531  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigchart653cb6b4b0254e6aa583fb83cc0f9531 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigchart653cb6b4b0254e6aa583fb83cc0f9531><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigchart40c96e04738542a4ba97319d35c9c27e')>收益概况</button><button class=tablinks onclick=showChart('bigchart64218ced224940c4b8404772f7b83625')>交易详情</button><button class=tablinks onclick=showChart('bigcharta49aa868c6fd4899a613ae3689fb5d16')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchart5ed78beee1c045af98ddec161e1220e2')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigchart40c96e04738542a4ba97319d35c9c27e><style>#bigchartcbfd98a6f6ec4efbba98d549af80f226 .value {color: #E74C3C}
# #bigchartcbfd98a6f6ec4efbba98d549af80f226 .positive-True {color: #E74C3C}
# #bigchartcbfd98a6f6ec4efbba98d549af80f226 .positive-False {color: #24BB85}
# #bigchartcbfd98a6f6ec4efbba98d549af80f226 .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchartcbfd98a6f6ec4efbba98d549af80f226 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchartcbfd98a6f6ec4efbba98d549af80f226 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchartcbfd98a6f6ec4efbba98d549af80f226 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchartcbfd98a6f6ec4efbba98d549af80f226 .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchartcbfd98a6f6ec4efbba98d549af80f226 .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchartcbfd98a6f6ec4efbba98d549af80f226 ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchartcbfd98a6f6ec4efbba98d549af80f226 ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchartcbfd98a6f6ec4efbba98d549af80f226><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-True">2.05%</span></li><li><span class=name>年化收益率</span><span class="value positive-True">66.7%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-True">1.18%</span></li><li><span class=name>阿尔法</span><span class="value positive-True">0.4</span></li><li><span class=name>贝塔</span><span class=value>0.61</span></li><li><span class=name>夏普比率</span><span class="value positive-True">2.2</span></li><li><span class=name>胜率</span><span class=value>0.25</span></li><li><span class=name>盈亏比</span><span class=value>2.88</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">23.03</span></li><li><span class=name>最大回撤</span><span class="value positive-True">2.12</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=318b1cbd66df4abfb4cb915cd2eb4800></div><script>require([`echarts`,`walden`],(a=>{let J=3.09,aq=5,I=0.41,a1=`\u7b56\u7565\u6536\u76ca\u7387`,al=`stroke`,E=2.45,a7=`2026-02-05`,a8=`2026-02-06`,H=2.47,p=`318b1cbd66df4abfb4cb915cd2eb4800`,x=3.33,A=1.18,af=10,O=2.73,aF=`mousemove|click`,aO=`#fff`,aD=`auto`,au=`circle`,aw=`#ccc`,R=88.54,aE=7,aJ=`filter`,aP=`\u6570\u636e\u89c6\u56fe`,F=2.57,aj=`solid`,ap=`\u4ed3\u4f4d`,B=2.01,T=89.49,az=`#2f4554`,w=3.45,ab=`2026-02-11`,r=1.62,ai=1,a5=`2026-02-03`,S=88.46,a2=4,a0=`line`,C=1.4,ar=25,X=100,K=4.53,U=87.6,M=2.61,a6=`2026-02-04`,aB=15,aN=`blank`,z=0,u=4.26,aH=`{value}%`,D=0.82,ag=`column`,_=`cubicOut`,a4=`2026-02-02`,a3=`samesign`,ad=`2026-02-13`,ah=2,q=null,aC=800,ax=`end`,aI=`horizontal`,$=300,aa=`2026-02-10`,aK=`all`,Q=87.03,aA=`#aaa`,an=`\u57fa\u51c6\u6536\u76ca\u7387`,t=3.44,ac=`2026-02-12`,ay=`{current}/{total}`,P=1.65,v=3.76,N=2.38,Y=2000,ae=8,s=0.06,aG=`#88888800`,av=`transparent`,aL=`10%`,am=2.5,G=2.34,aM=`8%`,W=87.25,Z=1000,y=2.49,ao=`\u76f8\u5bf9\u6536\u76ca\u7387`,L=4.63,a9=`2026-02-09`,V=88.45,ak=`#E74C3C`,at=14;var b=a.init(document.getElementById(p),`walden`,{renderer:`canvas`});var c=q;var d=q;var e=[-r,-s,t,u,v,w,x,w,y];var f=[z,A,B,C,D,E,F,G,H];var g=[z,I,J,K,L,M,N,O,P];var h=[Q,R,S,T,U,V,z,W,Q];var i=[];var j=[];var k=[];var l=[];var m=a.init(document.getElementById(p));m.on(`datazoom`,(a=>{var b=m.getOption();var c=b.dataZoom[z];var d=c.startValue;var g=c.endValue;for(var l=d;l<e.length;l++){i[l]=(e[l]- e[d])/(X+ e[d]);i[l]=i[l]*X;j[l]=(f[l]- f[d])/(X+ f[d]);j[l]=j[l]*X;
# [2026-02-19 12:59:28] [info     ] bigtrader.v34 运行完成 [0.627s].
