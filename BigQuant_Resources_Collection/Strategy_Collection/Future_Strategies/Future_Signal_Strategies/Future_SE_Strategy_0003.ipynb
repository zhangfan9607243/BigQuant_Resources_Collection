# %% [markdown]
# # Future Strategy - Signal Event 0003 - Indicator Timing Strategy

# %% [markdown]
# ## 1. Import Library

# %%
import dai
import random
import pandas as pd

# %% [markdown]
# ## 2. Prepare Strategy Data

# %%
sd = '2023-01-01'
ed = '2026-02-13'

# %%
instrument_list = ['AP8888.CZC', 'PR8888.CZC', 'jm8888.DCE']

# %%
sql_strategy =  f"""
SELECT
    date,
    instrument,
    m_ta_macd_dea(close) AS DEA,
    m_ta_macd_dif(close) AS DIF,
    IF(DIF > DEA AND m_lag(DIF, 1) < m_lag(DEA, 1), 1, 0) AS signal_long,
    IF(DIF < DEA AND m_lag(DIF, 1) > m_lag(DEA, 1), 1, 0) AS signal_short,
FROM cn_future_bar1d
"""

# %%
sql_trade = f"""
WITH 
data_signal AS (
    {sql_strategy}
)
SELECT
    date,
    instrument,
    signal_long,
    signal_short,
FROM data_signal
WHERE (signal_long = 1 OR signal_short = 1)
AND instrument IN {str(tuple(instrument_list))}
ORDER BY date, instrument
"""

# %%
df = dai.query(sql_trade, filters={"date":[sd, ed]}).df()
df
# Out:
#           date  instrument  signal_long  signal_short
# 0   2023-03-03  AP8888.CZC            0             1
# 1   2023-03-09  jm8888.DCE            0             1
# 2   2023-04-17  AP8888.CZC            1             0
# 3   2023-05-12  jm8888.DCE            1             0
# 4   2023-05-16  AP8888.CZC            0             1
# ..         ...         ...          ...           ...
# 138 2026-01-22  PR8888.CZC            1             0
# 139 2026-02-02  PR8888.CZC            0             1
# 140 2026-02-04  jm8888.DCE            1             0
# 141 2026-02-06  jm8888.DCE            0             1
# 142 2026-02-12  AP8888.CZC            1             0
#
# [143 rows x 4 columns]

# %% [markdown]
# ## 3. Backtest Strategy

# %%
from bigmodule import M

def BigTrader_Initialize(context):
    from bigtrader.finance.commission import PerOrder
    context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))
    context.holding_days = 3

def BigTrader_Before_Trading(context, data):
    pass

def BigTrader_Handle_Tick(context, tick):
    pass

def BigTrader_Handle_Data(context, data):

    df_now = context.data[context.data["date"] == data.current_dt.strftime("%Y-%m-%d")]
    
    from bigtrader.constant import OrderType
    from bigtrader.constant import Direction

    instruments_hold  = set(context.get_account_positions().keys())

    for ins in instruments_hold:
        position_long  = context.get_position(ins, Direction.LONG)
        position_short = context.get_position(ins, Direction.SHORT)
        price = data.current(ins,"open")
        if (position_long.current_qty  != 0):
            context.sell_close(ins, position_long.avail_qty, price, order_type=OrderType.MARKET)
        if (position_short.current_qty != 0):
            context.buy_close(ins, position_short.avail_qty, price, order_type=OrderType.MARKET)

    if len(df_now) == 0:
        return

    instruments_long  = set(df_now[df_now["signal_long"]  == 1]["instrument"])
    instruments_short = set(df_now[df_now["signal_short"] == 1]["instrument"])

    for ins in instruments_long:
        price = data.current(ins, "open")
        volume = 1
        context.buy_open(ins, volume, price, order_type=OrderType.MARKET)
    
    for ins in instruments_short:
        price = data.current(ins, "open")
        volume = 1
        context.sell_open(ins, volume, price, order_type=OrderType.MARKET)

def BigTrader_Handle_Trade(context, trade):
    pass

def BigTrader_Handle_Order(context, order):
    pass

def BigTrader_After_Trading(context, data):
    pass

BigTrader = M.bigtrader.v34(
    
    data = df,
    
    start_date = """""",
    end_date   = """""",
    
    initialize           = BigTrader_Initialize,
    before_trading_start = BigTrader_Before_Trading,
    handle_tick          = BigTrader_Handle_Tick,
    handle_data          = BigTrader_Handle_Data,
    handle_trade         = BigTrader_Handle_Trade,
    handle_order         = BigTrader_Handle_Order,
    after_trading        = BigTrader_After_Trading,
    
    capital_base = 10000 + random.uniform(0, 10),
    frequency="""daily""",
    product_type="""期货""",
    rebalance_period_type="""交易日""",
    rebalance_period_days="""1""",
    rebalance_period_roll_forward=True,
    backtest_engine_mode="""标准模式""",
    before_start_days=0,
    volume_limit=1,
    order_price_field_buy="""open""",
    order_price_field_sell="""open""",
    benchmark="""沪深300指数""",
    
    plot_charts=True,
    debug=False,
    backtest_only=False,
    m_name="""BigTrader"""
)
# Out:
# [2026-02-26 21:05:45] [info     ] bigtrader.v34 开始运行 ..
# [2026-02-26 21:05:45] [info     ] 2023-03-03, 2026-02-12, , future, instruments=3
# [2026-02-26 21:05:45] [info     ] bigtrader module V2.2.0
# [2026-02-26 21:05:45] [info     ] bigtrader engine v0.1.0.post9+g7a244b6 2026-02-10
# [2026-02-26 21:05:46] [info     ] backtest done, raw_perf_ds:dai.DataSource("_4617664a57d946fca4a09588fe5a6e19")
# <style>#bigchartf46508d8be7742258572cfe39e0a3f69 .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigchartf46508d8be7742258572cfe39e0a3f69 .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigchartf46508d8be7742258572cfe39e0a3f69 .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigchartf46508d8be7742258572cfe39e0a3f69 .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigchartf46508d8be7742258572cfe39e0a3f69  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigchartf46508d8be7742258572cfe39e0a3f69 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigchartf46508d8be7742258572cfe39e0a3f69 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigchartf46508d8be7742258572cfe39e0a3f69><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigchartaac4bdb1346f4574b8e4ce38f9d174a3')>收益概况</button><button class=tablinks onclick=showChart('bigchartf6ea9c2f8dc843f09f40ac750b6fc86d')>交易详情</button><button class=tablinks onclick=showChart('bigchart3612b81bcfd8450fb950bb13bfa40399')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchart9e0735a30f1a42eab802056440c2e4e9')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigchartaac4bdb1346f4574b8e4ce38f9d174a3><style>#bigchart0c3f45f663254b41b7e3c1be150ae7ab .value {color: #E74C3C}
# #bigchart0c3f45f663254b41b7e3c1be150ae7ab .positive-True {color: #E74C3C}
# #bigchart0c3f45f663254b41b7e3c1be150ae7ab .positive-False {color: #24BB85}
# #bigchart0c3f45f663254b41b7e3c1be150ae7ab .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchart0c3f45f663254b41b7e3c1be150ae7ab .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchart0c3f45f663254b41b7e3c1be150ae7ab .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchart0c3f45f663254b41b7e3c1be150ae7ab .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchart0c3f45f663254b41b7e3c1be150ae7ab .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchart0c3f45f663254b41b7e3c1be150ae7ab .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchart0c3f45f663254b41b7e3c1be150ae7ab ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchart0c3f45f663254b41b7e3c1be150ae7ab ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchart0c3f45f663254b41b7e3c1be150ae7ab><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-True">95.67%</span></li><li><span class=name>年化收益率</span><span class="value positive-True">26.57%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-True">14.26%</span></li><li><span class=name>阿尔法</span><span class="value positive-True">0.37</span></li><li><span class=name>贝塔</span><span class=value>0.15</span></li><li><span class=name>夏普比率</span><span class="value positive-True">0.65</span></li><li><span class=name>胜率</span><span class=value>0.49</span></li><li><span class=name>盈亏比</span><span class=value>1.48</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">48.39</span></li><li><span class=name>最大回撤</span><span class="value positive-True">57.9</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=74309ffc9d2643049dbfbe61b5f2bad8></div><script>require([`echarts`,`walden`],(a=>{let jQ=12.09,xb=`2023-11-29`,FM=5,wX=`2023-11-07`,zX=`2024-08-20`,ao=95.31,Cg=`2025-04-07`,c7=6.38,zd=`2024-06-17`,dF=19.28,nZ=45.73,u6=34.86,DV=`2025-09-05`,F5=`2025-12-30`,AB=`2024-10-28`,uL=`2023-04-10`,mC=25.82,fd=14.39,zA=`2024-07-18`,lv=28.73,u8=33.49,m1=22.99,pO=53.42,r9=43.37,yG=`2024-04-23`,DM=`2025-08-25`,cr=7.56,sB=54.93,zh=`2024-06-21`,bi=0.46,CA=`2025-05-08`,pn=52.62,gl=4.18,ln=25.74,d0=12.59,aY=3.96,hg=5.56,o3=45.26,kP=4.53,oO=41.92,t_=35.3,jO=12.32,zl=`2024-06-27`,wR=`2023-10-30`,hv=2.97,na=26.35,st=24.16,d2=15.01,ju=11.08,aZ=2.95,k_=5.93,mw=18.04,ok=44.99,BK=`2025-02-17`,vo=`2023-06-09`,cc=5.41,wd=`2023-08-25`,vR=`2023-07-24`,k$=5.16,bB=4.13,FW=800,cm=3.95,cD=8.21,uN=`2023-04-12`,mP=18.15,fo=15.95,uF=`2023-03-30`,G0=`horizontal`,Fx=`2026-02-10`,oj=44.93,vG=`2023-07-07`,yO=`2024-05-08`,Dt=`2025-07-29`,un=`2023-03-06`,nt=46.3,ov=44.51,sg=10.34,DR=`2025-09-01`,ps=54.07,wI=`2023-10-17`,AP=`2024-11-15`,lT=24.13,td=73.62,Eh=`2025-10-17`,lA=27.21,t=7.53,hZ=5.63,Do=`2025-07-22`,mz=18.14,B7=`2024-12-13`,dC=18.85,vu=`2023-06-19`,Aq=`2024-10-11`,E2=`2025-09-18`,w7=`2023-08-17`,z=0.74,uf=2000,CC=`2025-05-12`,x=9.47,cy=10.2,r3=44.46,pJ=52.73,e5=22.16,i5=6.74,CK=`2025-05-22`,hX=5.85,q8=51.27,zP=`2024-08-08`,C2=`2025-03-17`,hC=5.88,yR=`2024-05-13`,T=36.85,dh=13.34,h7=7.99,bj=0.76,xE=`2024-01-10`,eX=10.96,ol=45.34,J=26.95,Ak=`2024-09-26`,wy=`2023-09-25`,e_=10.8,Cb=`2025-03-28`,xc=`2023-11-30`,Af=`2024-09-19`,aV=1.98,gE=6.41,qN=51.37,uk=`\u7b56
# [2026-02-26 21:05:47] [info     ] bigtrader.v34 运行完成 [1.918s].
