# %% [markdown]
# # Future Strategy - Signal Event 0001 - Indicator Timing Strategy

# %% [markdown]
# ## 1. Import Library

# %%
import dai
import random
import pandas as pd

# %% [markdown]
# ## 2. Prepare Strategy Data

# %%
sd = '2023-01-01'
ed = '2026-02-13'

# %%
instrument_list = ['AP8888.CZC', 'PR8888.CZC', 'jm8888.DCE']

# %%
sql_strategy =  f"""
SELECT
    date,
    instrument,
    m_avg(close, 5) AS ma_short,
    m_avg(close, 20) AS ma_long,
    IF(ma_short > ma_long AND m_lag(ma_short, 1) < m_lag(ma_long, 1), 1, 0) AS signal_long,
    IF(ma_short < ma_long AND m_lag(ma_short, 1) > m_lag(ma_long, 1), 1, 0) AS signal_short,
FROM cn_future_bar1d
"""

# %%
sql_trade = f"""
WITH 
data_signal AS (
    {sql_strategy}
)
SELECT
    date,
    instrument,
    signal_long,
    signal_short,
FROM data_signal
WHERE (signal_long = 1 OR signal_short = 1)
AND instrument IN {str(tuple(instrument_list))}
ORDER BY date, instrument
"""

# %%
df = dai.query(sql_trade, filters={"date":[sd, ed]}).df()
df
# Out:
#           date  instrument  signal_long  signal_short
# 0   2023-02-10  AP8888.CZC            0             1
# 1   2023-02-16  AP8888.CZC            1             0
# 2   2023-02-20  jm8888.DCE            1             0
# 3   2023-03-13  AP8888.CZC            0             1
# 4   2023-03-15  jm8888.DCE            0             1
# ..         ...         ...          ...           ...
# 110 2026-01-22  jm8888.DCE            0             1
# 111 2026-02-04  jm8888.DCE            1             0
# 112 2026-02-05  PR8888.CZC            0             1
# 113 2026-02-10  AP8888.CZC            1             0
# 114 2026-02-11  jm8888.DCE            0             1
#
# [115 rows x 4 columns]

# %% [markdown]
# ## 3. Backtest Strategy

# %%
from bigmodule import M

def BigTrader_Initialize(context):
    from bigtrader.finance.commission import PerOrder
    context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))
    context.holding_days = 3

def BigTrader_Before_Trading(context, data):
    pass

def BigTrader_Handle_Tick(context, tick):
    pass

def BigTrader_Handle_Data(context, data):

    df_now = context.data[context.data["date"] == data.current_dt.strftime("%Y-%m-%d")]
    
    from bigtrader.constant import OrderType
    from bigtrader.constant import Direction

    instruments_hold  = set(context.get_account_positions().keys())

    for ins in instruments_hold:
        position_long  = context.get_position(ins, Direction.LONG)
        position_short = context.get_position(ins, Direction.SHORT)
        price = data.current(ins,"open")
        if (position_long.current_qty  != 0):
            context.sell_close(ins, position_long.avail_qty, price, order_type=OrderType.MARKET)
        if (position_short.current_qty != 0):
            context.buy_close(ins, position_short.avail_qty, price, order_type=OrderType.MARKET)

    if len(df_now) == 0:
        return

    instruments_long  = set(df_now[df_now["signal_long"]  == 1]["instrument"])
    instruments_short = set(df_now[df_now["signal_short"] == 1]["instrument"])

    for ins in instruments_long:
        price = data.current(ins, "open")
        volume = 1
        context.buy_open(ins, volume, price, order_type=OrderType.MARKET)
    
    for ins in instruments_short:
        price = data.current(ins, "open")
        volume = 1
        context.sell_open(ins, volume, price, order_type=OrderType.MARKET)

def BigTrader_Handle_Trade(context, trade):
    pass

def BigTrader_Handle_Order(context, order):
    pass

def BigTrader_After_Trading(context, data):
    pass

BigTrader = M.bigtrader.v34(
    
    data = df,
    
    start_date = """""",
    end_date   = """""",
    
    initialize           = BigTrader_Initialize,
    before_trading_start = BigTrader_Before_Trading,
    handle_tick          = BigTrader_Handle_Tick,
    handle_data          = BigTrader_Handle_Data,
    handle_trade         = BigTrader_Handle_Trade,
    handle_order         = BigTrader_Handle_Order,
    after_trading        = BigTrader_After_Trading,
    
    capital_base = 10000 + random.uniform(0, 10),
    frequency="""daily""",
    product_type="""期货""",
    rebalance_period_type="""交易日""",
    rebalance_period_days="""1""",
    rebalance_period_roll_forward=True,
    backtest_engine_mode="""标准模式""",
    before_start_days=0,
    volume_limit=1,
    order_price_field_buy="""open""",
    order_price_field_sell="""open""",
    benchmark="""沪深300指数""",
    
    plot_charts=True,
    debug=False,
    backtest_only=False,
    m_name="""BigTrader"""
)
# Out:
# [2026-02-26 20:58:38] [info     ] bigtrader.v34 开始运行 ..
# [2026-02-26 20:58:38] [info     ] 2023-02-10, 2026-02-11, , future, instruments=3
# [2026-02-26 20:58:38] [info     ] bigtrader module V2.2.0
# [2026-02-26 20:58:38] [info     ] bigtrader engine v0.1.0.post9+g7a244b6 2026-02-10
# [2026-02-26 20:58:39] [info     ] backtest done, raw_perf_ds:dai.DataSource("_127ee66ce3b9452f9a298f79ad87ee5a")
# <style>#bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigchart1dfca7e20d0e4058a1f0c0054e36984d  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigchart1dfca7e20d0e4058a1f0c0054e36984d .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigchart1dfca7e20d0e4058a1f0c0054e36984d .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigchart1dfca7e20d0e4058a1f0c0054e36984d><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigchartd7c1979c76e540538fb99207e8065777')>收益概况</button><button class=tablinks onclick=showChart('bigchart806984ca698741d1a37330099d08d21b')>交易详情</button><button class=tablinks onclick=showChart('bigcharteb15800fd09c483abf0fba789ff07ed4')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchartfcf3a61af2314b75a0b722c3e1751e9e')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigchartd7c1979c76e540538fb99207e8065777><style>#bigchartb589595455fd47eb99f8e984c90a5003 .value {color: #E74C3C}
# #bigchartb589595455fd47eb99f8e984c90a5003 .positive-True {color: #E74C3C}
# #bigchartb589595455fd47eb99f8e984c90a5003 .positive-False {color: #24BB85}
# #bigchartb589595455fd47eb99f8e984c90a5003 .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchartb589595455fd47eb99f8e984c90a5003 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchartb589595455fd47eb99f8e984c90a5003 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchartb589595455fd47eb99f8e984c90a5003 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchartb589595455fd47eb99f8e984c90a5003 .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchartb589595455fd47eb99f8e984c90a5003 .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchartb589595455fd47eb99f8e984c90a5003 ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchartb589595455fd47eb99f8e984c90a5003 ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchartb589595455fd47eb99f8e984c90a5003><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-True">73.48%</span></li><li><span class=name>年化收益率</span><span class="value positive-True">20.88%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-True">14.79%</span></li><li><span class=name>阿尔法</span><span class="value positive-True">0.33</span></li><li><span class=name>贝塔</span><span class=value>-0.22</span></li><li><span class=name>夏普比率</span><span class="value positive-True">0.56</span></li><li><span class=name>胜率</span><span class=value>0.46</span></li><li><span class=name>盈亏比</span><span class=value>1.13</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">48.93</span></li><li><span class=name>最大回撤</span><span class="value positive-True">65.04</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=7b5b40081ff349fabe91673bcf1b6e07></div><script>require([`echarts`,`walden`],(a=>{let qx=194.85,Bs=`2023-11-29`,aE=132.13,jb=5,Bc=`2023-11-07`,HQ=`2025-08-06`,eI=8.95,Ec=`2024-08-20`,c9=49.72,d3=0.22,Gx=`2025-04-07`,m0=13.74,b0=126.52,dC=6.38,dJ=4.4,Du=`2024-06-17`,m8=34.43,ml=45.73,sD=120.54,q8=189.07,Ia=`2025-09-05`,Jm=`2025-12-30`,ES=`2024-10-28`,z0=`2023-04-10`,DR=`2024-07-18`,uB=20.36,xg=33.49,g9=15.02,wJ=30.81,wN=54.84,V=151.18,hU=20.28,I1=`2025-08-25`,lO=15.94,CX=`2024-04-23`,j1=7.56,w4=11.03,hG=18.8,qz=194.36,p5=259.57,Dy=`2024-06-21`,mf=34.2,GR=`2025-05-08`,pg=206.45,jw=4.18,wm=43.72,gi=12.59,kn=3.96,x3=24.79,xh=32.33,oy=175.64,qp=203.92,pn=201.19,mJ=63.77,DC=`2024-06-27`,oo=189.02,n3=83.68,B6=`2023-10-30`,cn=70.76,vx=5.93,iL=1.89,F$=`2025-02-17`,zF=`2023-06-09`,ee=5.41,wM=50.12,Au=`2023-08-25`,pi=204.93,A6=`2023-07-24`,kd=5.16,K9=800,jo=3.95,de=1.88,z2=`2023-04-12`,yW=`2023-03-30`,eY=15.08,Kf=`horizontal`,df=1.85,fU=20.37,JO=`2026-02-10`,f3=13.45,d7=0.44,zX=`2023-07-07`,D3=`2024-05-08`,HK=`2025-07-29`,yE=`2023-03-06`,bI=46.3,lv=10.34,I6=`2025-09-01`,F4=`2024-11-15`,r4=204.79,AZ=`2023-10-17`,lx=12.55,bz=31.77,fK=18.93,gD=14.61,ry=171.09,Iy=`2025-10-17`,nk=91.82,j6=7.53,je=4.9,kg=5.63,b8=119.34,rb=167.36,sw=118.41,Fo=`2024-12-13`,HF=`2025-07-22`,zL=`2023-06-19`,EH=`2024-10-11`,Ij=`2025-09-18`,Ao=`2023-08-17`,yh=2000,fX=18.59,GT=`2025-05-12`,ci=84.75,gJ=10.92,cc=35.55,qT=197.89,qo=214.71,j4=6.74,G$=`2025-05-22`,dx=6.63,vw=5.85,E4=`2024-08-08`,su=104.73,Gj=`2025-03-17`,dH=5.88,kT=8.8,sg=121.59,D6=`2024-05-13`,lE=12.
# [2026-02-26 20:58:40] [info     ] bigtrader.v34 运行完成 [1.934s].
