# %% [markdown]
# # Stock & Convertible Bond Arbitrage 0001

# %% [markdown]
# ## 1. Import Library

# %%
import dai
import random
import pandas as pd

# %% [markdown]
# ## 2. Prepare Strategy Data

# %%
sd = '2024-12-31'
ed = '2026-02-13'

# %%
sql = """
SELECT
    date,
    instrument,
    stock_code,
    1.2 * c_normalize(pure_debt_value) - 1.0 * c_normalize(transfer_value) - 0.5 * c_normalize(conversion_premium_rate) AS score,
    IF(score <  1.0 AND m_lag(score, 1) >  1.0, 1, 0) AS signal_stock,
    IF(score > -1.0 AND m_lag(score, 1) < -1.0, 1, 0) AS signal_cbond,
FROM cn_cbond_analyze_metric JOIN cn_cbond_basic_info USING (instrument)
QUALIFY (signal_stock = 1 OR signal_cbond = 1)
ORDER BY date
"""

# %%
df_strategy = dai.query(sql, filters={"date":[sd, ed]}).df()
df_strategy
# Out:
#           date instrument stock_code     score  signal_stock  signal_cbond
# 0   2025-01-02  113033.SH  601366.SH  0.998059             1             0
# 1   2025-01-02  113584.SH  603708.SH  0.985637             1             0
# 2   2025-01-02  118050.SH  688239.SH -0.967093             0             1
# 3   2025-01-02  113563.SH  603368.SH  0.996483             1             0
# 4   2025-01-02  113616.SH  603501.SH  0.992396             1             0
# ..         ...        ...        ...       ...           ...           ...
# 854 2026-02-11  113650.SH  603916.SH  0.979124             1             0
# 855 2026-02-11  123182.SZ  300900.SZ -0.888899             0             1
# 856 2026-02-12  118044.SH  688398.SH -0.992344             0             1
# 857 2026-02-12  123221.SZ  301188.SZ -0.464083             0             1
# 858 2026-02-13  123131.SZ  300738.SZ -0.996274             0             1
#
# [859 rows x 6 columns]

# %% [markdown]
# ## 3. Backtest Strategy

# %%
from bigmodule import M

def BigTrader_Initialize(context):
    from bigtrader.finance.commission import PerOrder
    context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))
    context.holding_days = 3

def BigTrader_Before_Trading(context, data):
    pass

def BigTrader_Handle_Tick(context, tick):
    pass

def BigTrader_Handle_Data(context, data):

    df_now = context.data[context.data["date"] == data.current_dt.strftime("%Y-%m-%d")]

    if len(df_now) == 0:
        return
    
    instruments_hold = set(context.get_account_positions().keys())

    for i, x in df_now.iterrows():
        
        if x.signal_stock == 1:
            if x.instrument in instruments_hold:
                context.order(x.instrument, 0)
            context.order(x.stock_code, 100)
        
        if x.signal_cbond == 1:
            if x.stock_code in instruments_hold:
                context.order(x.stock_code, 0)
            context.order(x.instrument, 100)
    
    for instrument in instruments_hold:
        if (data.current_dt - context.get_position(instrument).last_sale_date).days >= context.holding_days:
            context.order_target_percent(instrument, 0)

def BigTrader_Handle_Trade(context, trade):
    pass

def BigTrader_Handle_Order(context, order):
    pass

def BigTrader_After_Trading(context, data):
    pass

BigTrader = M.bigtrader.v34(
    
    data = df_strategy,
    
    start_date = """""",
    end_date   = """""",
    
    initialize           = BigTrader_Initialize,
    before_trading_start = BigTrader_Before_Trading,
    handle_tick          = BigTrader_Handle_Tick,
    handle_data          = BigTrader_Handle_Data,
    handle_trade         = BigTrader_Handle_Trade,
    handle_order         = BigTrader_Handle_Order,
    after_trading        = BigTrader_After_Trading,
    
    capital_base = 1000000 + random.uniform(0, 10),
    frequency="""daily""",
    product_type="""自动""",
    rebalance_period_type="""交易日""",
    rebalance_period_days="""1""",
    rebalance_period_roll_forward=True,
    backtest_engine_mode="""标准模式""",
    before_start_days=0,
    volume_limit=1,
    order_price_field_buy="""open""",
    order_price_field_sell="""open""",
    benchmark="""沪深300指数""",
    
    plot_charts=True,
    debug=False,
    backtest_only=False,
    m_name="""BigTrader"""
)
# Out:
# [2026-02-18 21:57:16] [info     ] bigtrader.v34 开始运行 ..
# [2026-02-18 21:57:16] [info     ] 2025-01-02, 2026-02-13, , , instruments=300
# [2026-02-18 21:57:16] [info     ] bigtrader module V2.2.0
# [2026-02-18 21:57:16] [info     ] bigtrader engine v0.1.0.post9+g7a244b6 2026-02-10
# [2026-02-18 21:57:36] [info     ] backtest done, raw_perf_ds:dai.DataSource("_24ce77610c0443cda3e3b4ca372589b2")
# <style>#bigchart68f051ac8c034c6da26d52f1d1682d92 .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigchart68f051ac8c034c6da26d52f1d1682d92  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigchart68f051ac8c034c6da26d52f1d1682d92 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigchart68f051ac8c034c6da26d52f1d1682d92 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigchart68f051ac8c034c6da26d52f1d1682d92><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigchart461ddb3641cb4b3383c5ff783f764361')>收益概况</button><button class=tablinks onclick=showChart('bigchartde55fdd958d746dfaa912f12e69cff84')>交易详情</button><button class=tablinks onclick=showChart('bigchart7091dc03dae449398e8458ae9891332c')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchart92cbeae2c37f4f6ea80466384e8d52dc')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigchart461ddb3641cb4b3383c5ff783f764361><style>#bigchart9ec37e20423c4e23a52131515b764d87 .value {color: #E74C3C}
# #bigchart9ec37e20423c4e23a52131515b764d87 .positive-True {color: #E74C3C}
# #bigchart9ec37e20423c4e23a52131515b764d87 .positive-False {color: #24BB85}
# #bigchart9ec37e20423c4e23a52131515b764d87 .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchart9ec37e20423c4e23a52131515b764d87 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchart9ec37e20423c4e23a52131515b764d87 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchart9ec37e20423c4e23a52131515b764d87 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchart9ec37e20423c4e23a52131515b764d87 .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchart9ec37e20423c4e23a52131515b764d87 .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchart9ec37e20423c4e23a52131515b764d87 ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchart9ec37e20423c4e23a52131515b764d87 ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchart9ec37e20423c4e23a52131515b764d87><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-False">-3.53%</span></li><li><span class=name>年化收益率</span><span class="value positive-False">-3.26%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-True">21.99%</span></li><li><span class=name>阿尔法</span><span class="value positive-False">-0.07</span></li><li><span class=name>贝塔</span><span class=value>0.08</span></li><li><span class=name>夏普比率</span><span class="value positive-False">-1.98</span></li><li><span class=name>胜率</span><span class=value>0.45</span></li><li><span class=name>盈亏比</span><span class=value>0.83</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">3.15</span></li><li><span class=name>最大回撤</span><span class="value positive-True">3.89</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=3a11b9edbe9244dca0fd8d36f366a65d></div><script>require([`echarts`,`walden`],(a=>{let gY=19.44,jx=5,bn=2.7,cn=1.78,lN=`2025-03-25`,D=0.22,B=0.02,dF=16.84,lV=`2025-04-07`,f5=23.09,bq=2.48,oL=`2025-12-30`,ny=`2025-09-05`,bz=3.26,fH=3.58,kZ=`2025-01-02`,b9=1.7,hG=21.36,ba=2.02,eq=20.36,pD=`filter`,fA=4.92,pi=`solid`,fc=22.99,f6=23.21,kO=9.09,jS=15.94,np=`2025-08-25`,ey=18.49,jZ=15.6,t=0.09,oY=`2026-01-20`,g9=6.97,nw=`2025-09-03`,hJ=21.56,el=22.89,md=`2025-05-08`,h0=21.37,hP=23.65,gi=9.97,kd=4.1,jm=3.96,f_=2.79,f0=23.86,jT=17.87,jf=8.24,gf=8.65,iP=1.66,lI=`2025-03-18`,bV=2.97,g4=5.61,p7=`2026-02-04`,ck=3.91,ac=0.73,nY=`2025-10-21`,bG=2.95,cb=1.89,eV=25.03,ln=`2025-02-17`,lU=`2025-04-03`,a0=0.24,O=0.34,fd=22.25,pB=`{value}%`,b6=1.56,d7=5.16,px=800,cW=1.88,jG=18.92,v=0.11,pC=`horizontal`,ei=21.12,lr=`2025-02-21`,b_=1.85,fw=3.46,bQ=2.54,dL=16.75,a$=1.52,hH=21.43,am=0.44,iZ=9.59,n6=`2025-07-29`,b7=1.49,n9=`2025-08-01`,pb=`2026-02-10`,kJ=3.9,mQ=`2025-07-03`,nu=`2025-09-01`,bA=3.23,kn=5.55,nW=`2025-10-17`,jR=13.95,cu=4.9,jv=5.63,n1=`2025-07-22`,h3=18.85,fm=0.47,hw=20.4,nH=`2025-09-18`,oa=`2025-11-10`,hY=21.71,al=0.74,kR=2000,mf=`2025-05-12`,oV=`2026-01-15`,hL=22.56,$=0.61,a_=1.23,bv=2.36,gb=7.14,kL=22.16,mn=`2025-05-22`,j6=6.63,lH=`2025-03-17`,jB=10.27,ax=1.03,jj=7.99,fj=0.76,cJ=0.31,g7=6.44,iG=6.12,dV=17.84,dO=16.36,fL=2.07,lQ=`2025-03-28`,e$=24.37,kW=`\u7b56\u7565\u6536\u76ca\u7387`,w=0.13,cQ=2.45,pk=`stroke`,f8=24.43,ak=0.68,gd=7.51,eW=24.01,cN=2.27,ki=11.68,pI=`#fff`,M=0.25,dC=16.98,mM=`2025-06-27`,cA=6.05,ed=22.81,db=6.23,m
# [2026-02-18 21:57:36] [info     ] bigtrader.v34 运行完成 [20.939s].
