# %% [markdown]
# # Fund Strategy - Signal Event 0001

# %% [markdown]
# ## 1. Import Library

# %%
import dai
import random
import pandas as pd

# %% [markdown]
# ## 2. Prepare Strategy Data

# %%
sd = '2015-12-31'
ed = '2026-02-13'

# %%
instrument_list = ['510170.SH', '513520.SH', '513030.SH']

# %%
sql = f"""
SELECT
    date,
    instrument,
    m_avg(close, 10) AS ma_short,
    m_avg(close, 20) AS ma_long,
    IF(ma_short > ma_long AND m_lag(ma_short, 1) < m_lag(ma_long, 1), 1, 0) AS signal_buy,
    IF(ma_short < ma_long AND m_lag(ma_short, 1) > m_lag(ma_long, 1), 1, 0) AS signal_sell,
FROM cn_fund_bar1d
WHERE instrument IN {str(tuple(instrument_list))}
QUALIFY (signal_buy = 1 OR signal_sell = 1)
"""

# %%
df = dai.query(sql, filters = {"date":[sd, ed]}).df()
df
# Out:
#           date instrument  ma_short   ma_long  signal_buy  signal_sell
# 0   2016-03-08  513030.SH  0.826300  0.825500           1            0
# 1   2016-04-08  513030.SH  0.856500  0.856650           0            1
# 2   2016-04-20  513030.SH  0.862300  0.860700           1            0
# 3   2016-05-13  513030.SH  0.882400  0.884750           0            1
# 4   2016-06-01  513030.SH  0.879400  0.877250           1            0
# ..         ...        ...       ...       ...         ...          ...
# 321 2025-09-24  510170.SH  4.430741  4.437012           0            1
# 322 2025-10-09  510170.SH  4.485357  4.467556           1            0
# 323 2025-11-24  510170.SH  4.874543  4.881016           0            1
# 324 2025-12-11  510170.SH  4.801723  4.791002           1            0
# 325 2026-02-12  510170.SH  5.832946  5.868143           0            1
#
# [326 rows x 6 columns]

# %% [markdown]
# ## 3. Backtest Strategy

# %%
from bigmodule import M

def BigTrader_Initialize(context):
    from bigtrader.finance.commission import PerOrder
    context.set_commission(PerOrder(buy_cost=0.0003, sell_cost=0.0013, min_cost=5))
    context.holding_days = 3
    context.is_trade_by_weight = True
    context.weight = 1 / len(context.data['instrument'].unique())

def BigTrader_Before_Trading(context, data):
    pass

def BigTrader_Handle_Tick(context, tick):
    pass

def BigTrader_Handle_Data(context, data):

    df_now = context.data[context.data["date"] == data.current_dt.strftime("%Y-%m-%d")]

    if len(df_now) == 0:
        return

    instruments_buy  = set(df_now[df_now["signal_buy"]  == 1]["instrument"])
    instruments_sell = set(df_now[df_now["signal_sell"] == 1]["instrument"])
    instruments_hold = set(context.get_account_positions().keys())

    for instrument in instruments_buy - instruments_hold:
        if context.is_trade_by_weight:
            context.order_target_percent(instrument, context.weight)
        else:
            context.order(instrument, 100)
    
    for instrument in instruments_sell:
        context.order_target_percent(instrument, 0)

    for instrument in instruments_hold:
        if (data.current_dt - context.get_position(instrument).last_sale_date).days >= context.holding_days:
            context.order_target_percent(instrument, 0)

def BigTrader_Handle_Trade(context, trade):
    pass

def BigTrader_Handle_Order(context, order):
    pass

def BigTrader_After_Trading(context, data):
    pass

BigTrader = M.bigtrader.v34(
    
    data = df,
    
    start_date = """""",
    end_date   = """""",
    
    initialize           = BigTrader_Initialize,
    before_trading_start = BigTrader_Before_Trading,
    handle_tick          = BigTrader_Handle_Tick,
    handle_data          = BigTrader_Handle_Data,
    handle_trade         = BigTrader_Handle_Trade,
    handle_order         = BigTrader_Handle_Order,
    after_trading        = BigTrader_After_Trading,
    
    capital_base = 1000000 + random.uniform(0, 10),
    frequency="""daily""",
    product_type="""自动""",
    rebalance_period_type="""交易日""",
    rebalance_period_days="""1""",
    rebalance_period_roll_forward=True,
    backtest_engine_mode="""标准模式""",
    before_start_days=0,
    volume_limit=1,
    order_price_field_buy="""open""",
    order_price_field_sell="""open""",
    benchmark="""沪深300指数""",
    
    plot_charts=True,
    debug=False,
    backtest_only=False,
    m_name="""BigTrader"""
)
# Out:
# [2026-02-19 15:06:36] [info     ] bigtrader.v34 开始运行 ..
# [2026-02-19 15:06:37] [info     ] 2016-03-08, 2026-02-12, , , instruments=3
# [2026-02-19 15:06:37] [info     ] bigtrader module V2.2.0
# [2026-02-19 15:06:37] [info     ] bigtrader engine v0.1.0.post9+g7a244b6 2026-02-10
# [2026-02-19 15:06:39] [info     ] backtest done, raw_perf_ds:dai.DataSource("_2f947c505e6d4a82b7ed25938cba3e6a")
# <style>#bigcharta0579eb1fa2243859d55b6473749f064 .tab {
#             overflow: hidden;
#             margin-bottom: 10px;
#             border-bottom: 1px solid #8888882E;
#             display: flex;
#             align-items: center;
#         }
#         @media screen and (max-width: 768px) {
#             #bigcharta0579eb1fa2243859d55b6473749f064 .tab{
#                 justify-content: space-between;
#             }
#         }
#         @media screen and (min-width: 768px) {
#             #bigcharta0579eb1fa2243859d55b6473749f064 .tab{
#                 justify-content: flex-start;
#                 gap: 30px;
#             }
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064  .title{
#             margin: 0;
#             font-size: 1.2em;
#             padding: 10px 10px;
#             margin-bottom: 10px;
#             font-weight: bold;
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .tab button, .tab span.title {
#             background-color: inherit;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .tab span.title {
#             font-size: 1.3em;
#             padding: 8px 16px;
#             font-weight: bold;
#         }
#         .vscode-dark #bigcharta0579eb1fa2243859d55b6473749f064 .tab button{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .tab button:hover {
#             color: #E74C3C;
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .tab button.active {
#             color: #E74C3C;
#             border-bottom: 2px solid #e74c3c;
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .legend_div{
#             text-align: left;
#             width:120px;
#             color:#757A88;
#             font-size: 12px;
#         }
#         .vscode-dark #bigcharta0579eb1fa2243859d55b6473749f064  .legend_div{
#             color: rgba(255, 255, 255, 0.80);
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .legend_span{
#             border-radius: 100%;
#             display:inline-block;
#             width:6px;height:6px;
#             margin-right:5px;
#         }
#         #bigcharta0579eb1fa2243859d55b6473749f064 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid rgba(0, 0, 0, 0.10);
#             background: rgba(255, 255, 255, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(117, 122, 136, 0.15);
#             width:145px;
#             padding:20px 18px 20px 20px
#         }
#         .vscode-dark #bigcharta0579eb1fa2243859d55b6473749f064 .legend_bgc{
#             border-radius: 5px;
#             border: 1px solid #373737;
#             background-color: rgba(37, 37, 38, 0.80);
#             box-shadow: 0px 10px 24px 0px rgba(0, 0, 0, 0.19);
#         }</style><div style="width:100%; clear: both"class=chart-container id=bigcharta0579eb1fa2243859d55b6473749f064><div class=title>BigTrader(高性能回测&交易)</div><div class=tab><button class=tablinks onclick=showChart('bigchart6ed9597abfe44e46b2662cd0b0bc4a5d')>收益概况</button><button class=tablinks onclick=showChart('bigchartecb22a6bbc1941a4a4efc34db758eb20')>交易详情</button><button class=tablinks onclick=showChart('bigchartfe76f88acc634e94b44f0d182ff76afe')>每日持仓和收益</button><button class=tablinks onclick=showChart('bigchartd0ed98cf2ade466ab06e0cc20ccc9887')>输出日志</button></div><style></style><div style="width:100%; clear: both"class=chart-container id=bigchart6ed9597abfe44e46b2662cd0b0bc4a5d><style>#bigchart7a277d9f0cbb4603b29ce4e200213b79 .value {color: #E74C3C}
# #bigchart7a277d9f0cbb4603b29ce4e200213b79 .positive-True {color: #E74C3C}
# #bigchart7a277d9f0cbb4603b29ce4e200213b79 .positive-False {color: #24BB85}
# #bigchart7a277d9f0cbb4603b29ce4e200213b79 .bigtrader_performance_metrics {
#     display:grid;
#     padding-bottom:10px;
#     margin-bottom: 30px;
#     grid-template-columns: repeat(11, 1fr);
#     gap:10px
# }
# @media screen and (max-width: 768px) {
#     #bigchart7a277d9f0cbb4603b29ce4e200213b79 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(3, 1fr);
#     }
# }
# @media screen and (max-width: 992px) and (min-width:768px) {
#     #bigchart7a277d9f0cbb4603b29ce4e200213b79 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(4, 1fr);
#     }
# }
# @media screen and (max-width: 1200px) and (min-width:992px) {
#     #bigchart7a277d9f0cbb4603b29ce4e200213b79 .bigtrader_performance_metrics{
#         grid-template-columns: repeat(6, 1fr);
#     }
# }
# #bigchart7a277d9f0cbb4603b29ce4e200213b79 .bigtrader_performance_metrics li{
#     display: flex;
#     height: 42px;
#     flex-direction: column;
#     list-style-type: none;
#     text-align: center;
#     padding: 0 10px;
# }
# #bigchart7a277d9f0cbb4603b29ce4e200213b79 .bigtrader_performance_metrics .name {
#     color: #888888;
#     margin-top:15px;
#     margin-bottom:11px;
#     display: block;
#     height: 17px;
#     font-size: 13px ;
#     text-aligin: left;
# }
# .vscode-dark #bigchart7a277d9f0cbb4603b29ce4e200213b79 ul li .name{
#     color: rgba(255, 255, 255, 0.50);
# }
# #bigchart7a277d9f0cbb4603b29ce4e200213b79 ul .value {
#     display: inline-block;
#     height: auto;
#     font-style: normal ;
#     font-weight: 550 ;
#     line-height: normal;
#     font-size: 16px ;
# }</style><div style="width:100%; clear: both"class=chart-container id=bigchart7a277d9f0cbb4603b29ce4e200213b79><ul class=bigtrader_performance_metrics><li><span class=name>累计收益率</span><span class="value positive-True">8.61%</span></li><li><span class=name>年化收益率</span><span class="value positive-True">0.86%</span></li><li name=基准累计收益率><span class=name>基准收益率</span><span class="value positive-True">51.87%</span></li><li><span class=name>阿尔法</span><span class="value positive-False">-0.02</span></li><li><span class=name>贝塔</span><span class=value>0.09</span></li><li><span class=name>夏普比率</span><span class="value positive-False">-0.34</span></li><li><span class=name>胜率</span><span class=value>0.51</span></li><li><span class=name>盈亏比</span><span class=value>1.26</span></li><li name=年化收益波动率><span class=name>收益波动率</span><span class="value positive-True">5.62</span></li><li><span class=name>最大回撤</span><span class="value positive-True">15.82</span></li></ul></div><script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`,'walden':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/themes/walden`}})</script><div style="width:100%; height:500px;"id=5132469782284e479dd9b8f7a97bffa5></div><script>require([`echarts`,`walden`],(a=>{let amK=`2020-08-20`,aoF=`2021-02-25`,aqr=`2021-08-11`,jx=13.91,aby=`2017-09-08`,asi=`2022-02-11`,atk=`2022-05-23`,h2=8.95,ayh=`2023-09-05`,aFw=`2025-08-06`,ZN=19.6,uh=22.82,a3R=66.88,asL=`2022-03-24`,jf=16.1,iJ=18.11,SA=38.63,acy=`2017-12-14`,a7O=`2016-09-13`,ah8=`2019-03-05`,YP=24.91,amE=`2020-08-12`,aBa=`2024-06-17`,bC=2.48,zC=65.25,a9Q=`2017-03-31`,D$=34.86,alJ=`2020-05-19`,aFS=`2025-09-05`,aH2=`2025-12-30`,bL=3.26,Yk=25.76,aox=`2021-02-08`,aCy=`2024-10-28`,oO=19.92,alE=`2020-05-12`,aBx=`2024-07-18`,am3=`2020-06-18`,a6S=`2016-06-21`,ajL=`2019-11-08`,eE=7.79,oi=15.02,RA=30.81,a9G=`2017-03-17`,oJ=20.28,p3=22.99,hL=15.94,lY=7.56,abu=`2017-09-04`,ic=18.8,v_=19.78,a15=34.96,wC=32,NI=15.6,Bc=58.84,yN=79.23,Wc=42.49,aBe=`2024-06-21`,$f=34.2,WE=37.92,_6=36.1,mF=4.18,Uq=43.72,a5m=66.39,abE=`2017-09-18`,bz=2.79,a6k=`2016-04-29`,v0=24.79,vn=32.33,RS=28.85,alS=`2020-06-01`,x2=53.53,FX=26.71,a5v=37.49,Vy=41.92,aib=`2019-06-13`,aBi=`2024-06-27`,L2=46.06,a6M=`2016-06-13`,JU=23.3,aqO=`2021-09-13`,ayO=`2023-10-30`,Ij=15.01,OK=26.07,s9=5.93,iC=18.91,dh=1.46,DL=39.08,XP=30.76,$X=44.99,a38=66.96,aiR=`2019-08-12`,anH=`2020-11-23`,a7w=`2016-08-18`,aoY=`2021-03-24`,avE=`2022-12-26`,ae3=`2018-05-14`,IR=33.4,yV=76.14,yK=74.97,OZ=22.25,Rv=28.47,oq=18.03,cI=4.13,MA=5.16,Tt=41.08,_O=35.08,wr=28.14,axl=`2023-06-09`,aHM=800,awC=`2023-03-30`,NJ=15.95,_E=35.13,ac4=`2017-11-02`,zh=65.45,r$=13.45,R=0.44,V7=44.93,aAL=`2024-05-08`,cH=3.82,aFq=`2025-07-29`,xf=50.57,awk=`202
# [2026-02-19 15:06:40] [info     ] bigtrader.v34 运行完成 [3.849s].
