# %% [markdown]
# # Chinese Hong Kong Data - Stock Index Data (Including Acia-Pacific)

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM ap_stock_index_bar1d
WHERE date = '2026-01-05'
AND instrument = 'HSI.GI'
""").df()
# Out:
#         date instrument  name  pre_close      open     high      low  \
# 0 2026-01-05     HSI.GI  恒生指数   26338.47  26361.44  26445.5  26256.0
#
#       close     volume        amount  change  change_ratio
# 0  26347.24  163066850  2.834623e+11    8.77      0.000333
