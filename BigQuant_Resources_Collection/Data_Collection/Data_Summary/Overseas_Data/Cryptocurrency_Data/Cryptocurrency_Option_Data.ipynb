# %% [markdown]
# # Cryptocurrency Data - Option Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Cryptocurrency Option Price

# %%
dai.query("""
SELECT *
FROM cc_binance_option_bar1d
WHERE date = '2026-02-13'
AND instrument LIKE '%BTC-260215%'
""").df()
# Out:
#          date          instrument      open_time     close_time    open  \
# 0  2026-02-13  BTC-260215-60000-P  1770940800000  1771027199999    85.0
# 1  2026-02-13  BTC-260215-62000-C  1770940800000  1771027199999  4670.0
# 2  2026-02-13  BTC-260215-62000-P  1770940800000  1771027199999   105.0
# ..        ...                 ...            ...            ...     ...
# 20 2026-02-13  BTC-260215-71000-P  1770940800000  1771027199999  3950.0
# 21 2026-02-13  BTC-260215-72000-C  1770940800000  1771027199999    25.0
# 22 2026-02-13  BTC-260215-72000-P  1770940800000  1771027199999  4975.0
#
#       high     low   close  volume   amount  deal_number  buy_volume  \
# 0     90.0     5.0     5.0   41.93  2205.20           69       12.54
# 1   4670.0  4595.0  4595.0    0.02    92.65            2        0.01
# 2    125.0    15.0    15.0    8.18   595.20           27        3.05
# ..     ...     ...     ...     ...      ...          ...         ...
# ...

# %% [markdown]
# ## 2. Cryptocurrency Spot Market Exchange Info & Trading Rules

# %%
dai.query("""
SELECT *
FROM cc_binance_option_exchange_info
WHERE instrument LIKE '%BTC-260215%'
""").df()
# Out:
#             instrument    expiry_date  side  strike_price underlying  unit  \
# 0   BTC-260215-60000-C  1771142400000  CALL       60000.0    BTCUSDT   1.0
# 1   BTC-260215-60000-P  1771142400000   PUT       60000.0    BTCUSDT   1.0
# 2   BTC-260215-62000-C  1771142400000  CALL       62000.0    BTCUSDT   1.0
# ..                 ...            ...   ...           ...        ...   ...
# 21  BTC-260215-71000-P  1771142400000   PUT       71000.0    BTCUSDT   1.0
# 22  BTC-260215-72000-C  1771142400000  CALL       72000.0    BTCUSDT   1.0
# 23  BTC-260215-72000-P  1771142400000   PUT       72000.0    BTCUSDT   1.0
#
#     liquidation_fee_rate  min_qty  max_qty  initial_margin  \
# 0                 0.0019     0.01    200.0            0.15
# 1                 0.0019     0.01    200.0            0.15
# 2                 0.0019     0.01    200.0            0.15
# ..                   ...      ...      ...             ...
# 21                0.0019     0.01    200.0            0.15
# ...
