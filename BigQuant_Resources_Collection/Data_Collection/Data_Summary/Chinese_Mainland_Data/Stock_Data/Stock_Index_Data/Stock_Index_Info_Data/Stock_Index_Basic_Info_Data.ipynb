# %% [markdown]
# # Chinese (Mainland) Stock Index Data - Information Data - Basic Information

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_stock_index_info
WHERE instrument = '000300.SH'
""").df()
# Out:
#   instrument   name  base_time  base_point  list_date delist_date  \
# 0  000300.SH  沪深300 2004-12-31        1000 2005-04-08         NaT
#
#   weight_method publisher section
# 0      自由流通市值加权  中证指数有限公司  中证规模指数
