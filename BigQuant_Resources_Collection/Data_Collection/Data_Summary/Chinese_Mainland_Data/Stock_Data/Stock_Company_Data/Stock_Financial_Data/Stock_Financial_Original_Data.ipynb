# %% [markdown]
# # Chinese (Mainland) Stock Data - Financial Data - Original FS Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Financial Reports Change Data

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_changedate
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
""", full_db_scan=True).df()
# Out:
#   instrument report_date                                         changedate  \
# 0  600519.SH  2022-12-31  2023-03-31,2023-04-26,2023-08-03,2023-10-21,20...
# 1  600519.SH  2022-12-31                              2023-03-31,2024-04-03
# 2  600519.SH  2022-12-31                              2023-03-31,2024-04-03
#
#   statement_type
# 0  balance_sheet
# 1         income
# 2      cash_flow

# %% [markdown]
# ## 2. Financial Statements Data

# %% [markdown]
# ### 2.1 Balance Sheet

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_balance_general_pit
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  fs_quarter_index  change_type  \
# 0 2023-03-31  600519.SH  2022-12-31                 4            0
#
#    noncurr_liabilities_due_within_1y  noncurr_assets_due_within_1y  \
# 0                       1.093512e+08                  2.123601e+09
#
#    general_reserve  specific_reserve  specific_payables  \
# 0     1.061530e+09               NaN                NaN
#
#    fin_assets_purchased_under_resale  tradable_fin_liabilities  \
# 0                                NaN                       NaN
#
#    tradable_fin_assets  acting_trading_payables  underwriting_payables  \
# 0                  NaN                      NaN                    NaN
#
#    fin_assets_by_fair_value  fin_assets_by_amortized_cost  preference_shares  \
# 0                       NaN                           NaN                NaN
#
#    right_of_use_assets  insurance_contract_reserves  debt_investments  \
# 0         4.025515e+08                          NaN      3.806853e+08
#
#    preference_of_other_equity_instruments  other_debt_investments  \
# 0                                     NaN                     NaN
#
#    other_payables  other_payables_sum  other_receivables  \
# 0    4.543843e+09        4.543843e+09        31818622.84
#
#    other_receivables_sum  other_equity_instruments  other_equity_investments  \
# 0            31818622.84                       NaN                       NaN
#
#    other_current_liabilities  other_current_assets  balance_othcom_income  \
# 0               1.979273e+09          1.608437e+08           -10776907.33
#
#    other_noncurr_liabilities  other_noncurr_assets  other_noncurr_fin_assets  \
# 0                        NaN                   NaN                       NaN
#
#    fin_assets_sold_under_resale  loans_and_advances  \
# 0                           NaN        4.134744e+09
#
#    available_for_sale_fin_assets  contract_liabilities  contract_assets  \
# 0                            NaN          1.547192e+10              NaN
#
#    borrowing_from_central_bank  deposits_from_banks_and_fin_instiutions  \
# 0                          NaN                             1.287404e+10
#
#    goodwill  fixed_assets  fixed_assets_sum  fixed_assets_disposal  \
# 0       NaN  1.974262e+10      1.974262e+10                    NaN
#
#    construction_in_progress  construction_in_progress_sum  \
# 0              2.208330e+09                  2.208330e+09
#
#    balance_translation_diff_of_foreign_currency   inventories  share_capital  \
# 0                                           NaN  3.882437e+10   1.256198e+09
#
#    minority_interests  project_materials  treasury_shares  \
# 0        7.458016e+09                NaN              NaN
#
#    taxes_and_levies_payable  bonds_payable  reinsurance_payables  \
# 0              6.896555e+09            NaN                   NaN
#
#    interest_payable  fees_and_commissions_payable  shortterm_bonds_payable  \
# 0               NaN                           NaN                      NaN
#
#    notes_payable  notes_and_accounts_payable  employee_benefits_payable  \
# 0            NaN                2.408371e+09               4.782311e+09
#
#    dividends_payable  accounts_payable  premiums_receivable  \
# 0                NaN      2.408371e+09                  NaN
#
#    receivable_reinsurance_contract_reserve  reinsurance_receivables  \
# 0                                      NaN                      NaN
#
#    interest_receivable  receivables_financing  notes_receivable  \
# 0                  NaN                    NaN       105453212.0
#
#    notes_and_accounts_receivable  dividends_receivable  accounts_receivable  \
# 0                    126390356.0                   NaN           20937144.0
#
#    development_costs  total_equity_to_parent_shareholders  total_owner_equity  \
# 0        190536632.6                         1.975067e+11        2.049647e+11
#
#    investment_property  loans_from_banks_and_fin_institutions  \
# 0           5335046.99                                    NaN
#
#    loans_to_banks_and_fin_institutions  liabilities_held_for_sale  \
# 0                         1.161727e+11                        NaN
#
#    assets_held_for_sale  held_to_maturity_invesments  intangible_assets  \
# 0                   NaN                          NaN       7.083177e+09
#
#    undistributed_profit  perpetual_bonds  oil_and_gas_assets  \
# 0          1.613020e+11              NaN                 NaN
#
#    total_current_liabilities  totbal_diff_of_current_liabilities  \
# 0               4.906567e+10                                 NaN
#
#    spec_diff_of_current_liabilities  total_current_assets  \
# 0                               NaN          2.166114e+11
#
#    totbal_diff_of_current_assets  spec_diff_of_current_assets  \
# 0                            NaN                          NaN
#
#    productive_biological_assets  surplus_reserve  shortterm_borrowings  \
# 0                           NaN     3.252278e+10                   NaN
#
#    lease_liabilities  settlment_reserves  spec_diff_of_shareholders_equity  \
# 0       3.344479e+08                 NaN                               NaN
#
#    totbal_diff_of_shareholders_equity  derivatives_fin_liabilities  \
# 0                                 NaN                          NaN
#
#    derivatives_fin_assets  totbal_diff_of_liabilities_and_shareholder_equity  \
# 0                     NaN                                                0.0
#
#    spec_diff_of_liabilities_and_shareholder_equity  total_liabilities  \
# 0                                              0.0       4.940012e+10
#
#    total_liabilities_and_owner_equity  totbal_diff_of_total_liabilities  \
# 0                        2.543648e+11                               NaN
#
#    spec_diff_of_total_liabilities  moneytary_assets  \
# 0                             NaN      5.827432e+10
#
#    totbal_diff_of_total_assets  spec_diff_of_total_assets  total_assets  \
# 0                          NaN                        NaN  2.543648e+11
#
#    capital_reserves  deferred_tax_liabilities  deferred_tax_assets  \
# 0      1.374964e+09                       NaN         3.458931e+09
#
#    deferred_income_current_liabilities  deferred_income_noncurr_liabilities  \
# 0                                  NaN                                  NaN
#
#    longterm_borrowings  longterm_payables  longterm_payables_sum  \
# 0                  NaN                NaN                    0.0
#
#    longterm_employee_benefits  longterm_receivables  longterm_prepaid_expense  \
# 0                         NaN                   NaN               146455346.9
#
#    longterm_equity_investments  total_noncurr_liabilities  \
# 0                          NaN               3.344479e+08
#
#    totbal_diff_of_noncurr_liabilities  spec_diff_of_noncurr_liabilities  \
# 0                                 NaN                               NaN
#
#    total_noncurr_assets  totbal_diff_of_noncurr_assets  \
# 0          3.775337e+10                            NaN
#
#    spec_diff_of_noncurr_assets   prepayments  advances  provisions
# 0                          NaN  8.973772e+08       NaN         NaN

# %% [markdown]
# ### 2.2 Income Statement

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_income_general_pit
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  fs_quarter_index  change_type  \
# 0 2023-03-31  600519.SH  2022-12-31                 4            0
#
#    continuing_operation_net_profit  discontinued_operation_net_profit  \
# 0                     6.537514e+10                                NaN
#
#    othcom_income_cannt_reclass  othcom_income_reclass  \
# 0                          NaN             2240973.45
#
#    income_derecognition_of_fin_assets_at_amortized_cost  \
# 0                                                NaN
#
#    own_credit_risk_fair_value_chg  expense_on_policy_dividends  \
# 0                             NaN                          NaN
#
#    credit_impairment_loss  fair_value_chg_gain  other_cannt_reclass  \
# 0             14686546.25                  NaN                  NaN
#
#    other_reclass  credit_impairment_of_other_debt_investments  \
# 0            NaN                                          NaN
#
#    other_debt_investments_fair_value_chg  other_income  \
# 0                                    NaN   24505353.83
#
#    other_equity_instruments_fair_value_chg  income_othcom_income  \
# 0                                      NaN            2240973.45
#
#      net_profit  totbal_diff_of_net_profit  spec_diff_of_net_profit  \
# 0  6.537514e+10                        NaN                      NaN
#
#    net_income_of_open_hedge  reinsurance_premium_expense  interest_costs  \
# 0                       NaN                          NaN    1.055842e+08
#
#    interest_income  total_profit  totbal_diff_of_total_profit  \
# 0     3.454116e+09  8.770149e+10                          NaN
#
#    spec_diff_of_total_profit  available_for_sale_fin_assets_fair_value_chg  \
# 0                        NaN                                           NaN
#
#    eps_basic  income_translation_diff_of_foreign_currency  \
# 0      49.93                                   2240973.45
#
#    invest_income_of_jv_and_associates  net_profit_to_minority  \
# 0                                 NaN            2.658693e+09
#
#    insurance_premium_income  othcom_income_to_minority  \
# 0                       NaN                        NaN
#
#    net_profit_to_parent_shareholders  \
# 0                       6.271644e+10
#
#    total_comprehensive_income_to_parent_shareholders  \
# 0                                       6.271868e+10
#
#    othcom_income_to_parent_shareholders  income_tax_expense  \
# 0                            2240973.45        2.232635e+10
#
#    fee_and_commission_costs  fee_and_commission_income  invest_income  \
# 0                 143141.51                        NaN     63840000.0
#
#    gains_or_losses_from_htm_to_afs  net_amount_of_insurance_reserve  \
# 0                              NaN                              NaN
#
#    othcom_income_cannt_reclass_under_equity_method  \
# 0                                              NaN
#
#    othcom_income_reclass_under_equity_method  exchange_gain  \
# 0                                        NaN            NaN
#
#    cashflow_hedge_reserve  effective_of_gains_or_losses_on_cashflow_hedge  \
# 0                     NaN                                             NaN
#
#    research_and_development_expense  eps_diluted  taxes_and_levies  \
# 0                       135185680.4        49.93      1.849582e+10
#
#    administrative_expense  total_comprehensive_income  operating_profit  \
# 0            9.012191e+09                6.537738e+10      8.787952e+10
#
#    totbal_diff_of_operating_profit  spec_diff_of_operating_profit  \
# 0                              NaN                            NaN
#
#    nonoperating_costs  nonoperating_income  total_operating_costs  \
# 0        2.488843e+08           70852285.4           3.976300e+10
#
#    totbal_diff_of_operating_costs  spec_diff_of_operating_costs  \
# 0                             NaN                           NaN
#
#    total_operating_revenue  totbal_diff_of_operating_revenue  \
# 0             1.275540e+11                               NaN
#
#    spec_diff_of_operating_revenue  operating_costs  operating_revenue  \
# 0                             NaN     1.009347e+10       1.240998e+11
#
#    finance_expense  fin_interest_income  fin_interest_expense  \
# 0    -1.391806e+09         1.475422e+09           12023204.77
#
#    asset_impairment_loss  asset_disposal_income  net_insurance_claims_paid  \
# 0                    NaN              213235.69                        NaN
#
#    surrenders  chg_by_remeasurements  \
# 0         NaN                    NaN
#
#    othcom_income_from_reclass_of_fin_assets  selling_epense  \
# 0                                       NaN    3.297724e+09
#
#    noncurr_assets_dispose_gain  noncurr_assets_dispose_loss
# 0                          NaN                          NaN

# %% [markdown]
# ### 2.3 Cash Flow Statement

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_cashflow_general_pit
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  fs_quarter_index  change_type  \
# 0 2023-03-31  600519.SH  2022-12-31                 4            0
#
#    conv_corp_bonds_within_1y  netinc_in_insurance_deposits_and_invest  \
# 0                        NaN                                      NaN
#
#    credit_impairment_loss_in_cashflow_sheet  debt_transfer_to_capital  \
# 0                                       NaN                       NaN
#
#    cash_paid_for_debt_repayment  loss_from_fair_value_chg  \
# 0                           NaN                       NaN
#
#    others_in_cashflow_sheet  cash_paid_for_dividends_profits_interests  \
# 0                       NaN                               5.737020e+10
#
#    cash_received_from_bond_issue  cash_received_from_borrowings  \
# 0                            NaN                            NaN
#
#    cash_paid_by_acquiring_subsidiaries  return_on_investment  \
# 0                                  NaN             5880000.0
#
#    netinc_in_borrowings_from_central_bank  \
# 0                                     NaN
#
#    netinc_in_loans_from_other_fin_institutions  \
# 0                                          NaN
#
#    capital_contributions_received  netinc_in_repurchase_transactions  \
# 0                             NaN                                NaN
#
#    depreciation_of_fa_oga_pba  loss_from_scraping_of_fixed_assets  \
# 0                1.520946e+09                         20780992.88
#
#    netinc_in_disposal_fin_assets  net_cash_received_from_disposal_filt_assets  \
# 0                            NaN                                     355149.0
#
#    loss_from_disposal_of_fa_ia_lta  \
# 0                       -213235.69
#
#    net_cash_received_from_disposal_subsidiaries  \
# 0                                           NaN
#
#    cash_received_by_subsidiaries_from_minority  \
# 0                                          NaN
#
#    cash_paid_by_subsidiaries_to_minority  \
# 0                           2.618815e+09
#
#    netinc_deposits_central_bank_interbank  decrease_in_inventories  \
# 0                            1.303776e+10            -5.430009e+09
#
#    netinc_in_deposits  netinc_in_loans_and_advances  invest_loss  \
# 0       -8.916033e+09                   723778672.0  -63840000.0
#
#    cash_paid_for_investments     net_cffia  totbal_diff_of_net_cffia  \
# 0                210000000.0 -5.536826e+09                       0.0
#
#    spec_diff_of_net_cffia  subtotal_cifia  totbal_diff_of_cifia  \
# 0                     NaN     11206911.18                   NaN
#
#    spec_diff_of_cifia  subtotal_of_cofia  totbal_diff_of_cofia  \
# 0                 NaN       5.548033e+09                   NaN
#
#    spec_diff_of_cofia  netinc_in_loans_from_banks_and_fin_institutions  \
# 0                 NaN                                              NaN
#
#    cash_paid_for_policy_dividends  cash_paid_for_other_investing  \
# 0                             NaN                            NaN
#
#    cash_paid_for_other_financing   other_cofoa  \
# 0                    54332788.37  5.123087e+09
#
#    cash_paid_for_interests_fees_and_commissions  cash_paid_for_claims  \
# 0                                   79226410.98                   NaN
#
#    cash_paid_for_taxes_and_levies  cash_paid_for_employees  \
# 0                             NaN             1.175224e+10
#
#    cash_received_from_other_investing  cash_received_from_other_financing  \
# 0                          4971762.18                                 NaN
#
#    cash_received_from_other_operating  net_cash_received_from_reinsurance  \
# 0                        2.759422e+09                                 NaN
#
#    cash_received_from_premiums  taxes_and_levies_rebates  \
# 0                          NaN               33191912.56
#
#    cash_received_from_interests_fess_and_commissions  \
# 0                                       3.247615e+09
#
#    cash_received_from_disposal_investments  amorization_of_intangible_assets  \
# 0                                      NaN                       156016278.9
#
#    cce_beginning    cce_ending  effect_of_exchange_chg_on_cce  netinc_in_cce  \
# 0   1.786406e+11  1.523787e+11                      911088.01  -2.626185e+10
#
#    net_profit_in_cashflow_sheet  finance_expenses_in_cashflow_sheet  \
# 0                  6.537514e+10                         12023204.77
#
#    cash_balance_beginning  cash_balance_ending  cce_balance_beginning  \
# 0            1.786406e+11         1.523787e+11                    NaN
#
#    cce_balance_ending  totbal_diff_of_netinc_in_cce  \
# 0                 NaN                           NaN
#
#    spec_diff_of_netinc_in_cce     net_cfffa  totbal_diff_of_net_cfffa  \
# 0                         NaN -5.742453e+10                       0.0
#
#    spec_diff_of_net_cfffa  subtotal_ciffa  totbal_diff_of_ciffa  \
# 0                     NaN             NaN                   NaN
#
#    spec_diff_of_ciffa  subtotal_of_coffa  totbal_diff_of_coffa  \
# 0                 NaN       5.742453e+10                   NaN
#
#    spec_diff_of_coffa  increase_in_operating_payables  \
# 0                 NaN                   -8.644821e+09
#
#    decrease_in_operating_receivables     net_cffoa  totbal_diff_of_net_cffoa  \
# 0                      -1.505187e+10  3.669860e+10                       0.0
#
#    spec_diff_of_net_cffoa  subtotal_cifoa  totbal_diff_of_cifoa  \
# 0                     NaN    1.378159e+11                   NaN
#
#    spec_diff_of_cifoa  subtotal_cofoa  totbal_diff_of_cofoa  \
# 0                 NaN             NaN                   NaN
#
#    spec_diff_of_cofoa  fin_lease_fixed_assets  netinc_in_pledge_loans  \
# 0                 NaN                     NaN                     NaN
#
#    cash_paid_for_goods_and_services  cash_paid_for_filt_assets  \
# 0                      8.357859e+09               5.306546e+09
#
#    asset_impairment_reserve  increase_in_deferred_tax_liabilities  \
# 0                       NaN                                   NaN
#
#    decrease_in_deferred_tax_assets  cash_received_from_sales_and_services  \
# 0                    -1.221725e+09                           1.406917e+11
#
#    amortization_of_longterm_deferred_expenses  netinc_in_cce_indirect  \
# 0                                 11487619.04           -2.626185e+10
#
#    totbal_diff_of_netinc_in_cce_indirect  spec_diff_of_netinc_in_cce_indirect  \
# 0                                    NaN                                  NaN
#
#    net_cffoa_indirect  totbal_diff_of_net_cffoa_indirect  \
# 0        3.669860e+10                                NaN
#
#    spec_diff_of_net_cffoa_indirect
# 0                              NaN

# %% [markdown]
# ## 3. Financial Reports Notes Data

# %% [markdown]
# ### 3.1 Margin Business

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_margin_business
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#   instrument       date report_date  change_type name_by_industry_1  \
# 0  600519.SH 2023-03-31  2022-12-31            0                 酒类
#
#    revenue_by_industry_1  cost_by_industry_1  profit_by_industry_1  \
# 0           1.237723e+11        9.896113e+09          1.138762e+11
#
#    profit_ratio_by_industry_1 name_by_industry_2  revenue_by_industry_2  \
# 0                    0.920046               其他业务           3.275114e+08
#
#    cost_by_industry_2  profit_by_industry_2  profit_ratio_by_industry_2  \
# 0        1.973553e+08          1.301561e+08                    0.397409
#
#   name_by_industry_3  revenue_by_industry_3  cost_by_industry_3  \
# 0               None                    NaN                 NaN
#
#    profit_by_industry_3  profit_ratio_by_industry_3 name_by_industry_4  \
# 0                   NaN                         NaN               None
#
#    revenue_by_industry_4  cost_by_industry_4  profit_by_industry_4  \
# 0                    NaN                 NaN                   NaN
#
#    profit_ratio_by_industry_4 name_by_industry_5  revenue_by_industry_5  \
# 0                         NaN               None                    NaN
#
#    cost_by_industry_5  profit_by_industry_5  profit_ratio_by_industry_5  \
# 0                 NaN                   NaN                         NaN
#
#   name_by_product_1  revenue_by_product_1  cost_by_product_1  \
# 0               茅台酒          1.078337e+11       6.265811e+09
#
#    profit_by_product_1  profit_ratio_by_product_1 name_by_product_2  \
# 0         1.015679e+11                   0.941894             其他系列酒
#
#    revenue_by_product_2  cost_by_product_2  profit_by_product_2  \
# 0          1.593865e+10       3.630302e+09         1.230834e+10
#
#    profit_ratio_by_product_2 name_by_product_3  revenue_by_product_3  \
# 0                   0.772233              其他业务          3.275114e+08
#
#    cost_by_product_3  profit_by_product_3  profit_ratio_by_product_3  \
# 0       1.973553e+08         1.301561e+08                   0.397409
#
#   name_by_product_4  revenue_by_product_4  cost_by_product_4  \
# 0              None                   NaN                NaN
#
#    profit_by_product_4  profit_ratio_by_product_4 name_by_product_5  \
# 0                  NaN                        NaN              None
#
#    revenue_by_product_5  cost_by_product_5  profit_by_product_5  \
# 0                   NaN                NaN                  NaN
#
#    profit_ratio_by_product_5 name_by_district_1  revenue_by_district_1  \
# 0                        NaN                 国内           1.195328e+11
#
#    cost_by_district_1  profit_by_district_1  profit_ratio_by_district_1  \
# 0        9.558682e+09          1.099741e+11                    0.920033
#
#   name_by_district_2  revenue_by_district_2  cost_by_district_2  \
# 0                 国外           4.239579e+09        3.374312e+08
#
#    profit_by_district_2  profit_ratio_by_district_2 name_by_district_3  \
# 0          3.902148e+09                    0.920409               其他业务
#
#    revenue_by_district_3  cost_by_district_3  profit_by_district_3  \
# 0           3.275114e+08        1.973553e+08          1.301561e+08
#
#    profit_ratio_by_district_3 name_by_district_4  revenue_by_district_4  \
# 0                    0.397409               None                    NaN
#
#    cost_by_district_4  profit_by_district_4  profit_ratio_by_district_4  \
# 0                 NaN                   NaN                         NaN
#
#   name_by_district_5  revenue_by_district_5  cost_by_district_5
# 0               None                    NaN                 NaN

# %% [markdown]
# ### 3.2 Supplier & Customers

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_supplier_customer
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#   instrument       date report_date  change_type margin_supplier_name_1  \
# 0  600519.SH 2023-03-31  2022-12-31            0
#
#    purchase_amount_1  purchase_ratio_1  total_purchase_amount_1  \
# 0                NaN               NaN             2.238479e+09
#
#    total_purchase_ratio_1 customer_name_1  sale_amount_1  sale_ratio_1  \
# 0                   35.33                            NaN           NaN
#
#    total_sale_amount_1  total_sale_ratio_1 margin_supplier_name_2  \
# 0         1.415813e+10               11.44
#
#    purchase_amount_2  purchase_ratio_2  total_purchase_amount_2  \
# 0                NaN               NaN             2.238479e+09
#
#    total_purchase_ratio_2 customer_name_2  sale_amount_2  sale_ratio_2  \
# 0                   35.33                            NaN           NaN
#
#    total_sale_amount_2  total_sale_ratio_2 margin_supplier_name_3  \
# 0         1.415813e+10               11.44
#
#    purchase_amount_3  purchase_ratio_3  total_purchase_amount_3  \
# 0                NaN               NaN             2.238479e+09
#
#    total_purchase_ratio_3 customer_name_3  sale_amount_3  sale_ratio_3  \
# 0                   35.33                            NaN           NaN
#
#    total_sale_amount_3  total_sale_ratio_3 margin_supplier_name_4  \
# 0         1.415813e+10               11.44
#
#    purchase_amount_4  purchase_ratio_4  total_purchase_amount_4  \
# 0                NaN               NaN             2.238479e+09
#
#    total_purchase_ratio_4 customer_name_4  sale_amount_4  sale_ratio_4  \
# 0                   35.33                            NaN           NaN
#
#    total_sale_amount_4  total_sale_ratio_4 margin_supplier_name_5  \
# 0         1.415813e+10               11.44
#
#    purchase_amount_5  purchase_ratio_5  total_purchase_amount_5  \
# 0                NaN               NaN             2.238479e+09
#
#    total_purchase_ratio_5 customer_name_5  sale_amount_5  sale_ratio_5  \
# 0                   35.33                            NaN           NaN
#
#    total_sale_amount_5  total_sale_ratio_5
# 0         1.415813e+10               11.44

# %% [markdown]
# ### 3.3 Impairment Loss

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_impairment_loss
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  change_type  bad_debt_loss  \
# 0 2023-03-31  600519.SH  2022-12-31            0            NaN
#
#    inventory_price_dropped_loss  salesable_impairment_loss  \
# 0                           NaN                        NaN
#
#    held_to_maturity_impairment_loss  \
# 0                               NaN
#
#    long_term_equity_investment_impairment_loss  \
# 0                                          NaN
#
#    invest_property_impairment_loss  fixed_assets_impairment_loss  \
# 0                              NaN                           NaN
#
#    engineering_material_impairment_loss  construct_project_impairment_loss  \
# 0                                   NaN                                NaN
#
#    intangible_assets_impairment_loss  goodwill_impairment_loss  \
# 0                                NaN                       NaN
#
#    other_impairment_loss  currency_impairment_loss  \
# 0            17485027.31                       NaN
#
#    accounts_receivable_impairment_loss  biils_receivable_impairment_loss  \
# 0                           -415705.24                               NaN
#
#    long_term_receivable_impairment_loss  debt_investment_impairment_loss  \
# 0                                   NaN                         119880.0
#
#    other_debt_investment_impairment_loss  \
# 0                                    NaN
#
#    tradable_financial_assets_impairment_loss  lending_fund_impairment_loss  \
# 0                                        NaN                           NaN
#
#    financing_fund_impairment_loss  \
# 0                             NaN
#
#    buy_resale_financial_assets_impairment_loss  \
# 0                                          NaN
#
#    loans_and_payment_impairment_loss  interbank_deposite_impairment_loss  \
# 0                                NaN                                 NaN
#
#    central_bank_deposite_impairment_loss  \
# 0                                    NaN
#
#    noncurrent_assets_within_1year_impairment_loss  \
# 0                                             NaN
#
#    financial_guarantee_contract_impairment_loss  loan_commit_impairment_loss  \
# 0                                           NaN                          NaN
#
#    wmp_impairment_loss  exchange_change_impairment_loss  \
# 0                  NaN                              NaN
#
#    margin_trading_impairment_loss  asset_impairment_loss_sum  \
# 0                             NaN                        NaN
#
#    credit_impairment_loss_sum
# 0                 14686546.25

# %% [markdown]
# ### 3.4 Goodwill

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_goodwill
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  change_type  original_book_value  \
# 0 2023-03-31  600519.SH  2022-12-31            0                  NaN
#
#    impairment_amount  book_value
# 0                NaN         NaN

# %% [markdown]
# ### 3.5 Income Tax

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_income_tax
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  change_type  current_income_tax  \
# 0 2023-03-31  600519.SH  2022-12-31            0        2.354808e+10
#
#    income_tax_adjust_from_previous_years  defer_income_tax  other_tax  \
# 0                                    NaN     -1.221725e+09        NaN
#
#       total_tax  current_income_tax_mainland  current_income_tax_hongkong  \
# 0  2.232635e+10                          NaN                          NaN
#
#    current_income_tax_foreign
# 0                         NaN

# %% [markdown]
# ### 3.6 Investment Income

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_investment_income
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  change_type  \
# 0 2023-03-31  600519.SH  2022-12-31            0
#
#    long_term_equity_investment_income_by_cost_method  \
# 0                                                NaN
#
#    long_term_equity_investment_income_by_equity_method  \
# 0                                                NaN
#
#    invest_income_from_saling_long_term_equity_investment  \
# 0                                                NaN
#
#    invest_income_from_helding_financial_assets  \
# 0                                          NaN
#
#    invest_income_from_helding_held_to_maturity  \
# 0                                          NaN
#
#    invest_income_from_helding_salesable_assets  \
# 0                                          NaN
#
#    invest_income_from_diposing_financial_assets  \
# 0                                           NaN
#
#    invest_income_from_diposing_held_to_maturity  \
# 0                                           NaN
#
#    invest_income_from_diposing_salesable_assets  invest_income_from_other  \
# 0                                           NaN                       NaN
#
#    total_invest_income
# 0                  NaN

# %% [markdown]
# ### 3.7 Financial Expense

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_financial_expense
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  change_type  interest_cost  \
# 0 2023-03-31  600519.SH  2022-12-31            0    12023204.77
#
#    interest_cost_capitalized  interest_income  exchange_gain  charge_free  \
# 0                12023204.77     3.454116e+09            NaN          NaN
#
#    capitalized  other  special
# 0          NaN    NaN      NaN

# %% [markdown]
# ### 3.8 Non-recurring Gain & Loss

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_nonrecurring_gain_loss
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df()
# Out:
#         date instrument report_date  change_type  illiquid_assets  taxfree  \
# 0 2023-03-31  600519.SH  2022-12-31            0     -20567757.19      NaN
#
#    government_grants  occupancy_fee  fair_value_investment  \
# 0        14973304.55            NaN                    NaN
#
#    non_monetary_asset_exchange  manage_investment  force_impairment  \
# 0                          NaN                NaN               NaN
#
#    debt_reorganization  enterprise_reorganization  fair_value_trading  merge  \
# 0                  NaN                        NaN                 NaN    NaN
#
#    bussiness_unrelated  other_financial_income  \
# 0                  NaN                     NaN
#
#    reversal_of_impairment_reserve  external_entruste_loan  \
# 0                             NaN                     NaN
#
#    invested_realestate_fair_value_change  influence_after_adjustment  \
# 0                                    NaN                         NaN
#
#    trustee_fee  other_nonoperating_income  other_nonrecurring_items  \
# 0          NaN              -1.572510e+08                63840000.0
#
#    income_tax_impact  nonrecurring_income_to_owner  \
# 0       -24751373.49                  -75428959.45
#
#    nonrecurring_income_to_minority  nonrecurring_income_sum
# 0                       1174838.97             -74254120.48
