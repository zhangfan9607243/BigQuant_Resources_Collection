# %% [markdown]
# # Chinese (Mainland) Stock Data - Financial Data - Original FS Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', None)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Financial Reports Change Data

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_changedate
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
""", full_db_scan=True).df()
# Out:
#   instrument report_date                                         changedate  \
# 0  600519.SH  2022-12-31  2023-03-31,2023-04-26,2023-08-03,2023-10-21,20...
# 1  600519.SH  2022-12-31                              2023-03-31,2024-04-03
# 2  600519.SH  2022-12-31                              2023-03-31,2024-04-03
#
#   statement_type
# 0  balance_sheet
# 1         income
# 2      cash_flow

# %% [markdown]
# ## 2. Financial Statements Data

# %% [markdown]
# ### 2.1 Balance Sheet

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_balance_general_pit
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                                      0
# date                                               2023-03-31 00:00:00
# instrument                                                   600519.SH
# report_date                                        2022-12-31 00:00:00
# fs_quarter_index                                                     4
# change_type                                                          0
# noncurr_liabilities_due_within_1y                         109351155.28
# noncurr_assets_due_within_1y                             2123601333.33
# general_reserve                                           1061529724.0
# specific_reserve                                                   NaN
# specific_payables                                                  NaN
# fin_assets_purchased_under_resale                                  NaN
# tradable_fin_liabilities                                           NaN
# ...

# %% [markdown]
# ### 2.2 Income Statement

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_income_general_pit
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                                       0
# date                                                2023-03-31 00:00:00
# instrument                                                    600519.SH
# report_date                                         2022-12-31 00:00:00
# fs_quarter_index                                                      4
# change_type                                                           0
# continuing_operation_net_profit                          65375136766.75
# discontinued_operation_net_profit                                   NaN
# othcom_income_cannt_reclass                                         NaN
# othcom_income_reclass                                        2240973.45
# income_derecognition_of_fin_assets_at_amortized...                  NaN
# own_credit_risk_fair_value_chg                                      NaN
# expense_on_policy_dividends                                         NaN
# ...

# %% [markdown]
# ### 2.3 Cash Flow Statement

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_cashflow_general_pit
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                                      0
# date                                               2023-03-31 00:00:00
# instrument                                                   600519.SH
# report_date                                        2022-12-31 00:00:00
# fs_quarter_index                                                     4
# change_type                                                          0
# conv_corp_bonds_within_1y                                          NaN
# netinc_in_insurance_deposits_and_invest                            NaN
# credit_impairment_loss_in_cashflow_sheet                           NaN
# debt_transfer_to_capital                                           NaN
# cash_paid_for_debt_repayment                                       NaN
# loss_from_fair_value_chg                                           NaN
# others_in_cashflow_sheet                                           NaN
# ...

# %% [markdown]
# ## 3. Financial Reports Notes Data

# %% [markdown]
# ### 3.1 Margin Business

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_margin_business
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                               0
# instrument                            600519.SH
# date                        2023-03-31 00:00:00
# report_date                 2022-12-31 00:00:00
# change_type                                   0
# name_by_industry_1                           酒类
# revenue_by_industry_1       123772332348.710007
# cost_by_industry_1            9896113336.799999
# profit_by_industry_1        113876219011.910004
# profit_ratio_by_industry_1             0.920046
# name_by_industry_2                         其他业务
# revenue_by_industry_2              327511423.28
# cost_by_industry_2                 197355279.83
# profit_by_industry_2               130156143.45
# profit_ratio_by_industry_2             0.397409
# name_by_industry_3                         None
# revenue_by_industry_3                       NaN
# cost_by_industry_3                          NaN
# profit_by_industry_3                        NaN
# profit_ratio_by_industry_3                  NaN
# ...

# %% [markdown]
# ### 3.2 Supplier & Customers

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_supplier_customer
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                            0
# instrument                         600519.SH
# date                     2023-03-31 00:00:00
# report_date              2022-12-31 00:00:00
# change_type                                0
# margin_supplier_name_1
# purchase_amount_1                        NaN
# purchase_ratio_1                         NaN
# total_purchase_amount_1         2238478800.0
# total_purchase_ratio_1                 35.33
# customer_name_1
# sale_amount_1                            NaN
# sale_ratio_1                             NaN
# total_sale_amount_1            14158125700.0
# total_sale_ratio_1                     11.44
# margin_supplier_name_2
# purchase_amount_2                        NaN
# purchase_ratio_2                         NaN
# total_purchase_amount_2         2238478800.0
# total_purchase_ratio_2                 35.33
# customer_name_2
# sale_amount_2                            NaN
# sale_ratio_2                             NaN
# ...

# %% [markdown]
# ### 3.3 Impairment Loss

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_impairment_loss
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                                   0
# date                                            2023-03-31 00:00:00
# instrument                                                600519.SH
# report_date                                     2022-12-31 00:00:00
# change_type                                                       0
# bad_debt_loss                                                   NaN
# inventory_price_dropped_loss                                    NaN
# salesable_impairment_loss                                       NaN
# held_to_maturity_impairment_loss                                NaN
# long_term_equity_investment_impairment_loss                     NaN
# invest_property_impairment_loss                                 NaN
# fixed_assets_impairment_loss                                    NaN
# engineering_material_impairment_loss                            NaN
# construct_project_impairment_loss                               NaN
# ...

# %% [markdown]
# ### 3.4 Goodwill

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_goodwill
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                        0
# date                 2023-03-31 00:00:00
# instrument                     600519.SH
# report_date          2022-12-31 00:00:00
# change_type                            0
# original_book_value                  NaN
# impairment_amount                    NaN
# book_value                           NaN

# %% [markdown]
# ### 3.5 Income Tax

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_income_tax
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                          0
# date                                   2023-03-31 00:00:00
# instrument                                       600519.SH
# report_date                            2022-12-31 00:00:00
# change_type                                              0
# current_income_tax                      23548077905.700001
# income_tax_adjust_from_previous_years                  NaN
# defer_income_tax                            -1221724924.27
# other_tax                                              NaN
# total_tax                                   22326352981.43
# current_income_tax_mainland                            NaN
# current_income_tax_hongkong                            NaN
# current_income_tax_foreign                             NaN

# %% [markdown]
# ### 3.6 Investment Income

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_investment_income
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                                       0
# date                                                2023-03-31 00:00:00
# instrument                                                    600519.SH
# report_date                                         2022-12-31 00:00:00
# change_type                                                           0
# long_term_equity_investment_income_by_cost_method                   NaN
# long_term_equity_investment_income_by_equity_me...                  NaN
# invest_income_from_saling_long_term_equity_inve...                  NaN
# invest_income_from_helding_financial_assets                         NaN
# invest_income_from_helding_held_to_maturity                         NaN
# invest_income_from_helding_salesable_assets                         NaN
# invest_income_from_diposing_financial_assets                        NaN
# invest_income_from_diposing_held_to_maturity                        NaN
# ...

# %% [markdown]
# ### 3.7 Financial Expense

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_financial_expense
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                              0
# date                       2023-03-31 00:00:00
# instrument                           600519.SH
# report_date                2022-12-31 00:00:00
# change_type                                  0
# interest_cost                      12023204.77
# interest_cost_capitalized          12023204.77
# interest_income                  3454115583.98
# exchange_gain                              NaN
# charge_free                                NaN
# capitalized                                NaN
# other                                      NaN
# special                                    NaN

# %% [markdown]
# ### 3.8 Non-recurring Gain & Loss

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_note_nonrecurring_gain_loss
WHERE report_date = '2022-12-31'
AND instrument = '600519.SH'
AND change_type = 0
""", full_db_scan=True).df().transpose()
# Out:
#                                                          0
# date                                   2023-03-31 00:00:00
# instrument                                       600519.SH
# report_date                            2022-12-31 00:00:00
# change_type                                              0
# illiquid_assets                               -20567757.19
# taxfree                                                NaN
# government_grants                              14973304.55
# occupancy_fee                                          NaN
# fair_value_investment                                  NaN
# non_monetary_asset_exchange                            NaN
# manage_investment                                      NaN
# force_impairment                                       NaN
# debt_reorganization                                    NaN
# enterprise_reorganization                              NaN
# fair_value_trading                                     NaN
# ...
