# %% [markdown]
# # Chinese (Mainland) Stock Data - Financial Data - Forecasting FS Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', None)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_forecast_consensus_rolling
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""", full_db_scan=True).df().transpose()
# Out:
#                                                0
# date                         2024-12-31 00:00:00
# instrument                             600519.SH
# forecast_eps_fy1                          68.536
# forecast_eps_fy2                         76.5857
# forecast_eps_fy3                         85.1602
# forecast_eps_12m                         76.5857
# forecast_np_fy1               86094691964.830002
# forecast_np_fy2               96207229808.188995
# forecast_np_fy3              106977706714.339996
# forecast_np_12m               96207229808.188995
# forecast_np_yoy                        15.201394
# forecast_np_yoy_fy2to1                 11.745832
# forecast_np_cagr_2                     13.460458
# forecast_revenue_fy1         173634295576.920013
# forecast_revenue_fy2         193178523076.920013
# forecast_revenue_fy3         213720541923.079987
# forecast_revenue_12m         193178523076.920013
# forecast_revenue_yoy                   17.563855
# forecast_revenue_yoy_fy2to1            11.255972
# forecast_revenue_cagr_2                14.366433
