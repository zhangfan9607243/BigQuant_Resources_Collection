# %% [markdown]
# # Chinese (Mainland) Stock Data - Financial Data - Forecasting FS Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_stock_financial_forecast_consensus_rolling
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""", full_db_scan=True).df()
# Out:
#         date instrument  forecast_eps_fy1  forecast_eps_fy2  forecast_eps_fy3  \
# 0 2024-12-31  600519.SH            68.536           76.5857           85.1602
#
#    forecast_eps_12m  forecast_np_fy1  forecast_np_fy2  forecast_np_fy3  \
# 0           76.5857     8.609469e+10     9.620723e+10     1.069777e+11
#
#    forecast_np_12m  forecast_np_yoy  forecast_np_yoy_fy2to1  \
# 0     9.620723e+10        15.201394               11.745832
#
#    forecast_np_cagr_2  forecast_revenue_fy1  forecast_revenue_fy2  \
# 0           13.460458          1.736343e+11          1.931785e+11
#
#    forecast_revenue_fy3  forecast_revenue_12m  forecast_revenue_yoy  \
# 0          2.137205e+11          1.931785e+11             17.563855
#
#    forecast_revenue_yoy_fy2to1  forecast_revenue_cagr_2
# 0                    11.255972                14.366433
