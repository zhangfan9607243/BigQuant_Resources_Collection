# %% [markdown]
# # Chinese (Mainland) Stock Data - Market Data - Leverage Trading Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Margin Trading & Security Lending Market

# %%
dai.query("""
SELECT *
FROM cn_stock_margin_trading_market
WHERE date = '2026-02-12'
""").df()
# Out:
#         date method  financing_balance  financing_quantity  \
# 0 2026-02-12    sum       2.499369e+12        1.633562e+11
# 1 2026-02-12   mean       6.605097e+08        4.317025e+07
#
#    financing_balance_ratio  financing_purchase  financing_purchase_quantity  \
# 0                 0.026156        1.940563e+11                 1.010606e+10
# 1                 0.000007        5.128337e+07                 2.670735e+06
#
#    financing_repayment  financing_repayment_quantity  financing_net_purchase  \
# 0         1.970465e+11                  1.027946e+10           -2.990211e+09
# 1         5.207359e+07                  2.716560e+06           -7.902250e+05
#
#    financing_net_purchase_quantity  securities_lending_balance  \
# 0                    -1.733991e+08                8.736988e+09
# 1                    -4.582429e+04                2.308929e+06
#
#    securities_lending_quantity  securities_lending_sales  \
# 0                 4.813785e+08              4.260977e+08
# ...

# %% [markdown]
# ## 2. Margin Trading & Security Lending Detail

# %%
dai.query("""
SELECT *
FROM cn_stock_margin_trading_detail
WHERE date = '2026-02-12'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  financing_balance  financing_quantity  \
# 0 2026-02-12  600519.SH       1.672798e+10          26575247.0
#
#    financing_balance_ratio  financing_purchase  financing_purchase_quantity  \
# 0                 0.008986         713979824.0                     480277.0
#
#    financing_repayment  financing_repayment_quantity  financing_net_purchase  \
# 0         1.284571e+09                      864100.0            -570591546.0
#
#    financing_net_purchase_quantity  securities_lending_balance  \
# 0                        -383823.0                 178860279.0
#
#    securities_lending_quantity  securities_lending_sales  \
# 0                     120315.0                 6243720.0
#
#    securities_lending_sales_quantity  securities_lending_repayment  \
# 0                             4200.0                     6838360.0
#
#    securities_lending_repayment_quantity  securities_lending_net_sales  \
# ...
