# %% [markdown]
# # Chinese (Mainland) Stock Data - Factor Data - Market & Basic Information Factors

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Basic Information Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_base
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#   instrument       date  list_sector  list_date  adjust_factor        amount  \
# 0  600519.SH 2026-02-13            1 2001-08-27       8.446992  6.216379e+09
#
#     volume         close          high           low          open  \
# 0  4167901  12546.317168  12736.374488  12421.977447  12557.298258
#
#    price_limit_status  st_status   upper_limit   lower_limit  \
# 0                   2          0  13813.028084  11301.568432
#
#    total_market_cap  float_market_cap  list_days  trading_days  total_shares  \
# 0      1.859997e+12      1.859997e+12       8937          5938  1.256198e+09
#
#     float_total  float_ratio  financing_balance  securities_lending_balance  \
# 0  1.256198e+09          1.0                NaN                         NaN
#
#    financing_net_purchase  financing_purchase  financing_repayment  \
# 0                     NaN                 NaN                  NaN
#
#   sw2021_level1 sw2021_level2 sw2021_level3 sw2014_level1 sw2014_level2  \
# 0        340000        340500        340501        340000        340300
#
#   sw2014_level3 cs_level1 cs_level2 cs_level3  suspended  \
# 0        340301    360000    361000    361010          0
#
#    margin_trading_status  is_szzs  is_sh50  is_hs300  is_kc50  is_zz1000  \
# 0                      0        1        1         1        0          0
#
#    is_zz100  is_zz500  is_szcz  is_cybz  is_sz100  is_bz50  is_zza500  \
# 0         1         0        0        0         0        0          1
#
#    szzs_high  szzs_open   szzs_low  szzs_close  szzs_volume   szzs_amount  \
# 0  4123.8443  4115.9243  4079.7702   4082.0726  500799472.0  8.468083e+11
#
#    sh50_high  sh50_open   sh50_low  sh50_close  sh50_volume   sh50_amount  \
# 0   3066.039   3062.206  3032.6561   3034.3459   45953549.0  1.259656e+11
#
#    hs300_high  hs300_open  hs300_low  hs300_close  hs300_volume  hs300_amount  \
# 0   4703.6332   4693.4106  4658.4038    4660.4056   189167756.0  4.528786e+11
#
#    kc50_high  kc50_open  kc50_low  kc50_close  kc50_volume  kc50_amount  \
# 0        NaN        NaN       NaN         NaN          NaN          NaN
#
#    zz1000_high  zz1000_open  zz1000_low  zz1000_close  zz1000_volume  \
# 0          NaN          NaN         NaN           NaN            NaN
#
#    zz1000_amount  zz100_high  zz100_open  zz100_low  zz100_close  \
# 0            NaN    4598.352   4589.6512  4554.3982    4556.3312
#
#    zz100_volume  zz100_amount  zz500_high  zz500_open  zz500_low  zz500_close  \
# 0    90007986.0  2.516031e+11         NaN         NaN        NaN          NaN
#
#    zz500_volume  zz500_amount  szcz_high  szcz_open  szcz_low  szcz_close  \
# 0           NaN           NaN        NaN        NaN       NaN         NaN
#
#    szcz_volume  szcz_amount  cybz_high  cybz_open  cybz_low  cybz_close  \
# 0          NaN          NaN        NaN        NaN       NaN         NaN
#
#    cybz_volume  cybz_amount  sz100_high  sz100_open  sz100_low  sz100_close  \
# 0          NaN          NaN         NaN         NaN        NaN          NaN
#
#    sz100_volume  sz100_amount  bz50_high  bz50_open  bz50_low  bz50_close  \
# 0           NaN           NaN        NaN        NaN       NaN         NaN
#
#    bz50_volume  bz50_amount  zza500_high  zza500_open  zza500_low  \
# 0          NaN          NaN    5902.3072     5883.478   5837.5205
#
#    zza500_close  zza500_volume  zza500_amount  price_ampolitude
# 0      5840.727    301238379.0   7.075769e+11          0.025037

# %% [markdown]
# ## 2. Valuation Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_valuation
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  total_market_cap  float_market_cap  \
# 0 2026-02-13  600519.SH      1.859997e+12      1.859997e+12
#
#    dividend_yield_ratio     pe_ttm  pe_leading  pe_trailing        pb  \
# 0              0.034761  20.660356   21.585455    21.570647  7.000232
#
#       ps_ttm  ps_leading  ps_trailing  pcf_net_ttm  pcf_net_leading  \
# 0  10.223953   10.656656    10.680794   430.986022       -133.26781
#
#    pcf_op_ttm  pcf_op_leading
# 0   21.567906       36.521322

# %% [markdown]
# ## 3. Moneyflow Factor

# %%
dai.query("""
SELECT *
FROM cn_stock_moneyflow
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  active_buy_volume_large  passive_buy_volume_large  \
# 0 2026-02-13  600519.SH                 587820.0                  467259.0
#
#    active_sell_volume_large  passive_sell_volume_large  \
# 0                  556471.0                   535710.0
#
#    active_buy_amount_large  passive_buy_amount_large  \
# 0              878278656.0               696634752.0
#
#    active_sell_amount_large  passive_sell_amount_large  active_buy_volume_big  \
# 0               829974016.0                800068736.0               709336.0
#
#    passive_buy_volume_big  active_sell_volume_big  passive_sell_volume_big  \
# 0                765335.0                827786.0                 593539.0
#
#    active_buy_amount_big  passive_buy_amount_big  active_sell_amount_big  \
# 0           1.057769e+09            1.141039e+09            1.233796e+09
#
#    passive_sell_amount_big  active_buy_volume_mid  passive_buy_volume_mid  \
# 0              884887616.0               801410.0                865856.0
#
#    active_sell_volume_mid  passive_sell_volume_mid  active_buy_amount_mid  \
# 0                684996.0                 940070.0           1.194810e+09
#
#    passive_buy_amount_mid  active_sell_amount_mid  passive_sell_amount_mid  \
# 0            1.293010e+09            1.021629e+09             1.400541e+09
#
#    active_buy_volume_small  passive_buy_volume_small  \
# 0                     16.0                     132.0
#
#    active_sell_volume_small  passive_sell_volume_small  \
# 0                      66.0                        0.0
#
#    active_buy_amount_small  passive_buy_amount_small  \
# 0             23742.400391              197901.53125
#
#    active_sell_amount_small  passive_sell_amount_small  active_buy_volume_all  \
# 0                   98774.0                        0.0              2098582.0
#
#    active_buy_amount_all  passive_buy_volume_all  passive_buy_amount_all  \
# 0           3.130881e+09               2098582.0            3.130881e+09
#
#    active_sell_volume_all  active_sell_amount_all  passive_sell_volume_all  \
# 0               2069319.0            3.085498e+09                2069319.0
#
#    passive_sell_amount_all  active_buy_volume_main  active_buy_amount_main  \
# 0             3.085498e+09               1297156.0            1.936047e+09
#
#    passive_buy_volume_main  passive_buy_amount_main  active_sell_volume_main  \
# 0                1232594.0             1.837673e+09                1384257.0
#
#    active_sell_amount_main  passive_sell_volume_main  \
# 0             2.063770e+09                 1129249.0
#
#    passive_sell_amount_main  net_active_buy_volume_large  \
# 0              1.684956e+09                      31349.0
#
#    net_active_buy_amount_large  net_active_buy_volume_big  \
# 0                   48304640.0                  -118450.0
#
#    net_active_buy_amount_big  net_active_buy_volume_mid  \
# 0               -176027200.0                   116414.0
#
#    net_active_buy_amount_mid  net_active_buy_volume_small  \
# 0                173180928.0                        -50.0
#
#    net_active_buy_amount_small  net_active_buy_volume_all  \
# 0                -75031.599609                    29263.0
#
#    net_active_buy_amount_all  net_active_buy_volume_main  \
# 0               4.538334e+07                    -87101.0
#
#    net_active_buy_amount_main  inflow_volume_large  outflow_volume_large  \
# 0                -127722560.0            1123530.0             1023730.0
#
#    netflow_volume_large  inflow_amount_large  outflow_amount_large  \
# 0               99800.0         1.678347e+09          1.526609e+09
#
#    netflow_amount_large  inflow_volume_big  outflow_volume_big  \
# 0           151738624.0          1302875.0           1593121.0
#
#    netflow_volume_big  inflow_amount_big  outflow_amount_big  \
# 0           -290246.0       1.942656e+09        2.374834e+09
#
#    netflow_amount_big  inflow_volume_mid  outflow_volume_mid  \
# 0        -432178304.0          1741480.0           1550852.0
#
#    netflow_volume_mid  inflow_amount_mid  outflow_amount_mid  \
# 0            190628.0       2.595352e+09        2.314639e+09
#
#    netflow_amount_mid  inflow_volume_small  outflow_volume_small  \
# 0         280712448.0                 16.0                 198.0
#
#    netflow_volume_small  inflow_amount_small  outflow_amount_small  \
# 0                -182.0         23742.400391          296675.53125
#
#    netflow_amount_small  inflow_volume_all  outflow_volume_all  \
# 0        -272933.130859          4167901.0           4167901.0
#
#    netflow_volume_all  inflow_amount_all  outflow_amount_all  \
# 0                 0.0       6.216379e+09        6.216379e+09
#
#    netflow_amount_all  inflow_volume_main  outflow_volume_main  \
# 0         -165.130859           2426405.0            2616851.0
#
#    netflow_volume_main  inflow_amount_main  outflow_amount_main  \
# 0            -190446.0        3.621004e+09         3.901443e+09
#
#    netflow_amount_main  active_buy_volume_rate_large  \
# 0         -280439680.0                      0.141035
#
#    active_buy_amount_rate_large  active_buy_volume_rate_big  \
# 0                      0.141285                     0.17019
#
#    active_buy_amount_rate_big  active_buy_volume_rate_mid  \
# 0                    0.170158                    0.192281
#
#    active_buy_amount_rate_mid  active_buy_volume_rate_small  \
# 0                    0.192204                      0.000004
#
#    active_buy_amount_rate_small  active_buy_volume_rate_all  \
# 0                      0.000004                    0.503511
#
#    active_buy_amount_rate_all  active_buy_volume_rate_main  \
# 0                     0.50365                     0.311225
#
#    active_buy_amount_rate_main  passive_buy_volume_rate_large  \
# 0                     0.311443                       0.112109
#
#    passive_buy_amount_rate_large  passive_buy_volume_rate_big  \
# 0                       0.112064                     0.183626
#
#    passive_buy_amount_rate_big  passive_buy_volume_rate_mid  \
# 0                     0.183554                     0.207744
#
#    passive_buy_amount_rate_mid  passive_buy_volume_rate_small  \
# 0                        0.208                       0.000032
#
#    passive_buy_amount_rate_small  passive_buy_volume_rate_all  \
# 0                       0.000032                     0.503511
#
#    passive_buy_amount_rate_all  passive_buy_volume_rate_main  \
# 0                      0.50365                      0.295735
#
#    passive_buy_amount_rate_main  active_sell_volume_rate_large  \
# 0                      0.295618                       0.133513
#
#    active_sell_amount_rate_large  active_sell_volume_rate_big  \
# 0                       0.133514                      0.19861
#
#    active_sell_amount_rate_big  active_sell_volume_rate_mid  \
# 0                     0.198475                      0.16435
#
#    active_sell_amount_rate_mid  active_sell_volume_rate_small  \
# 0                     0.164345                       0.000016
#
#    active_sell_amount_rate_small  active_sell_volume_rate_all  \
# 0                       0.000016                     0.496489
#
#    active_sell_amount_rate_all  active_sell_volume_rate_main  \
# 0                      0.49635                      0.332123
#
#    active_sell_amount_rate_main  passive_sell_volume_rate_large  \
# 0                      0.331989                        0.128532
#
#    passive_sell_amount_rate_large  passive_sell_volume_rate_big  \
# 0                        0.128703                      0.142407
#
#    passive_sell_amount_rate_big  passive_sell_volume_rate_mid  \
# 0                      0.142348                       0.22555
#
#    passive_sell_amount_rate_mid  passive_sell_volume_rate_small  \
# 0                      0.225299                             0.0
#
#    passive_sell_amount_rate_small  passive_sell_volume_rate_all  \
# 0                             0.0                      0.496489
#
#    passive_sell_amount_rate_all  passive_sell_volume_rate_main  \
# 0                       0.49635                       0.270939
#
#    passive_sell_amount_rate_main  net_active_buy_volume_rate_large  \
# 0                       0.271051                          0.007522
#
#    net_active_buy_amount_rate_large  net_active_buy_volume_rate_big  \
# 0                          0.007771                        -0.02842
#
#    net_active_buy_amount_rate_big  net_active_buy_volume_rate_mid  \
# 0                       -0.028317                        0.027931
#
#    net_active_buy_amount_rate_mid  net_active_buy_volume_rate_small  \
# 0                        0.027859                         -0.000012
#
#    net_active_buy_amount_rate_small  net_active_buy_volume_rate_all  \
# 0                         -0.000012                        0.007021
#
#    net_active_buy_amount_rate_all  net_active_buy_volume_rate_main  \
# 0                        0.007301                        -0.020898
#
#    net_active_buy_amount_rate_main  inflow_volume_rate_large  \
# 0                        -0.020546                  0.269567
#
#    inflow_amount_rate_large  inflow_volume_rate_big  inflow_amount_rate_big  \
# 0                  0.269988                0.312597                0.312506
#
#    inflow_volume_rate_mid  inflow_amount_rate_mid  inflow_volume_rate_small  \
# 0                0.417831                0.417502                  0.000004
#
#    inflow_amount_rate_small  inflow_volume_rate_all  inflow_amount_rate_all  \
# 0                  0.000004                     1.0                     1.0
#
#    inflow_volume_rate_main  inflow_amount_rate_main  \
# 0                 0.582165                 0.582494
#
#    outflow_volume_rate_large  outflow_amount_rate_large  \
# 0                   0.245622                   0.245578
#
#    outflow_volume_rate_big  outflow_amount_rate_big  outflow_volume_rate_mid  \
# 0                 0.382236                 0.382029                 0.372094
#
#    outflow_amount_rate_mid  outflow_volume_rate_small  \
# 0                 0.372345                   0.000048
#
#    outflow_amount_rate_small  outflow_volume_rate_all  \
# 0                   0.000048                      1.0
#
#    outflow_amount_rate_all  outflow_volume_rate_main  \
# 0                      1.0                  0.627858
#
#    outflow_amount_rate_main  netflow_volume_rate_large  \
# 0                  0.627607                   0.023945
#
#    netflow_amount_rate_large  netflow_volume_rate_big  \
# 0                   0.024409                -0.069638
#
#    netflow_amount_rate_big  netflow_volume_rate_mid  netflow_amount_rate_mid  \
# 0                -0.069523                 0.045737                 0.045157
#
#    netflow_volume_rate_small  netflow_amount_rate_small  \
# 0                  -0.000044                  -0.000044
#
#    netflow_volume_rate_all  netflow_amount_rate_all  netflow_volume_rate_main  \
# 0                      0.0            -2.656383e-08                 -0.045694
#
#    netflow_amount_rate_main  active_buy_volume_proportion_large  \
# 0                 -0.045113                            0.000469
#
#    active_buy_amount_proportion_large  active_buy_volume_proportion_big  \
# 0                            0.000472                          0.000566
#
#    active_buy_amount_proportion_big  active_buy_volume_proportion_mid  \
# 0                          0.000569                           0.00064
#
#    active_buy_amount_proportion_mid  active_buy_volume_proportion_small  \
# 0                          0.000642                        1.277680e-08
#
#    active_buy_amount_proportion_small  active_buy_volume_proportion_all  \
# 0                        1.276475e-08                          0.001676
#
#    active_buy_amount_proportion_all  active_buy_volume_proportion_main  \
# 0                          0.001683                           0.001036
#
#    active_buy_amount_proportion_main  passive_buy_volume_proportion_large  \
# 0                           0.001041                             0.000373
#
#    passive_buy_amount_proportion_large  passive_buy_volume_proportion_big  \
# 0                             0.000375                           0.000611
#
#    passive_buy_amount_proportion_big  passive_buy_volume_proportion_mid  \
# 0                           0.000613                           0.000691
#
#    passive_buy_amount_proportion_mid  passive_buy_volume_proportion_small  \
# 0                           0.000695                         1.054086e-07
#
#    passive_buy_amount_proportion_small  passive_buy_volume_proportion_all  \
# 0                         1.063988e-07                           0.001676
#
#    passive_buy_amount_proportion_all  passive_buy_volume_proportion_main  \
# 0                           0.001683                            0.000984
#
#    passive_buy_amount_proportion_main  active_sell_volume_proportion_large  \
# 0                            0.000988                             0.000444
#
#    active_sell_amount_proportion_large  active_sell_volume_proportion_big  \
# 0                             0.000446                           0.000661
#
#    active_sell_amount_proportion_big  active_sell_volume_proportion_mid  \
# 0                           0.000663                           0.000547
#
#    active_sell_amount_proportion_mid  active_sell_volume_proportion_small  \
# 0                           0.000549                         5.270428e-08
#
#    active_sell_amount_proportion_small  active_sell_volume_proportion_all  \
# 0                         5.310439e-08                           0.001652
#
#    active_sell_amount_proportion_all  active_sell_volume_proportion_main  \
# 0                           0.001659                            0.001105
#
#    active_sell_amount_proportion_main  passive_sell_volume_proportion_large  \
# 0                             0.00111                              0.000428
#
#    passive_sell_amount_proportion_large  passive_sell_volume_proportion_big  \
# 0                               0.00043                            0.000474
#
#    passive_sell_amount_proportion_big  passive_sell_volume_proportion_mid  \
# 0                            0.000476                            0.000751
#
#    passive_sell_amount_proportion_mid  passive_sell_volume_proportion_small  \
# 0                            0.000753                                   0.0
#
#    passive_sell_amount_proportion_small  passive_sell_volume_proportion_all  \
# 0                                   0.0                            0.001652
#
#    passive_sell_amount_proportion_all  passive_sell_volume_proportion_main  \
# 0                            0.001659                             0.000902
#
#    passive_sell_amount_proportion_main  \
# 0                             0.000906
#
#    net_active_buy_volume_proportion_large  \
# 0                                0.000025
#
#    net_active_buy_amount_proportion_large  \
# 0                                0.000026
#
#    net_active_buy_volume_proportion_big  net_active_buy_amount_proportion_big  \
# 0                             -0.000095                             -0.000095
#
#    net_active_buy_volume_proportion_mid  net_active_buy_amount_proportion_mid  \
# 0                              0.000093                              0.000093
#
#    net_active_buy_volume_proportion_small  \
# 0                           -3.992748e-08
#
#    net_active_buy_amount_proportion_small  \
# 0                           -4.033964e-08
#
#    net_active_buy_volume_proportion_all  net_active_buy_amount_proportion_all  \
# 0                              0.000023                              0.000024
#
#    net_active_buy_volume_proportion_main  \
# 0                               -0.00007
#
#    net_active_buy_amount_proportion_main  inflow_volume_proportion_large  \
# 0                              -0.000069                        0.000897
#
#    inflow_amount_proportion_large  inflow_volume_proportion_big  \
# 0                        0.000902                       0.00104
#
#    inflow_amount_proportion_big  inflow_volume_proportion_mid  \
# 0                      0.001044                      0.001391
#
#    inflow_amount_proportion_mid  inflow_volume_proportion_small  \
# 0                      0.001395                    1.277680e-08
#
#    inflow_amount_proportion_small  inflow_volume_proportion_all  \
# 0                    1.276475e-08                      0.003328
#
#    inflow_amount_proportion_all  inflow_volume_proportion_main  \
# 0                      0.003342                       0.001938
#
#    inflow_amount_proportion_main  outflow_volume_proportion_large  \
# 0                       0.001947                         0.000817
#
#    outflow_amount_proportion_large  outflow_volume_proportion_big  \
# 0                         0.000821                       0.001272
#
#    outflow_amount_proportion_big  outflow_volume_proportion_mid  \
# 0                       0.001277                       0.001238
#
#    outflow_amount_proportion_mid  outflow_volume_proportion_small  \
# 0                       0.001244                     1.581128e-07
#
#    outflow_amount_proportion_small  outflow_volume_proportion_all  \
# 0                     1.595032e-07                       0.003328
#
#    outflow_amount_proportion_all  outflow_volume_proportion_main  \
# 0                       0.003342                         0.00209
#
#    outflow_amount_proportion_main  netflow_volume_proportion_large  \
# 0                        0.002098                          0.00008
#
#    netflow_amount_proportion_large  netflow_volume_proportion_big  \
# 0                         0.000082                      -0.000232
#
#    netflow_amount_proportion_big  netflow_volume_proportion_mid  \
# 0                      -0.000232                       0.000152
#
#    netflow_amount_proportion_mid  netflow_volume_proportion_small  \
# 0                       0.000151                    -1.453360e-07
#
#    netflow_amount_proportion_small  netflow_volume_proportion_all  \
# 0                    -1.467385e-07                            0.0
#
#    netflow_amount_proportion_all  netflow_volume_proportion_main  \
# 0                  -8.878018e-11                       -0.000152
#
#    netflow_amount_proportion_main
# 0                       -0.000151

# %% [markdown]
# ## 4. Auction Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_auction
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  open_auction_order_volume  open_auction_order_amount  \
# 0 2026-02-13  600519.SH                   323230.0               4.901286e+08
#
#    open_auction_trade_volume  open_auction_trade_amount  \
# 0                    32200.0                 47868520.0
#
#    open_auction_cancel_volume  open_auction_trade_price  open_order_price_max  \
# 0                      2700.0               1486.599976            1635.26001
#
#    open_order_price_min  open_auction_turnover  open_auction_limit_up  \
# 0           1337.939941                    NaN                      0
#
#    open_auction_limit_low  open_auction_amplitude  overnight_change_ratio  \
# 0                       0               22.222228                     NaN
#
#    close_auction_order_volume  close_auction_order_amount  \
# 0                    114751.0                1.687129e+08
#
#    close_auction_trade_volume  close_auction_trade_amount  \
# 0                     39251.0                5.829951e+07
#
#    close_auction_trade_price  close_order_price_max  close_order_price_min  \
# 0                1485.300049             1635.26001            1337.939941
#
#    close_auction_turnover  close_auction_amplitude
# 0                     NaN                22.222228

# %% [markdown]
# ## 5. Shareholder Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_shareholder
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  total_shareholder  total_shareholder_chg  \
# 0 2026-02-13  600519.SH           238512.0               0.080913
#
#    a_shareholder  a_shareholder_chg  avg_share_per_account_total  \
# 0       238512.0           0.080913                  5266.811733
#
#    avg_share_per_account_total_chg  avg_share_ratio_per_account_total  \
# 0                        -0.074856                           0.000004
#
#    avg_share_ratio_per_account_total_chg  avg_share_per_account_float  \
# 0                              -0.074856                  5266.811733
#
#    avg_share_per_account_float_chg  avg_share_ratio_per_account_float  \
# 0                        -0.074856                           0.000004
#
#    avg_share_ratio_per_account_float_chg  total_shareholder_chg_1q  \
# 0                              -0.074856                  0.080913
#
#    total_shareholder_chg_2q  total_shareholder_chg_3q  \
# 0                  0.239474                  0.239474
#
#    total_shareholder_chg_4q  a_shareholder_chg_1q  a_shareholder_chg_2q  \
# 0                  0.147277              0.080913              0.239474
#
#    a_shareholder_chg_3q  a_shareholder_chg_4q  \
# 0              0.239474              0.147277
#
#    avg_share_per_account_total_chg_1q  avg_share_per_account_total_chg_2q  \
# 0                           -0.074856                           -0.193206
#
#    avg_share_per_account_total_chg_3q  avg_share_per_account_total_chg_4q  \
# 0                           -0.193206                           -0.128371
#
#    avg_share_ratio_per_account_total_chg_1q  \
# 0                                 -0.074856
#
#    avg_share_ratio_per_account_total_chg_2q  \
# 0                                 -0.193206
#
#    avg_share_ratio_per_account_total_chg_3q  \
# 0                                 -0.193206
#
#    avg_share_ratio_per_account_total_chg_4q  \
# 0                                 -0.128371
#
#    avg_share_per_account_float_chg_1q  avg_share_per_account_float_chg_2q  \
# 0                           -0.074856                           -0.193206
#
#    avg_share_per_account_float_chg_3q  avg_share_per_account_float_chg_4q  \
# 0                           -0.193206                           -0.128371
#
#    avg_share_ratio_per_account_float_chg_1q  \
# 0                                 -0.074856
#
#    avg_share_ratio_per_account_float_chg_2q  \
# 0                                 -0.193206
#
#    avg_share_ratio_per_account_float_chg_3q  \
# 0                                 -0.193206
#
#    avg_share_ratio_per_account_float_chg_4q  rank_total_shareholder  \
# 0                                 -0.128371                0.977273
#
#    rank_total_shareholder_chg  rank_a_shareholder  rank_a_shareholder_chg  \
# 0                    0.749398            0.976817                0.749171
#
#    rank_avg_share_per_account_total  rank_avg_share_per_account_total_chg  \
# 0                          0.032015                              0.245899
#
#    rank_avg_share_ratio_per_account_total  \
# 0                                0.023367
#
#    rank_avg_share_ratio_per_account_total_chg  \
# 0                                    0.250876
#
#    rank_avg_share_per_account_float  rank_avg_share_per_account_float_chg  \
# 0                          0.125483                              0.240553
#
#    rank_avg_share_ratio_per_account_float  \
# 0                                0.023376
#
#    rank_avg_share_ratio_per_account_float_chg  rank_total_shareholder_chg_1q  \
# 0                                    0.250737                       0.725842
#
#    rank_total_shareholder_chg_2q  rank_total_shareholder_chg_3q  \
# 0                       0.811791                       0.765593
#
#    rank_total_shareholder_chg_4q  rank_a_shareholder_chg_1q  \
# 0                        0.62036                   0.725309
#
#    rank_a_shareholder_chg_2q  rank_a_shareholder_chg_3q  \
# 0                   0.811573                   0.765831
#
#    rank_a_shareholder_chg_4q  rank_avg_share_per_account_total_chg_1q  \
# 0                   0.620329                                 0.267098
#
#    rank_avg_share_per_account_total_chg_2q  \
# 0                                 0.172516
#
#    rank_avg_share_per_account_total_chg_3q  \
# 0                                 0.213008
#
#    rank_avg_share_per_account_total_chg_4q  \
# 0                                 0.353227
#
#    rank_avg_share_ratio_per_account_total_chg_1q  \
# 0                                       0.273937
#
#    rank_avg_share_ratio_per_account_total_chg_2q  \
# 0                                       0.188672
#
#    rank_avg_share_ratio_per_account_total_chg_3q  \
# 0                                       0.232948
#
#    rank_avg_share_ratio_per_account_total_chg_4q  \
# 0                                       0.379046
#
#    rank_avg_share_per_account_float_chg_1q  \
# 0                                 0.259519
#
#    rank_avg_share_per_account_float_chg_2q  \
# 0                                 0.162488
#
#    rank_avg_share_per_account_float_chg_3q  \
# 0                                 0.196981
#
#    rank_avg_share_per_account_float_chg_4q  \
# 0                                 0.329654
#
#    rank_avg_share_ratio_per_account_float_chg_1q  \
# 0                                       0.273585
#
#    rank_avg_share_ratio_per_account_float_chg_2q  \
# 0                                        0.18829
#
#    rank_avg_share_ratio_per_account_float_chg_3q  \
# 0                                       0.232319
#
#    rank_avg_share_ratio_per_account_float_chg_4q
# 0                                       0.378348

# %% [markdown]
# ## 6. Industry Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_industry
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  sw_level1_close  sw_level1_open  sw_level1_high  \
# 0 2026-02-13  600519.SH         16509.82        16561.05        16704.85
#
#    sw_level1_low  sw_level1_volume  sw_level1_amount  sw_level1_turn  \
# 0       16466.85      1.086583e+09      2.542822e+10        0.011737
#
#   sw_level1_name sw_level_index_code sw2021_level1 sw2021_level2  \
# 0           食品饮料          801120.SWI        340000        340500
#
#   sw2021_level3 sw2014_level1 sw2014_level2 sw2014_level3 cs_level1 cs_level2  \
# 0        340501        340000        340300        340301    360000    361000
#
#   cs_level3 sw2021_level1_name sw2021_level2_name sw2021_level3_name  \
# 0    361010               食品饮料                白酒Ⅱ                白酒Ⅲ
#
#   sw2014_level1_name sw2014_level2_name sw2014_level3_name cs_level1_name  \
# 0               食品饮料               饮料制造                 白酒           食品饮料
#
#   cs_level2_name cs_level3_name
# 0             酒类             白酒
