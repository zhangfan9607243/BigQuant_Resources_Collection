# %% [markdown]
# # Chinese (Mainland) Convertible Bond Data - Information Data - Bond Covenants

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_cbond_basic_info
WHERE instrument = '127040.SZ'
""").df()
# Out:
#   instrument  name stock_code stock_name  list_date delist_date  par_value  \
# 0  127040.SZ  国泰转债  002091.SZ       江苏国泰 2021-08-10         NaT      100.0
#
#    issue_term  issue_price  issue_total_amount value_date maturity_date  \
# 0         6.0        100.0        4.557419e+09 2021-07-07    2027-07-07
#
#   interest_rate_type  issue_interest_rate credit_rating  credit_agent
# 0               累进利率                  0.2           AA+  联合资信评估股份有限公司
