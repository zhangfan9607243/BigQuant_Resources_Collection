# %% [markdown]
# # Chinese (Mainland) Convertible Bond Data - Information Data - Rating Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_cbond_rating
WHERE instrument = '127040.SZ'
""").df()
# Out:
#   instrument latest_credict_rating latest_rating_chg latest_rating_date  \
# 0  127040.SZ                   AA+                维持         2023-06-20
#
#   rating_type    rating_org
# 0    债券长期信用评级  联合资信评估股份有限公司
