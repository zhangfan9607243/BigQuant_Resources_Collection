# %% [markdown]
# # Chinese (Mainland) Convertible Bond Data - Information Data - Bond Covenants

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Interest Terms

# %%
dai.query("""
SELECT *
FROM cn_cbond_interest
WHERE instrument = '127040.SZ'
""").df()
# Out:
#   instrument                           nominal_interest_explain  \
# 0  127040.SZ  20210707-20220706,票面利率:0.2%;20220707-20230706,...
#
#    compen_interest                            compen_interest_explain  \
# 0           2.0833  　　在本次发行的可转换公司债券期满后五个交易日内，公司将按照债券面值的108%（含最后一期利...
#
#   is_adjust_by_deposit_interest isinterest_compensation  \
# 0                             否                       是
#
#   is_ic_include_current_interest
# 0                              是

# %% [markdown]
# ## 2. Resale Terms

# %%
dai.query("""
SELECT *
FROM cn_cbond_resale
WHERE instrument = '127040.SZ'
""").df()
# Out:
#   date instrument  cndtn_resale_price cndtn_resale_sd cndtn_resale_ed  \
# 0  NaT  127040.SZ                 NaN      2025-07-07      2027-07-07
#
#    relative_resale_period  resale_trigger_calc_mti  resale_trigger_calc_ti  \
# 0                    48.0                     30.0                    30.0
#
#    resale_trigger_ratio  resale_trigger_price  resale_price resale_audit_ad  \
# 0                  70.0                 5.355         102.0             NaT
#
#    resale_times_per_year resale_interest_process uncndtn_resale_period  \
# 0                    1.0                      应计
#
#   uncndtn_resale_sd uncndtn_resale_ed  uncndtn_resale_price  \
# 0               NaT               NaT                   NaN
#
#   uncndtn_resale_clause  time_point_resalenum add_resale_price_explain
# 0                                         NaN                面值加当期应计利息

# %% [markdown]
# ## 3. Revise Terms

# %%
dai.query("""
SELECT *
FROM cn_cbond_revise
WHERE instrument = '127040.SZ'
""").df()
# Out:
#         date instrument is_special_down_correct_clause   end_date  \
# 0 2021-07-07  127040.SZ                              是 2027-07-07
#
#    down_correct_trigger_calc_mti  down_correct_trigger_calc_int  \
# 0                           30.0                           15.0
#
#    conversion_price_ratio is_arith_avg_price  revise_extent  \
# 0                    85.0                  否            NaN
#
#   correct_times_limit
# 0                  不限

# %% [markdown]
# ## 4. Redemption Terms

# %%
dai.query("""
SELECT *
FROM cn_cbond_redemption
WHERE instrument = '127040.SZ'
""").df()
# Out:
#   date instrument                                  redemption_clause  \
# 0  NaT  127040.SZ  　　1、到期赎回条款在本次发行的可转换公司债券期满后五个交易日内，公司将按照债券面值的108...
#
#   redemption_price_explain  cndtn_redemption_price  maturity_redemption_price  \
# 0                面值加当期应计利息                     NaN                      108.0
#
#   cndtn_redemption_sd cndtn_redemption_ed redemption_stop_redemption_date  \
# 0          2022-01-13          2027-07-06                             NaT
#
#   redemption_stop_transfer_date issuer_capital_to_account_date  \
# 0                           NaT                     2024-10-10
#
#    relative_redemption_period redemption_times_per_year  \
# 0                         6.0                      不限次数
#
#    redemption_triggercalc_mti  redemption_triggercalc_time_int  \
# 0                        30.0                             15.0
#
#    redemption_trigger_ratio  redemption_trigger_price  redemption_price  \
# 0                     130.0                     9.945             102.0
#
#   redemption_audit_ad not_compulsory_redemp_indicative_date  \
# 0                 NaT                                   NaT
#
#   not_compulsory_redemp_startdate not_compulsory_redemp_enddate  \
# 0                             NaT                           NaT
#
#   interest_process is_redemption_clause_of_time  time_point_redemption_num
# 0               应计                            否                        NaN

# %% [markdown]
# ## 5. Conversion Terms

# %%
dai.query("""
SELECT *
FROM cn_cbond_conversion
WHERE instrument = '127040.SZ'
""").df()
# Out:
#         date instrument    code  name  conversion_clause_price  \
# 0 2022-01-13  127040.SZ  127040  国泰转债                     7.65
#
#   trans_price_change_date  transfer_ratio   end_date  \
# 0              2023-05-31       13.071895 2027-07-06
#
#    relative_tranfer_stock_period is_compulsory_transfer  \
# 0                            6.0                      否
#
#   compulsory_transfer_date  compulsory_transfer_price  un_conversion_balance  \
# 0                      NaT                        NaN           3.986355e+09
#
#    un_conversion_ratio conversion_price_adjust
# 0            87.469586                       是
