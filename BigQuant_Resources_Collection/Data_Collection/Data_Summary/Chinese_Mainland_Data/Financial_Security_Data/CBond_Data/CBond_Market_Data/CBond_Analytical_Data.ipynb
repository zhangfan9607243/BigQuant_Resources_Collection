# %% [markdown]
# # Chinese (Mainland) Convertible Bond Data - Market Data - Analytical Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Daily Analytical Data

# %%
dai.query("""
SELECT *
FROM cn_cbond_analyze_metric
WHERE date = '2026-02-13'
AND instrument = '127040.SZ'
""").df()
# Out:
#         date instrument  days_accrued_interest  accrued_interest  \
# 0 2026-02-13  127040.SZ                  222.0          1.094795
#
#   next_interest_date last_td_date_convertible  remaining_days  \
# 0         2026-07-07                      NaT           509.0
#
#    remaining_life_year  wgt_surplus_years  accum_conversion_ratio  \
# 0             1.394521           1.378127               12.530414
#
#    current_yield  pure_debt_value  pure_debt_premium  pure_bond_premium_rate  \
# 0       1.293289        107.18468           31.99532               29.850647
#
#    pure_bond_ytm  conversion_price  conversion_ratio  transfer_value  \
# 0       -15.7926              7.65         13.071895      113.071895
#
#    conversion_premium  conversion_premium_rate  conver_pe  conver_pb  \
# 0           26.108105                23.089827  13.895024   1.102291
#
#    stock_pe  stock_pb  conversion_dlt_ratio  float_shares_dlt_rate  \
# ...

# %% [markdown]
# ## 2. Daily Risk & Return Data

# %%
dai.query("""
SELECT *
FROM cn_cbond_risk_return
WHERE date = '2026-02-13'
AND instrument = '127040.SZ'
""").df()
# Out:
#         date instrument  interest_acctualed_days  accrued_interest  \
# 0 2026-02-13  127040.SZ                    222.0          1.094795
#
#    surplus_limit_days  surplus_limit_year  special_surplus_limit  \
# 0               509.0            1.394521                 1.3945
#
#    rb_strike_surplus_years  wgt_surplus_limit  wgt_surplus_limit_principal  \
# 0                      NaN           1.378127                     1.394521
#
#   first_pay_date prev_interest_pay_date next_interest_pay_date  \
# 0     2022-07-07             2025-07-07             2026-07-07
#
#    days_to_next_interest_pay_date next_strike_date theory_strike_date  \
# 0                           144.0              NaT                NaT
#
#    next_dividend_cash_flow  next_total_cash_flow  cash_flow  \
# 0                      1.8                   1.8        NaN
#
#    principal_cash_flow  interest_cash_flow  ytm  strike_ytm  base_point_value  \
# ...
