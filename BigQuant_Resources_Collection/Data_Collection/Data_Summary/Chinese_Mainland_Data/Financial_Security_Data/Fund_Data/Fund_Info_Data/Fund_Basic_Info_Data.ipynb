# %% [markdown]
# # Chinese (Mainland) ETF Data - Information Data - Basic Information

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Fund Basic Information

# %%
dai.query("""
SELECT *
FROM cn_fund_basic_info
WHERE instrument = '588990.SH'
""").df()
# Out:
#   instrument name                full_name abbreviation_name  list_date  \
# 0  588990.SH  科芯片  博时上证科创板芯片交易型开放式指数证券投资基金               KXP 2024-08-16
#
#   delist_date    type invest_first_classi_type invest_second_classi_type  \
# 0  2200-01-01  契约型开放式                    股票型基金                 被动指数型股票基金
#
#    day_trading
# 0            0

# %% [markdown]
# ## 2. Fund Manager Information

# %%
dai.query("""
SELECT *
FROM cn_fund_manager_info
WHERE current_fund_codes LIKE '%588990%'
""").df()
# Out:
#     name affiliated_company  \
# 0    李庆阳               博时基金
# 1    李庆阳               博时基金
# 2    李庆阳               博时基金
# ..   ...                ...
# 441  李庆阳               博时基金
# 442  李庆阳               博时基金
# 443  李庆阳               博时基金
#
#                                     current_fund_codes  \
# 0    010785,010786,020183,020184,020691,020692,0209...
# 1    010785,010786,020183,020184,020691,020692,0209...
# 2    010785,010786,020183,020184,020691,020692,0209...
# ..                                                 ...
# 441  010785,010786,020183,020184,020691,020692,0209...
# 442  010785,010786,020183,020184,020691,020692,0209...
# 443  010785,010786,020183,020184,020691,020692,0209...
#
#                                      current_fund_name total_work_experience  \
# 0    博时创业板指数A,博时创业板指数C,博时中证传媒指数发起式A,博时中证传媒指数发起式C,博时...                   300
# 1    博时创业板指数A,博时创业板指数C,博时中证传媒指数发起式A,博时中证传媒指数发起式C,博时...                   301
# 2    博时创业板指数A,博时创业板指数C,博时中证传媒指数发起式A,博时中证传媒指数发起式C,博时...                   302
# ..                                                 ...                   ...
# 441  博时创业板指数A,博时创业板指数C,博时中证传媒指数发起式A,博时中证传媒指数发起式C,博时...                   747
# 442  博时创业板指数A,博时创业板指数C,博时中证传媒指数发起式A,博时中证传媒指数发起式C,博时...                   748
# 443  博时创业板指数A,博时创业板指数C,博时中证传媒指数发起式A,博时中证传媒指数发起式C,博时...                   749
#
#     current_fund_total_assets current_fund_best_return
# 0                      0.5001                     6.48
# 1                      0.5017                     6.48
# 2                      0.5386                     6.48
# ..                        ...                      ...
# 441                    1.7775                    96.36
# 442                    1.7775                    96.36
# 443                    1.7775                    96.36
#
# [444 rows x 7 columns]
