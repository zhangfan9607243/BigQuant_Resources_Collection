# %% [markdown]
# # Chinese (Mainland) ETF Data - Market Data - Popularity Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Dividend Rank

# %%
dai.query("""
SELECT *
FROM cn_fund_dividend_rank
ORDER BY rank
""").df()
# Out:
#      instrument                  name  rank  accum_dividend  dividend_count  \
# 0        159972           鹏华中证5年地债ETF     1          8.8200               3
# 1        511090        鹏扬中债-30年期国债ETF     2          7.5000               5
# 2        000011             华夏大盘精选混合A     3          7.3057              23
# ...         ...                   ...   ...             ...             ...
# 7637     159937               博时黄金ETF  7510          0.0002               1
# 7638     024705  嘉实中证港股通高股息投资ETF发起联接A  7511          0.0001               1
# 7639     024706  嘉实中证港股通高股息投资ETF发起联接C  7512          0.0001               1
#
#      fund_type establishment_date
# 0       指数型-固收         2019-08-23
# 1       指数型-固收         2023-05-19
# 2       混合型-灵活         2004-08-11
# ...        ...                ...
# 7637    ETF-场内         2014-08-13
# 7638    指数型-股票         2025-07-15
# 7639    指数型-股票         2025-07-15
#
# [7640 rows x 7 columns]

# %% [markdown]
# ## 2. Change Ratio Rank

# %%
dai.query("""
SELECT *
FROM cn_fund_change_ratio_rank
WHERE date = '2026-02-11'
ORDER BY rank
""").df()
# Out:
#      instrument               name       date  rank fund_type  unit_nav  \
# 0     515880.SH      国泰中证全指通信设备ETF 2026-02-11     0    指数型-股票    1.0499
# 1     561330.SH    国泰中证有色金属矿业主题ETF 2026-02-11     1    指数型-股票    2.2798
# 2     560860.SH    万家中证工业有色金属主题ETF 2026-02-11     2    指数型-股票    1.9089
# ...         ...                ...        ...   ...       ...       ...
# 1335  560290.SH  景顺长城中证有色金属矿业主题ETF 2026-02-11  1413    指数型-股票    0.9731
# 1336  159152.SZ     平安恒生港股通科技主题ETF 2026-02-11  1414    指数型-股票    0.9422
# 1337  159168.SZ    富国中证工业有色金属主题ETF 2026-02-11  1415    指数型-股票    1.0342
#
#       accum_nav  l1w_change_ratio  l1m_change_ratio  l3m_change_ratio  \
# 0        3.1497           -0.0010            0.0027            0.2026
# 1        2.2798           -0.0019            0.0900            0.3322
# 2        1.9089            0.0072            0.0851            0.3559
# ...         ...               ...               ...               ...
# 1335     0.9731               NaN               NaN               NaN
# 1336     0.9422            0.0145               NaN               NaN
# 1337     1.0342            0.0342               NaN               NaN
#
#       l6m_change_ratio  l1y_change_ratio  l2y_change_ratio  l3y_change_ratio  \
# 0               0.7501            1.2567            2.2881            2.3985
# 1               0.8107            1.2470            1.7527            1.0496
# 2               0.8216            1.2313            1.6085               NaN
# ...                ...               ...               ...               ...
# 1335               NaN               NaN               NaN               NaN
# 1336               NaN               NaN               NaN               NaN
# 1337               NaN               NaN               NaN               NaN
#
#       ry_change_ratio  cy_change_ratio fund_establishment_date
# 0              0.0218           2.1500              2019-08-16
# 1              0.1876           1.2798              2022-10-19
# 2              0.2025           0.9089              2023-02-22
# ...               ...              ...                     ...
# 1335              NaN          -0.0269              2026-01-26
# 1336              NaN          -0.0578              2026-01-21
# 1337              NaN           0.0342              2026-02-04
#
# [1338 rows x 17 columns]

# %% [markdown]
# ## 3. Return Rank

# %%
dai.query("""
SELECT *
FROM cn_fund_returns_rank
WHERE date = '2026-02-11'
ORDER BY rank
""").df()
# Out:
#       instrument         name       date  rank fund_type  unit_nav  \
# 0         000043  嘉实美国成长股票人民币 2026-02-11     1      QDII    5.6690
# 1         000746   招商行业精选股票基金 2026-02-11     1       股票型    6.7000
# 2         006011      中信保诚稳鸿A 2026-02-11     1       债券型    4.7568
# ...          ...          ...        ...   ...       ...       ...
# 14132     481001    工银核心价值混合A 2026-02-11  7175       混合型    0.3705
# 14133     460001   华泰柏瑞盛世中国混合 2026-02-11  7176       混合型    0.3698
# 14134     398001     中海优质成长混合 2026-02-11  7177       混合型    0.3485
#
#        l1y_returns  l2y_returns  l3y_returns  l5y_returns     fee
# 0           0.0900       0.1707       0.3471       0.5746  0.0015
# 1           0.3428       0.5248       0.6988       0.7626  0.0015
# 2          -0.0035       0.0023       0.0204       0.0574  0.0008
# ...            ...          ...          ...          ...     ...
# 14132       0.2523       0.3507       0.3718       0.2662  0.0015
# 14133       0.2005       0.2472       0.1501      -0.0515  0.0015
# 14134       0.1237       0.1767       0.1238       0.0119  0.0012
#
# [14135 rows x 11 columns]
