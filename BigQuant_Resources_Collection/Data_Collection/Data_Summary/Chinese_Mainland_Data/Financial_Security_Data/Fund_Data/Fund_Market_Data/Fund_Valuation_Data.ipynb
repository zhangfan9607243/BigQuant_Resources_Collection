# %% [markdown]
# # Chinese (Mainland) ETF Data - Market Data - Valuation Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Valuation Data

# %%
dai.query("""
SELECT *
FROM cn_fund_nav
WHERE date = '2026-02-10'
AND instrument = '588990.SH'
""").df()
# Out:
#   instrument       date  unit_nav  accum_nav  actual_yield_rate  navg_rate  \
# 0  588990.SH 2026-02-10    2.7605     2.7605                NaN     0.0116
#
#   pur_status redemp_status dividend_bonus
# 0       场内买入          场内卖出

# %% [markdown]
# ## 2. Fee Data

# %%
dai.query("""
SELECT *
FROM cn_fund_fee
WHERE instrument = '588990.SH'
""").df()
# Out:
#   instrument          name  management_fee_rate  \
# 0  588990.SH  博时上证科创板芯片ETF                  0.5
#
#   management_fee_rate_description is_floating_management_fee_collected  \
# 0                                                                    否
#
#   floating_management_fee_rate_description  custody_fee_rate  \
# 0                                                        0.1
#
#    sales_service_fee_rate  index_license_fee_rate  \
# 0                     NaN                     NaN
#
#                            frontend_subscription_fee backend_subscription_fee  \
# 0  金额0-50万元,费率为:0.8%,金额50(含)-100万元,费率为:0.5%,100(含...
#
#   frontend_purchase_fee backend_purchase_fee frontend_redemption_fee  \
# 0              费率为:0.5%                                     费率为:0.5%
#
#   backend_redemption_fee  maximum_subscription_fee_rate  \
# 0                                                   0.8
#
#    frontend_maximum_purchase_fee_rate  backend_maximum_purchase_fee_rate  \
# 0                                 0.5                                NaN
#
#    frontend_maximum_redemption_fee_rate  backend_maximum_redemption_fee_rate  \
# 0                                   0.5                                  NaN
#
#   is_fee_discount_available  minimum_purchase_discount  \
# 0                                                  NaN
#
#    minimum_regular_investment_discount
# 0                                  NaN
