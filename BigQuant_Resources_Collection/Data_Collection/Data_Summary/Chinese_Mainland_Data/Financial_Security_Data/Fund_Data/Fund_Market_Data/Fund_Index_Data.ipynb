# %% [markdown]
# # Chinese (Mainland) ETF Data - Market Data - Index Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_fund_swhy_index_bar1d
WHERE date = '2026-01-05'
""").df()
# Out:
#    instrument                  name index_type       date  first_close  \
# 0      807100            申万宏源权益基金指数       基础一级 2026-01-05      1089.89
# 1      807110          申万宏源主动权益基金指数       基础二级 2026-01-05      1052.91
# 2      807111      申万宏源主动权益中高仓位基金指数       基础三级 2026-01-05      1048.71
# ..        ...                   ...        ...        ...          ...
# 57     808001   申万宏源公募沪深300增强基金超额指数       特色指数 2026-01-05      1060.55
# 58     808002   申万宏源公募中证500增强基金超额指数       特色指数 2026-01-05      1058.41
# 59     808003  申万宏源公募中证1000增强基金超额指数       特色指数 2026-01-05      1177.99
#
#     pre_close  change_ratio  change_ratio_yearly
# 0     1114.93        0.0230               0.0230
# 1     1076.06        0.0220               0.0220
# 2     1071.51        0.0217               0.0217
# ..        ...           ...                  ...
# 57    1059.52       -0.0010              -0.0010
# 58    1054.65       -0.0036              -0.0036
# 59    1176.27       -0.0015              -0.0015
#
# ...
