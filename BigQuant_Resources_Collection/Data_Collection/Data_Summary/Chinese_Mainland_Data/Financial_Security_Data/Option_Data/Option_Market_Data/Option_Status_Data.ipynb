# %% [markdown]
# # Chinese (Mainland) Option Data - Market Data - Status Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_option_static_data
WHERE date = '2026-02-13'
AND instrument = '10009633.SHO'
""").df()
# Out:
#         date    instrument  trading_day        contract_id           name  \
# 0 2026-02-13  10009633.SHO     20260213  510050C2603A02700  50ETF购3月2630A
#
#   call_put product_class delivery_date  list_date delist_date exchange  \
# 0        C   spot_option    2026-03-26 2025-07-24  2026-03-25      SSE
#
#   expire_date strike_date  strike_price underlying  multiplier  margin_uint  \
# 0  2026-03-25  2026-03-25          2.63  510050.SH     10265.0      9450.16
#
#    pre_close  pre_settle  open_interest  uderlying_pre_close  \
# 0     0.5413      0.5413           1629                3.161
#
#    underlying_pre_settle trading_code  pre_open_interest
# 0                    NaN     10009633                  0
