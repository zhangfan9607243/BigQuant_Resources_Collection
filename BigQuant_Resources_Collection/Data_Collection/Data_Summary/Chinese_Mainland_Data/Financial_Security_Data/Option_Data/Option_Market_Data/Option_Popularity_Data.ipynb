# %% [markdown]
# # Chinese (Mainland) Option Data - Market Data - Popularity Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_option_dragon_list
WHERE date = '2026-02-13'
""").df()
# Out:
#    instrument       date          name trade_type  rank org_name  sell_volume  \
# 0      159919 2026-02-13    沪深300ETF嘉实      认沽交易量     1     华泰证券      42493.0
# 1      159919 2026-02-13    沪深300ETF嘉实      认沽交易量     2     中信证券      25008.0
# 2      159919 2026-02-13    沪深300ETF嘉实      认沽交易量     3     中泰证券      23158.0
# ..        ...        ...           ...        ...   ...      ...          ...
# 52     510300 2026-02-13  沪深300ETF华泰柏瑞      认购持仓量     3     中信证券          NaN
# 53     510300 2026-02-13  沪深300ETF华泰柏瑞      认购持仓量     4     广发证券          NaN
# 54     510300 2026-02-13  沪深300ETF华泰柏瑞      认购持仓量     5     华泰证券          NaN
#
#     sell_volume_change  net_sell_volume  sell_volume_ratio  org_code  \
# 0              30734.0              NaN           0.161583       NaN
# 1              14224.0          12147.0           0.095095       NaN
# 2               6098.0              NaN           0.088060       NaN
# ..                 ...              ...                ...       ...
# 52                 NaN              NaN                NaN       NaN
# 53                 NaN              NaN                NaN       NaN
# 54                 NaN              NaN                NaN       NaN
#
#     sell_position  sell_position_change  net_sell_position  \
# 0             NaN                   NaN                NaN
# 1             NaN                   NaN                NaN
# 2             NaN                   NaN                NaN
# ..            ...                   ...                ...
# 52            NaN                   NaN                NaN
# 53            NaN                   NaN                NaN
# 54            NaN                   NaN                NaN
#
#     sell_position_ratio  buy_volume  buy_volume_change  net_buy_volume  \
# 0                   NaN         NaN                NaN             NaN
# 1                   NaN         NaN                NaN             NaN
# 2                   NaN         NaN                NaN             NaN
# ..                  ...         ...                ...             ...
# 52                  NaN         NaN                NaN             NaN
# 53                  NaN         NaN                NaN             NaN
# 54                  NaN         NaN                NaN             NaN
#
#     buy_volume_ratio  buy_position  buy_position_change  net_buy_position  \
# 0                NaN           NaN                  NaN               NaN
# 1                NaN           NaN                  NaN               NaN
# 2                NaN           NaN                  NaN               NaN
# ..               ...           ...                  ...               ...
# 52               NaN       81093.0               1539.0           12565.0
# 53               NaN       79216.0              -1659.0               NaN
# 54               NaN       69561.0                162.0               NaN
#
#     buy_position_ratio
# 0                  NaN
# 1                  NaN
# 2                  NaN
# ..                 ...
# 52            0.056718
# 53            0.055405
# 54            0.048652
#
# [55 rows x 23 columns]
