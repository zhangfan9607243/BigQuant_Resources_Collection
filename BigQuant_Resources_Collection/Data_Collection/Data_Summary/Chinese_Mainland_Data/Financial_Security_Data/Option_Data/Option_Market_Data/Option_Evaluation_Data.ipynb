# %% [markdown]
# # Chinese (Mainland) Option Data - Market Data - Evaluation Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Valuation Data

# %%
dai.query("""
SELECT *
FROM cn_option_valuation
WHERE date = '2026-02-13'
AND instrument = '10009633.SHO'
""").df()
# Out:
#      instrument       date  lower_limit  upper_limit  delta  gamma    rho  \
# 0  10009633.SHO 2026-02-13       0.2252       0.8574    1.0    0.0  0.287
#
#    theta  underlying_implied_vol  vega
# 0 -0.077                     NaN   0.0

# %% [markdown]
# ## 2. Risk Measurement Data

# %%
dai.query("""
SELECT *
FROM cn_option_risk
WHERE date = '2026-02-13'
AND instrument = '10009633.SHO'
""").df()
# Out:
#      instrument trading_code       date  delta  theta  gamma  vega    rho
# 0  10009633.SHO     10009633 2026-02-13    1.0 -0.077    0.0   0.0  0.287
