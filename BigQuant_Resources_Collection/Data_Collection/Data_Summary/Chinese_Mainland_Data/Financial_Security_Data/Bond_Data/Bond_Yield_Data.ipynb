# %% [markdown]
# # Chinese (Mainland) Bond Data - Bond Yield Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_bond_yield
WHERE date = '2026-02-11'
""").df()
# Out:
#         date               symbol  month3  month6   year1   year3   year5  \
# 0 2026-02-11    中债中短期票据收益率曲线(AAA)  1.6401  1.6580  1.6800  1.8125  1.9578
# 1 2026-02-11  中债商业银行普通债收益率曲线(AAA)  1.5937  1.5989  1.6165  1.7517  1.7889
# 2 2026-02-11            中债国债收益率曲线  1.3299  1.3175  1.3141  1.3788  1.5435
#
#     year7  year10  year30
# 0  2.1327  2.3009     NaN
# 1  2.0013  2.1948  2.4947
# 2  1.6479  1.7994  2.2455
