# %% [markdown]
# # Chinese (Mainland) Stock Index Data - Market Data - Analytical Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. SW Stock Index Market Data

# %%
dai.query("""
SELECT *
FROM cn_stock_swhy_index_bar1d
WHERE date = '2026-01-05'
""").df()
# Out:
#     instrument          name index_type       date  first_close  pre_close  \
# 0       801001          申万50       市场表征 2026-01-05          NaN        NaN
# 1       801002          申万中小       市场表征 2026-01-05          NaN        NaN
# 2       801003          申万Ａ指       市场表征 2026-01-05          NaN        NaN
# ..         ...           ...        ...        ...          ...        ...
# 181     802610  华夏理财数字基础设施指数       金创指数 2026-01-05      2869.11    2912.18
# 182     802611    华夏理财水力发电指数       金创指数 2026-01-05      2412.33    2424.40
# 183     802612    华夏理财先进农业指数       金创指数 2026-01-05      1934.66    1954.23
#
#         open     high      low    close    volume   amount  change_ratio  \
# 0    3823.86  3890.22  3823.86  3883.43   3170.39    46.75        0.0254
# 1    8260.69  8354.48  8260.69  8354.48   5147.95   343.64        0.0184
# 2    4667.72  4732.08  4667.72  4732.08  25399.59  1425.64        0.0202
# ..       ...      ...      ...      ...       ...      ...           ...
# ...

# %% [markdown]
# ## 2. SW Stock Index Analytical Reports

# %% [markdown]
# ### 2.1 SW Stock Index Analytical - Daily

# %%
dai.query("""
SELECT *
FROM cn_stock_industry_analysis_daily
WHERE date = '2026-01-05'
""").df()
# Out:
#     instrument   name index_type       date  closing_index   volume  \
# 0       801001   申万50       市场表征 2026-01-05        3883.43    46.75
# 1       801002   申万中小       市场表征 2026-01-05        8354.48   343.64
# 2       801003   申万Ａ指       市场表征 2026-01-05        4732.08  1425.64
# ..         ...    ...        ...        ...            ...      ...
# 185     801993  旅游及景区       二级行业 2026-01-05        2476.57     4.72
# 186     801994     教育       二级行业 2026-01-05        2431.12     7.84
# 187     801995  电视广播Ⅱ       二级行业 2026-01-05        1245.04     7.74
#
#      change_ratio  turnover_ratio  pe_ratio  pb_ratio  average_price  \
# 0          0.0254          0.0223     19.69      2.76         177.52
# 1          0.0184          0.0596     29.87      2.81          17.24
# 2          0.0202          0.0461     21.47      2.15          26.01
# ..            ...             ...       ...       ...            ...
# 185       -0.0095          0.0566     54.52      3.10          14.98
# ...

# %% [markdown]
# ### 2.2 SW Stock Index Analytical - Weekly

# %%
dai.query("""
SELECT *
FROM cn_stock_industry_analysis_weekly
WHERE date = '2026-01-09'
""").df()
# Out:
#     instrument   name index_type       date  closing_index   volume  \
# 0       801001   申万50       市场表征 2026-01-09        3880.85   243.64
# 1       801002   申万中小       市场表征 2026-01-09        8651.25  1926.08
# 2       801003   申万Ａ指       市场表征 2026-01-09        4878.75  7981.59
# ..         ...    ...        ...        ...            ...      ...
# 185     801993  旅游及景区       二级行业 2026-01-09        2518.18    21.83
# 186     801994     教育       二级行业 2026-01-09        2552.41    41.51
# 187     801995  电视广播Ⅱ       二级行业 2026-01-09        1405.25    44.58
#
#      change_ratio  turnover_ratio  pe_ratio  pb_ratio  average_price  \
# 0          0.0247          0.1161     19.68      2.76         180.04
# 1          0.0546          0.3340     30.92      2.91          17.94
# 2          0.0518          0.2580     22.07      2.22          27.24
# ..            ...             ...       ...       ...            ...
# 185        0.0072          0.2619     55.44      3.15          15.26
# ...

# %% [markdown]
# ### 2.1 SW Stock Index Analytical - Monthly

# %%
dai.query("""
SELECT *
FROM cn_stock_industry_analysis_monthly
WHERE date = '2026-01-30'
""").df()
# Out:
#     instrument   name index_type       date  closing_index    volume  \
# 0       801001   申万50       市场表征 2026-01-30        3806.17   1085.71
# 1       801002   申万中小       市场表征 2026-01-30        8642.65   7945.67
# 2       801003   申万Ａ指       市场表征 2026-01-30        4911.48  34391.50
# ..         ...    ...        ...        ...            ...       ...
# 185     801993  旅游及景区       二级行业 2026-01-30        2602.61    104.89
# 186     801994     教育       二级行业 2026-01-30        2410.36    174.43
# 187     801995  电视广播Ⅱ       二级行业 2026-01-30        1344.80    205.46
#
#      change_ratio  turnover_ratio  pe_ratio  pb_ratio  average_price  \
# 0          0.0050          0.5172     19.32      2.71         176.58
# 1          0.0535          1.3750     30.92      2.91          18.05
# 2          0.0589          1.1109     22.34      2.24          27.70
# ..            ...             ...       ...       ...            ...
# ...
