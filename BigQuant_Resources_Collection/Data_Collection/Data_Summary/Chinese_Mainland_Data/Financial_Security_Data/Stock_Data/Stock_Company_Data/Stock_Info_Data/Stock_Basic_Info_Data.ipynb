# %% [markdown]
# # Chinese (Mainland) Stock Data - Information Data - Basic Information

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_stock_basic_info
WHERE instrument = '600519.SH'
""").df()
# Out:
#   instrument  name    full_name                   en_name used_name  \
# 0  600519.SH  贵州茅台  贵州茅台酒股份有限公司  Kweichow Moutai Co.,Ltd.  贵州茅台→G茅台
#
#   instrument_b name_b instrument_hk name_hk exchange  list_sector  \
# 0         None   None          None    None  上海证券交易所            1
#
#   security_type         industry office_addr regster_addr  register_captial  \
# 0       上交所主板A股  制造业-酒、饮料和精制茶制造业   贵州省仁怀市茅台镇    贵州省仁怀市茅台镇         125619.78
#
#    nums_employees  nums_managers    law_firm        account_firm  \
# 0         31413.0           15.0  北京市金杜律师事务所  天职国际会计师事务所(特殊普通合伙)
#
#                                              profile estab_date  list_date  \
# 0      贵州茅台酒股份有限公司(以下简称“公司”)成立于1999年11月20日,由中国贵州茅... 1999-11-20 2001-08-27
#
#   delist_date online_list  ipo_price    ipo_nums  ipo_pe  ipo_parvalue  \
# 0         NaT  2001-07-31      31.39  71500000.0   23.93           1.0
#
#    net_amount_funds  offline_dtor     dtor  f_open  f_high  f_close  \
# 0      2.202174e+09           NaN  1.13057   34.51   37.78    35.55
#
#    f_turnover corp_nature corp_scale
# 0     56.8277      省属国资控股       大型企业
