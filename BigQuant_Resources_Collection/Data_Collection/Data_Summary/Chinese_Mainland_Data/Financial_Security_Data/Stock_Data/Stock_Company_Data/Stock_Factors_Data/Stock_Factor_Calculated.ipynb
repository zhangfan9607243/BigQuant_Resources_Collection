# %% [markdown]
# # Chinese (Mainland) Stock Data - Factor Data - Calculated Factors

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Technical Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_ta
WHERE date <= '2026-02-13'
AND instrument = '600519.SH'
QUALIFY date = '2026-02-13'
""").df()
# Out:
#         date instrument         sma_5        sma_10        sma_20  \
# 0 2026-02-13  600519.SH  12680.607447  12672.954472  12091.028525
#
#          sma_60      sma_120       sma_250         ema_5        ema_10  \
# 0  11962.512053  12053.93711  12173.888242  12625.124047  12531.966332
#
#          ema_20        ema_60       ema_120       ema_250         wma_5  \
# 0  12306.007302  12062.150928  12046.467834  12123.693606  12625.690736
#
#          wma_10        wma_20        wma_60       wma_120      wma_250  \
# 0  12700.788078  12386.511343  12027.217231  12012.187716  12069.93595
#
#    macd_diff_5_20_5  macd_diff_8_34_7  macd_diff_12_26_9  macd_diff_10_50_10  \
# 0        319.116744         429.88635         255.117256          449.190362
#
#    macd_dea_5_20_5  macd_dea_8_34_7  macd_dea_12_26_9  macd_dea_10_50_10  \
# 0       403.420432       403.368246        199.913649         309.284645
#
#    macd_hist_5_20_5  macd_hist_8_34_7  macd_hist_12_26_9  macd_hist_10_50_10  \
# 0       -168.607376         53.036208         110.407214          279.811435
#
#     bias_5   bias_10   bias_20   bias_60  bias_120  bias_250  kdj_rsv_9_3_3  \
# 0 -0.01059 -0.009993  0.037655  0.048803  0.040848  0.030592       0.338241
#
#    kdj_rsv_14_3_3  kdj_rsv_5_3_3  kdj_rsv_10_3_6  kdj_rsv_20_5_5  kdj_k_9_3_3  \
# 0        0.663807       0.203596         0.47116        0.663807    54.681772
#
#    kdj_k_14_3_3  kdj_k_5_3_3  kdj_k_10_3_6  kdj_k_20_5_5  kdj_d_9_3_3  \
# 0     71.622678    29.491161      61.61452     71.306353    66.500428
#
#    kdj_d_14_3_3  kdj_d_5_3_3  kdj_d_10_3_6  kdj_d_20_5_5  kdj_j_9_3_3  \
# 0     74.779894    44.257038     66.066914     65.984576     31.04446
#
#    kdj_j_14_3_3  kdj_j_5_3_3  kdj_j_10_3_6  kdj_j_20_5_5      rsi_6    rsi_12  \
# 0     65.308244    -0.040592     52.709732     81.949907  52.509135  57.52649
#
#       rsi_24    rsi_48     rsi_60    rsi_120  bbands_middle_5_1d5  \
# 0  56.785515  54.49379  53.719627  51.677137         12680.607447
#
#    bbands_middle_10_1d5  bbands_middle_20_1d5  bbands_middle_5_2  \
# 0          12672.954472          12091.028525       12680.607447
#
#    bbands_middle_10_2  bbands_middle_20_2  bbands_middle_5_2d5  \
# 0        12672.954472        12091.028525         12680.607447
#
#    bbands_middle_10_2d5  bbands_middle_20_2d5  bbands_upper_5_1d5  \
# 0          12672.954472          12091.028525        12864.505468
#
#    bbands_upper_10_1d5  bbands_upper_20_1d5  bbands_upper_5_2  \
# 0         13091.136136         13059.510279      12925.804809
#
#    bbands_upper_10_2  bbands_upper_20_2  bbands_upper_5_2d5  \
# 0       13230.530024       13382.337531         12987.10415
#
#    bbands_upper_10_2d5  bbands_upper_20_2d5  bbands_lower_5_1d5  \
# 0         13369.923912         13705.164782        12496.709425
#
#    bbands_lower_10_1d5  bbands_lower_20_1d5  bbands_lower_5_2  \
# 0         12254.772808         11122.546771      12435.410085
#
#    bbands_lower_10_2  bbands_lower_20_2  bbands_lower_5_2d5  \
# 0        12115.37892       10799.719519        12374.110744
#
#    bbands_lower_10_2d5  bbands_lower_20_2d5  trix_5_3  trix_7_4  trix_12_9  \
# 0         11975.985032         10476.892268  0.619012  0.727465   0.189744
#
#    trix_20_12  trix_60_20      cci_5     cci_14     cci_20    cci_30  \
# 0   -0.010188   -0.021675 -82.525979  28.755954  54.970464  83.61475
#
#       cci_60     cci_120          obv      maobv_6      maobv_14     maobv_20  \
# 0  146.51708  142.846043  648593534.0  657162653.5  6.479789e+08  641496336.4
#
#       maobv_30      maobv_60       atr_6      atr_14      atr_20      atr_30  \
# 0  645631000.5  6.529123e+08  314.027506  285.160672  260.067488  233.133976
#
#        atr_60
# 0  203.713591

# %% [markdown]
# ## 2. A101 Factor

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_alpha_101
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  alpha_001  alpha_002  alpha_003  alpha_004  \
# 0 2026-02-13  600519.SH  -0.325881  -0.346045   0.531646  -0.888889
#
#    alpha_005  alpha_006  alpha_007  alpha_008   alpha_009  alpha_010  \
# 0   -0.99817   0.296794       -1.0  -0.999633  712.081423        1.0
#
#    alpha_011  alpha_012  alpha_013  alpha_014  alpha_015  alpha_016  \
# 0   0.001383  -10.98109  -0.254212   0.219171  -1.952816  -0.195788
#
#    alpha_017  alpha_018  alpha_019     alpha_020  alpha_021  alpha_022  \
# 0  -0.200629  -0.998165   -1.99918 -12562.401379        1.0   0.443119
#
#    alpha_023    alpha_024  alpha_025  alpha_026  alpha_027  alpha_028  \
# 0   52.37135 -1365.118372   0.337415  -0.592927        1.0   0.003198
#
#    alpha_029  alpha_030  alpha_031  alpha_032  alpha_033  alpha_034  \
# 0   0.600275   0.130213   0.996142  15.845876   0.348374   0.802706
#
#    alpha_035  alpha_036  alpha_037  alpha_038  alpha_039  alpha_040  \
# 0    0.06189   4.152968   1.472762  -0.251169  -0.003819  -0.073823
#
#       alpha_041  alpha_042  alpha_043  alpha_044  alpha_045  alpha_046  \
# 0  11086.704526   0.001097       0.15   -0.96984  -0.258628       -1.0
#
#    alpha_047  alpha_048  alpha_049  alpha_050  alpha_051  alpha_052  \
# 0   0.000351  -0.007039   10.98109        NaN   10.98109 -42.999002
#
#    alpha_053  alpha_054  alpha_055  alpha_056     alpha_057  alpha_058  \
# 0   8.117246   -0.39722   -0.55644  -0.080357 -14015.256085       -4.0
#
#    alpha_059  alpha_060  alpha_061  alpha_062  alpha_063  alpha_064  \
# 0     -0.125   -0.00041        0.0        0.0  -0.251275        0.0
#
#    alpha_065  alpha_066  alpha_067  alpha_068  alpha_069  alpha_070  \
# 0       -1.0  -1.333333  -0.999805        0.0  -0.008392  -0.998707
#
#    alpha_071  alpha_072  alpha_073  alpha_074  alpha_075  alpha_076  \
# 0        1.0   0.994472    -0.8125        0.0        1.0  -0.631579
#
#    alpha_077  alpha_078  alpha_079  alpha_080  alpha_081  alpha_082  \
# 0   0.933063        NaN        1.0  -0.713474        0.0  -0.538462
#
#       alpha_083      alpha_084  alpha_085  alpha_086  alpha_087  alpha_088  \
# 0 -19593.487006  2.055737e+133   0.460055       -1.0  -0.999269   0.367644
#
#    alpha_089  alpha_090  alpha_091  alpha_092  alpha_093  alpha_094  \
# 0  -0.533333  -0.113538  -0.989713   0.666667   4.171481  -0.999633
#
#    alpha_095  alpha_096  alpha_097  alpha_098  alpha_099  alpha_100  alpha_101
# 0        0.0  -0.384615   0.001292   0.471925        0.0  -0.000263  -0.034927

# %% [markdown]
# ## 3. High-Frequency Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_hf
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  hf_buy_trades_exlarge_order_act  \
# 0 2026-02-13  600519.SH                            160.0
#
#    hf_buy_trades_large_order_act  hf_buy_trades_med_order_act  \
# 0                         2009.0                      13889.0
#
#    hf_buy_trades_small_order_act  hf_buy_value_act  \
# 0                           33.0      3.130881e+09
#
#    hf_buy_value_exlarge_order  hf_buy_value_exlarge_order_act  \
# 0                2.582086e+09                    2.922021e+08
#
#    hf_buy_value_large_order  hf_buy_value_large_order_act  \
# 0              3.838640e+09                  7.723042e+08
#
#    hf_buy_value_med_order  hf_buy_value_med_order_act  \
# 0            4.577921e+09                2.065474e+09
#
#    hf_buy_value_small_order  hf_buy_value_small_order_act  hf_buy_volume_act  \
# 0                  82256.25                 900871.690674          2098582.0
#
#    hf_buy_volume_exlarge_order  hf_buy_volume_exlarge_order_act  \
# 0                    1747501.0                         195700.0
#
#    hf_buy_volume_large_order  hf_buy_volume_large_order_act  \
# 0                  2575177.0                       517997.0
#
#    hf_buy_volume_med_order  hf_buy_volume_med_order_act  \
# 0                3079214.0                    1384283.0
#
#    hf_buy_volume_small_order  hf_buy_volume_small_order_act  \
# 0                       55.0                          602.0
#
#    hf_close_buy_volume_exlarge_order  hf_close_buy_volume_exlarge_order_act  \
# 0                           191900.0                                22100.0
#
#    hf_close_buy_volume_large_order  hf_close_buy_volume_large_order_act  \
# 0                         303700.0                              97119.0
#
#    hf_close_buy_volume_med_order  hf_close_buy_volume_med_order_act  \
# 0                       448113.0                           168081.0
#
#    hf_close_buy_volume_small_order  hf_close_buy_volume_small_order_act  \
# 0                              0.0                                 84.0
#
#    hf_close_net_inflow_value  hf_close_net_inflow_value_rate  \
# 0              -5.165170e+06                       -0.006013
#
#    hf_close_net_inflow_volume  hf_close_net_inflow_volume_rate  \
# 0                     -3520.0                        -0.006087
#
#    hf_close_netinflow_rate_exlarge_order_act  \
# 0                                  -0.004342
#
#    hf_close_netinflow_rate_large_order_act  \
# 0                                 0.037064
#
#    hf_close_netinflow_rate_med_order_act  \
# 0                              -0.038716
#
#    hf_close_netinflow_rate_small_order_act  \
# 0                                -0.000019
#
#    hf_close_sell_volume_exlarge_order  hf_close_sell_volume_exlarge_order_act  \
# 0                            234810.0                                 24600.0
#
#    hf_close_sell_volume_large_order  hf_close_sell_volume_large_order_act  \
# 0                          362003.0                               75698.0
#
#    hf_close_sell_volume_med_order  hf_close_sell_volume_med_order_act  \
# 0                        204908.0                            190511.0
#
#    hf_close_sell_volume_small_order  hf_close_sell_volume_small_order_act  \
# 0                              96.0                                  95.0
#
#    hf_amount_auction_am_ratio  hf_buy_orders_exlarge_order  \
# 0                         0.0                        898.0
#
#    hf_buy_orders_large_order  hf_buy_orders_med_order  \
# 0                    10263.0                  30797.0
#
#    hf_buy_orders_small_order  hf_close_volume_ask  hf_close_volume_bid  \
# 0                        4.0             801817.0             943713.0
#
#    hf_continuous_volume_ratio  hf_corr_vp_1  hf_corr_vp_10  hf_corr_vp_11  \
# 0                    0.982617      0.748935        -0.1416      -0.203485
#
#    hf_corr_vp_12  hf_corr_vp_13  hf_corr_vp_2  hf_corr_vp_3  hf_corr_vp_4  \
# 0       0.239259       0.264453      -0.20997     -0.404756     -0.415028
#
#    hf_corr_vp_5  hf_corr_vp_6  hf_corr_vp_7  hf_corr_vp_8  hf_corr_vp_9  \
# 0     -0.128575     -0.218948      -0.11611     -0.215821     -0.475008
#
#    hf_cross_night_chg  hf_last_price_stage1  hf_last_price_stage2  \
# 0                 0.0           1486.599976           1486.589966
#
#    hf_net_inflow_value  hf_net_inflow_value_rate  hf_net_inflow_volume  \
# 0         4.538335e+07                  0.007301               29263.0
#
#    hf_net_inflow_volume_rate  hf_netinflow_rate_exlarge_order_act  \
# 0                   0.007021                            -0.012393
#
#    hf_netinflow_rate_large_order_act  hf_netinflow_rate_med_order_act  \
# 0                          -0.006723                         0.026394
#
#    hf_netinflow_rate_small_order_act  hf_num_trades  \
# 0                           0.000022        31172.0
#
#    hf_open_buy_volume_exlarge_order  hf_open_buy_volume_exlarge_order_act  \
# 0                          599700.0                               75100.0
#
#    hf_open_buy_volume_large_order  hf_open_buy_volume_large_order_act  \
# 0                        568710.0                            150233.0
#
#    hf_open_buy_volume_med_order  hf_open_buy_volume_med_order_act  \
# 0                      793235.0                          336560.0
#
#    hf_open_buy_volume_small_order  hf_open_buy_volume_small_order_act  \
# 0                            20.0                                42.0
#
#    hf_open_max_cng_stage1  hf_open_max_cng_stage2  hf_open_min_cng_stage1  \
# 0                    -1.0                    -1.0                     NaN
#
#    hf_open_min_cng_stage2  hf_open_net_inflow_value  \
# 0                    -1.0              6.392243e+07
#
#    hf_open_net_inflow_value_rate  hf_open_net_inflow_volume  \
# 0                       0.039835                    42625.0
#
#    hf_open_net_inflow_volume_rate  hf_open_netinflow_rate_exlarge_order_act  \
# 0                        0.039422                                  0.015611
#
#    hf_open_netinflow_rate_large_order_act  \
# 0                               -0.006801
#
#    hf_open_netinflow_rate_med_order_act  \
# 0                               0.03106
#
#    hf_open_netinflow_rate_small_order_act  hf_open_sell_volume_exlarge_order  \
# 0                               -0.000035                           527988.0
#
#    hf_open_sell_volume_exlarge_order_act  hf_open_sell_volume_large_order  \
# 0                                58300.0                         662123.0
#
#    hf_open_sell_volume_large_order_act  hf_open_sell_volume_med_order  \
# 0                             157680.0                       705747.0
#
#    hf_open_sell_volume_med_order_act  hf_open_sell_volume_small_order  \
# 0                           303250.0                             75.0
#
#    hf_open_sell_volume_small_order_act  hf_open_volume_ask  \
# 0                                 80.0           1895933.0
#
#    hf_open_volume_bid  hf_price_avg_stage2  hf_price_chg_abs_stage2  \
# 0           1961665.0          1486.599487                  0.01001
#
#    hf_price_chg_stage1  hf_price_chg_stage2  hf_price_decrease_stage2  \
# 0                  1.0             0.999993                         1
#
#    hf_price_increase_stage2  hf_price_max_stage2  hf_price_min_stage2  \
# 0                         0          1486.599976          1486.589966
#
#    hf_price_pct_chg_stage2  hf_price_range_stage1  hf_price_range_stage2  \
# 0                -0.000007            1486.599976                0.01001
#
#    hf_ratio_realdownstd  hf_ratio_realupstd  hf_ratio_volume_1  \
# 0              0.584956            0.669056           0.077846
#
#    hf_ratio_volume_10  hf_ratio_volume_12  hf_ratio_volume_13  \
# 0            0.399315            0.178608            0.158655
#
#    hf_ratio_volume_2  hf_ratio_volume_3  hf_ratio_volume_4  hf_ratio_volume_5  \
# 0           0.165084           0.259326           0.422077            0.24066
#
#    hf_ratio_volume_6  hf_ratio_volume_7  hf_ratio_volume_8  hf_ratio_volume_9  \
# 0           0.138844           0.067249           0.020694           0.600685
#
#    hf_real_downstd  hf_real_downvar  hf_real_kurtosis  hf_real_kurtosis_3  \
# 0         0.000622     3.869766e-07         14.645852            3.727261
#
#    hf_real_kurtosis_5m  hf_real_kurtosis_6  hf_real_skew  hf_real_skew_3  \
# 0             4.902176           -0.580339      0.654901        -1.53135
#
#    hf_real_skew_5m  hf_real_skew_6  hf_real_std  hf_real_std_3  \
# 0         0.059665       -0.294683     0.001063        0.00191
#
#    hf_real_std_5m  hf_real_std_6  hf_real_upstd  hf_real_upvar  hf_real_var  \
# 0        0.002412       0.000677       0.000712   5.062487e-07     0.000001
#
#    hf_real_var_3  hf_real_var_5m  hf_real_var_6  hf_ret_in_1  hf_ret_in_10  \
# 0       0.000004        0.000006   4.584125e-07    -0.008657     -0.005164
#
#    hf_ret_in_11  hf_ret_in_12  hf_ret_in_13  hf_ret_in_2  hf_ret_in_3  \
# 0     -0.000874     -0.007848     -0.003362    -0.000202     0.004493
#
#    hf_ret_in_4  hf_ret_in_5  hf_ret_in_6  hf_ret_in_7  hf_ret_in_8  \
# 0     0.012384    -0.001136     0.001126     0.000957      0.00029
#
#    hf_ret_in_9  hf_sell_orders_exlarge_order  hf_sell_orders_large_order  \
# 0     0.004312                        1091.0                      8332.0
#
#    hf_sell_orders_med_order  hf_sell_orders_small_order  \
# 0                   24926.0                        31.0
#
#    hf_sell_trades_exlarge_order_act  hf_sell_trades_large_order_act  \
# 0                             186.0                          2046.0
#
#    hf_sell_trades_med_order_act  hf_sell_trades_small_order_act  \
# 0                       12818.0                            31.0
#
#    hf_sell_value_act  hf_sell_value_exlarge_order  \
# 0       3.085498e+09                 2.242814e+09
#
#    hf_sell_value_exlarge_order_act  hf_sell_value_large_order  \
# 0                     3.692406e+08               3.493358e+09
#
#    hf_sell_value_large_order_act  hf_sell_value_med_order  \
# 0                   8.140948e+08             3.731216e+09
#
#    hf_sell_value_med_order_act  hf_sell_value_small_order  \
# 0                 1.901399e+09              734715.430176
#
#    hf_sell_value_small_order_act  hf_sell_volume_act  \
# 0                  763371.760864           2069319.0
#
#    hf_sell_volume_exlarge_order  hf_sell_volume_exlarge_order_act  \
# 0                     1492720.0                          246930.0
#
#    hf_sell_volume_large_order  hf_sell_volume_large_order_act  \
# 0                   2338594.0                        546092.0
#
#    hf_sell_volume_med_order  hf_sell_volume_med_order_act  \
# 0                 2490614.0                     1275787.0
#
#    hf_sell_volume_small_order  hf_sell_volume_small_order_act  \
# 0                       480.0                           510.0
#
#    hf_tot_volume_ask  hf_tot_volume_bid  hf_trend_str_1  hf_trend_str_10  \
# 0          6322408.0          7401947.0       -0.625927        -0.206147
#
#    hf_trend_str_11  hf_trend_str_12  hf_trend_str_13  hf_trend_str_2  \
# 0         0.009475         -0.26047        -0.359885        0.080607
#
#    hf_trend_str_3  hf_trend_str_4  hf_trend_str_5  hf_trend_str_6  \
# 0        0.170992        0.222796       -0.053726       -0.008269
#
#    hf_trend_str_7  hf_trend_str_8  hf_trend_str_9  \
# 0       -0.087892        0.636444         0.07118
#
#    hf_value_diff_exlarge_order  hf_value_diff_exlarge_order_act  \
# 0                 3.392723e+08                    -7.703850e+07
#
#    hf_value_diff_large_order  hf_value_diff_large_order_act  \
# 0               3.452814e+08                  -4.179054e+07
#
#    hf_value_diff_med_order  hf_value_diff_med_order_act  \
# 0             8.467054e+08                 1.640749e+08
#
#    hf_value_diff_small_order  hf_value_diff_small_order_act  \
# 0             -652459.180176                   137499.92981
#
#    hf_value_exlarge_order_ratio  hf_value_large_order_ratio  \
# 0                      0.106403                    0.255197
#
#    hf_value_med_order_ratio  hf_value_small_order_ratio  \
# 0                  0.638132                    0.000268
#
#    hf_volume_auction_am_ratio  hf_volume_diff_exlarge_order  \
# 0                         0.0                      254781.0
#
#    hf_volume_diff_exlarge_order_act  hf_volume_diff_large_order  \
# 0                          -51230.0                    236583.0
#
#    hf_volume_diff_large_order_act  hf_volume_diff_med_order  \
# 0                        -28095.0                  588600.0
#
#    hf_volume_diff_med_order_act  hf_volume_diff_small_order  \
# 0                      108496.0                      -425.0
#
#    hf_volume_diff_small_order_act  hf_volume_kurtosis  hf_volume_kurtosis_5m  \
# 0                            92.0            7.482413               6.162112
#
#    hf_volume_ratio_stage1  hf_volume_ratio_stage2  hf_volume_skew  \
# 0                0.001488                0.005614        2.451175
#
#    hf_volume_skew_5m  hf_volume_std  hf_volume_std_5m  hf_volume_var  \
# 0            2.08793   14143.299946      55202.447117   2.000329e+08
#
#    hf_volume_var_5m
# 0      3.047310e+09

# %%
dai.query("""
SELECT *
FROM hf_alpha_fzzq
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#   instrument       date  alpha_91008  alpha_91009  alpha_91010  alpha_91011  \
# 0  600519.SH 2026-02-13     0.079017    -0.932693     0.000655     0.000327
#
#    alpha_91007  alpha_91001  alpha_91002  alpha_91003  alpha_91004  \
# 0    -0.441468     3.343201      1.09858     0.412402     0.221665
#
#    alpha_91005  alpha_91006  alpha_91018  alpha_91019  alpha_91020  \
# 0     0.669395    -0.499004    -0.218747     0.002588    -0.319665
#
#    alpha_91021  alpha_91012  alpha_91013  alpha_91014  alpha_91015  \
# 0    -2.488354     1.095388     1.041195     0.666756    -1.832909
#
#    alpha_91016  alpha_91017  alpha_91022  alpha_91023  alpha_91024  \
# 0     0.114607     2.219267    -1.281637    -1.345233    -0.550075
#
#    alpha_91025  alpha_91038  alpha_91039  alpha_91040  alpha_91041  \
# 0       -0.212     0.370848     0.424315     1.369992     3.535147
#
#    alpha_91026  alpha_91027  alpha_91028  alpha_91028_1  alpha_91038_1  \
# 0    -0.458053      0.37816  3097.221573   -2018.001066       73.77731
#
#    alpha_91039_1  alpha_91040_1  alpha_91041_1  alpha_91042  alpha_91043  \
# 0       0.000355      82.348841       0.000431     16.08921    -0.522801
#
#    alpha_91044
# 0    15.566409

# %%
dai.query("""
SELECT *
FROM hf_alpha_gfzq
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#   instrument  ret_intraday       date  real_var  real_kurtosis  real_skewness  \
# 0  600519.SH     -0.000874 2026-02-13  0.000001      14.584871        0.74107
#
#      real_upvar  real_downvar  ratio_realupvar  ratio_realdownvar  trendratio  \
# 0  7.933934e-07  4.883331e-07         0.717181           0.441425   -0.005249
#
#    ratio_volumeH1  ratio_volumeH2  ratio_volumeH3  ratio_volumeH4  \
# 0        0.259326        0.169421        0.113563        0.071859
#
#    ratio_volumeH5  ratio_volumeH6  ratio_volumeH7  ratio_volumeH8   corr_VP  \
# 0        0.084167        0.076647         0.10376        0.142779 -0.203485
#
#     corr_VR  corr_VRlag  corr_VRlead    ret_H1  ret_close2H1  corr_VPH1  \
# 0  0.060716   -0.352168    -0.102086  1.004494      0.996044  -0.404756
#
#    corr_VRH1  corr_VRlagH1  corr_VRleadH1  real_varH1  real_kurtosisH1  \
# 0  -0.415741     -0.511046       -0.52547    0.000003         3.839653
#
#    real_skewnessH1  corr_VPH8  corr_VRH8  corr_VRlagH8  corr_VRleadH8  \
# 0        -1.547222  -0.190807  -0.044335     -0.239284      -0.451878
#
#      real_varH8  real_kurtosisH8  real_skewnessH8  amountbuy_xlarge  \
# 0  5.802536e-07        -0.384248        -0.320533      2.582086e+09
#
#    amountsell_xlarge  amountbuy_large  amountsell_large  amountbuy_med  \
# 0       2.242814e+09     3.838640e+09      3.493358e+09   4.577921e+09
#
#    amountsell_med  amountbuy_small  amountsell_small  amountdiff_xlarge  \
# 0    3.731216e+09     82256.250977     734715.431641       3.392723e+08
#
#    amountdiff_large  amountdiff_med  amountdiff_small
# 0      3.452814e+08    8.467054e+08    -652459.180664

# %%
dai.query("""
SELECT *
FROM hf_alpha_htzq
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#    alpha_92087  alpha_92088  alpha_92089  alpha_92090  alpha_92091  \
# 0    -0.000005     0.000089     0.717486     0.000027     0.000153
#
#    alpha_92092  alpha_92093  alpha_92094  alpha_92095  alpha_92096  \
# 0    -0.070965     -0.00001     0.000075     1.079122    -0.000013
#
#    alpha_92097  alpha_92098  alpha_92099  alpha_92100  alpha_92101  \
# 0     0.000077    -0.191064    -0.000006     0.000146    -0.319601
#
#    alpha_92102  alpha_92103  alpha_92104  alpha_92105  alpha_92106  \
# 0    -0.000016      0.00022    -0.171781    -0.000002     0.000121
#
#    alpha_92107  alpha_92108  alpha_92109  alpha_92027  alpha_92028  \
# 0    -0.036483    -0.000023     0.000144     0.002168     0.303168
#
#    alpha_92029  alpha_92030  alpha_92031  alpha_92032  alpha_92033  \
# 0    -0.010527     0.002523     0.297144     0.029768    -0.074781
#
#    alpha_92034  alpha_92001  alpha_92002  alpha_92003  alpha_92004  \
# 0     0.007022    -0.003673     0.714723     0.435974    -0.203485
#
#    alpha_92005  alpha_92006  alpha_92007  alpha_92008  alpha_92009  \
# 0     1.032961     0.142779     0.025939      0.03985     0.116766
#
#    alpha_92010  alpha_92011  alpha_92012  alpha_92013  alpha_92014  \
# 0     0.724861     1.025203      0.50365     0.000622    -0.026297
#
#    alpha_92015  alpha_92016  alpha_92017  alpha_92018  alpha_92019  \
# 0     0.493568     0.039021     0.994465     0.135422    -0.014406
#
#    alpha_92020  alpha_92021  alpha_92022  alpha_92023  alpha_92024  \
# 0    -0.003154     0.006153     0.593158     1.214298     0.508248
#
#    alpha_92025  alpha_92026  alpha_92063  alpha_92064  alpha_92065  \
# 0     1.005373    -0.047812     0.000001     0.673049    15.242882
#
#    alpha_92066  alpha_92067  alpha_92068  alpha_92069  alpha_92070  \
# 0     0.000005     1.468503      3.22237     0.000002     0.376901
#
#    alpha_92071  alpha_92072  alpha_92073  alpha_92074   alpha_92075  \
# 0     9.253043     0.000005     1.599355     3.541771  9.796535e-07
#
#    alpha_92076  alpha_92077  alpha_92078  alpha_92079  alpha_92080  \
# 0    -0.125137     4.332951     0.000004     0.234315     2.245082
#
#    alpha_92081  alpha_92082  alpha_92083  alpha_92084  alpha_92085  \
# 0     0.000001    -0.101839     1.883463     0.000006     0.258896
#
#    alpha_92086       date instrument
# 0     0.872012 2026-02-13  600519.SH

# %%
dai.query("""
SELECT *
FROM hf_alpha_kyzq
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  alpha_93031  alpha_93032  alpha_93033  alpha_93036  \
# 0 2026-02-13  600519.SH   -122.80913     0.365159     0.049945  5968.564076
#
#    alpha_93037  alpha_93038  alpha_93035  alpha_93034  alpha_93014  \
# 0    -1.255426     1.805654     1.229114    -0.007823          NaN
#
#    alpha_93015  alpha_93016
# 0          NaN          NaN

# %% [markdown]
# ## 4. AI Model Synthetic Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_ai
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument    vp_cnn    vp_dnn    vp_gru  vp_lightgbm   vp_lstm  \
# 0 2026-02-13  600519.SH -0.026331 -0.003723 -0.026764    -0.037372 -0.128611
#
#    vp_randomforest  vp_resnet    vp_rnn  vp_stockranker  vp_xgboost
# 0          0.31921  -0.014905 -0.014454       -0.243647   -0.018027

# %% [markdown]
# ## 5. Style Factors

# %%
dai.query("""
SELECT *
FROM cn_stock_factors_style_bq
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  DIVIDEND  FUNDAMENTAL  QUALITY    GROWTH  VALUATION  \
# 0 2026-02-13  600519.SH       NaN         36.0      NaN -3.155243  20.660356
#
#    VOLATILITY    ADJMOM  BETA_399001  BETA_399006  BETA_000903  BETA_000300  \
# 0    0.012422 -3.700146      3.41172     5.658524      1.79081     1.647263
#
#    BETA_399330  BETA_000688  BETA_000985  BETA_899050  BETA_000905  \
# 0     2.854902      14.0052     2.673829      8.45191     4.294007
#
#    BETA_000852  BETA_000001  BETA_000016
# 0     4.738052      1.62197     1.132937
