# %% [markdown]
# # Chinese (Mainland) Stock Data - Factor Data - Style Factors

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. CERM (China Equity Risk Model) Risk Factor

# %% [markdown]
# ### 1.1 CERM Factor Exposure

# %%
dai.query("""
SELECT *
FROM cerm_factors_exposure
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 1.2 CERM Factor Return

# %%
dai.query("""
SELECT *
FROM cerm_factors_return
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 1.3 CERM Factor Covariance

# %%
dai.query("""
SELECT *
FROM cerm_factor_covariance
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 1.4 CERM Specific Return

# %%
dai.query("""
SELECT *
FROM cerm_specific_return
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 1.5 CERM Factor Exposure

# %%
dai.query("""
SELECT *
FROM cerm_specific_risk
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ## 2. BQ Risk Factors

# %% [markdown]
# ### 2.1 BQ Factors Exposure

# %%
dai.query("""
SELECT *
FROM factors_exposure
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 2.2 BQ Factors Return

# %%
dai.query("""
SELECT *
FROM factors_return
WHERE date = '2024-12-31'
AND instrument = '600519.SH'
""").df()
