# %% [markdown]
# # Chinese (Mainland) Stock Data - Market Data - Price-Volume Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Daily Price-Volume & Trading Data

# %% [markdown]
# ### 1.1 Daily Trading Record

# %%
dai.query("""
SELECT *
FROM cn_stock_instruments
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  name   type
# 0 2026-02-13  600519.SH  贵州茅台  stock

# %% [markdown]
# ### 1.2 Post-Adjusted Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_bar1d
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  name  adjust_factor     pre_close          open  \
# 0 2026-02-13  600519.SH  贵州茅台       8.446992  12557.298258  12557.298258
#
#           close          high           low   volume  deal_number  \
# 0  12546.317168  12736.374488  12421.977447  4167901        31172
#
#          amount  change_ratio      turn   upper_limit   lower_limit
# 0  6.216379e+09     -0.000874  0.003328  13813.028084  11301.568432

# %% [markdown]
# ### 1.3 Pre-Adjusted Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_real_bar1d
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  name  adjust_factor  pre_close    open   close  \
# 0 2026-02-13  600519.SH  贵州茅台       8.446992     1486.6  1486.6  1485.3
#
#      high      low   volume  deal_number        amount  change_ratio  \
# 0  1507.8  1470.58  4167901        31172  6.216379e+09     -0.000874
#
#        turn  upper_limit  lower_limit
# 0  0.003328      1635.26      1337.94

# %% [markdown]
# ### 1.4 Daily VWAP

# %%
dai.query("""
SELECT *
FROM cn_stock_wap
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  wap_1_buy_volume  wap_1_sell_volume  wap_1_twap_buy  \
# 0 2026-02-13  600519.SH            324455             324455     1477.936157
#
#    wap_1_twap_sell  wap_1_vwap_buy  wap_1_vwap_sell  wap_2_buy_volume  \
# 0      1477.936157     1476.414185      1476.414185            688055
#
#    wap_2_sell_volume  wap_2_twap_buy  wap_2_twap_sell  wap_2_vwap_buy  \
# 0             688055     1481.038696      1481.038696     1480.131592
#
#    wap_2_vwap_sell  wap_3_buy_volume  wap_3_sell_volume  wap_3_twap_buy  \
# 0      1480.131592           1048645            1048645     1485.426514
#
#    wap_3_twap_sell  wap_3_vwap_buy  wap_3_vwap_sell  wap_4_buy_volume  \
# 0      1485.426514     1483.931885      1483.931885           1759175
#
#    wap_4_sell_volume  wap_4_twap_buy  wap_4_twap_sell  wap_4_vwap_buy  \
# 0            1759175     1492.209106      1492.209106     1490.190918
#
#    wap_4_vwap_sell  wap_5_buy_volume  wap_5_sell_volume  wap_5_twap_buy  \
# ...

# %% [markdown]
# ### 1.5 Daily Limit Price

# %%
dai.query("""
SELECT *
FROM cn_stock_limit_price
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  upper_limit  lower_limit
# 0 2026-02-13  600519.SH      1635.26      1337.94

# %% [markdown]
# ### 1.6 Daily Chips Distribution

# %%
dai.query("""
SELECT *
FROM cn_stock_chips_distribution
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#           date instrument    price   chips  chips_ratio     avg_cost  \
# 0   2026-02-13  600519.SH   515.78  150640     0.000120  1548.153788
# 1   2026-02-13  600519.SH   560.44  249985     0.000199  1548.153788
# 2   2026-02-13  600519.SH   564.50  181563     0.000145  1548.153788
# ..         ...        ...      ...     ...          ...          ...
# 346 2026-02-13  600519.SH  2453.35  239093     0.000191  1548.153788
# 347 2026-02-13  600519.SH  2522.85  264146     0.000210  1548.153788
# 348 2026-02-13  600519.SH  2540.40  244654     0.000195  1548.153788
#
#      win_percent  upper_90  lower_90  upper_70  lower_70  concentration
# 0       0.490095   1869.86   1364.29    1729.3   1412.89       0.156322
# 1       0.490095   1869.86   1364.29    1729.3   1412.89       0.156322
# 2       0.490095   1869.86   1364.29    1729.3   1412.89       0.156322
# ..           ...       ...       ...       ...       ...            ...
# ...

# %% [markdown]
# ## 2. Intraday Price-Volume & Trading Data

# %% [markdown]
# ### 2.1 1-min Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_bar1m
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                    date instrument  adjust_factor     open    close     high  \
# 0   2026-01-12 09:25:00  600519.SH       8.446992  1419.10  1419.10  1419.10
# 1   2026-01-12 09:31:00  600519.SH       8.446992  1419.10  1418.05  1422.00
# 2   2026-01-12 09:32:00  600519.SH       8.446992  1418.05  1419.08  1419.29
# ..                  ...        ...            ...      ...      ...      ...
# 238 2026-01-12 14:58:00  600519.SH       8.446992  1424.64  1424.64  1424.64
# 239 2026-01-12 14:59:00  600519.SH       8.446992  1424.64  1424.64  1424.64
# 240 2026-01-12 15:00:00  600519.SH       8.446992  1424.64  1423.23  1424.64
#
#          low  volume        amount
# 0    1419.10   43459  6.167267e+07
# 1    1417.50   83374  1.183186e+08
# 2    1417.10   72300  1.025815e+08
# ..       ...     ...           ...
# 238  1424.64       0  0.000000e+00
# 239  1424.64       0  0.000000e+00
# 240  1423.23   48663  6.925864e+07
#
# [241 rows x 9 columns]

# %%
dai.query("""
SELECT *
FROM cn_stock_bar1m_derived
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                    date    time  trading_day  total_10_bid_volume  \
# 0   2026-01-12 09:31:00   93100     20260112                 3267
# 1   2026-01-12 09:32:00   93200     20260112                 8100
# 2   2026-01-12 09:33:00   93300     20260112                 5600
# ..                  ...     ...          ...                  ...
# 237 2026-01-12 14:58:00  145800     20260112                17400
# 238 2026-01-12 14:59:00  145900     20260112                25600
# 239 2026-01-12 15:00:00  150000     20260112                 7137
#
#      total_10_ask_volume instrument         open        close  deal_number  \
# 0                  12200  600519.SH  1419.099976  1418.050049          740
# 1                  11700  600519.SH  1418.050049  1419.079956          460
# 2                   5100  600519.SH  1419.979980  1421.209961          348
# ..                   ...        ...          ...          ...          ...
# ...

# %% [markdown]
# ### 2.2 5-min Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_bar5m
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                   date instrument  adjust_factor     open    close     high  \
# 0  2026-01-12 09:35:00  600519.SH       8.446992  1419.10  1424.00  1425.00
# 1  2026-01-12 09:40:00  600519.SH       8.446992  1424.00  1423.93  1427.77
# 2  2026-01-12 09:45:00  600519.SH       8.446992  1423.00  1429.58  1431.00
# ..                 ...        ...            ...      ...      ...      ...
# 45 2026-01-12 14:50:00  600519.SH       8.446992  1423.01  1422.96  1423.51
# 46 2026-01-12 14:55:00  600519.SH       8.446992  1423.00  1423.09  1423.70
# 47 2026-01-12 15:00:00  600519.SH       8.446992  1423.29  1423.23  1424.69
#
#         low  volume        amount
# 0   1417.10  320833  4.555990e+08
# 1   1422.05  184417  2.626556e+08
# 2   1423.00  307864  4.395682e+08
# ..      ...     ...           ...
# 45  1422.51   56800  8.081974e+07
# 46  1422.27   74200  1.055789e+08
# 47  1423.23   83763  1.192313e+08
#
# [48 rows x 9 columns]

# %%
dai.query("""
SELECT *
FROM cn_stock_bar5m_derived
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                   date    time  trading_day  total_10_bid_volume  \
# 0  2026-01-12 09:35:00   93500     20260112                11700
# 1  2026-01-12 09:40:00   94000     20260112                 8400
# 2  2026-01-12 09:45:00   94500     20260112                 2000
# ..                 ...     ...          ...                  ...
# 45 2026-01-12 14:50:00  145000     20260112                11900
# 46 2026-01-12 14:55:00  145500     20260112                 5200
# 47 2026-01-12 15:00:00  150000     20260112                 7137
#
#     total_10_ask_volume instrument     open    close  deal_number      low  \
# 0                  4100  600519.SH  1419.10  1424.00         2066  1417.10
# 1                  4200  600519.SH  1424.00  1423.93         1286  1422.05
# 2                  2900  600519.SH  1423.00  1429.58         2090  1423.00
# ..                  ...        ...      ...      ...          ...      ...
# ...

# %% [markdown]
# ### 2.3 15-min Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_bar15m
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                   date instrument  adjust_factor     open    close     high  \
# 0  2026-01-12 09:45:00  600519.SH       8.446992  1419.10  1429.58  1431.00
# 1  2026-01-12 10:00:00  600519.SH       8.446992  1429.09  1419.01  1429.09
# 2  2026-01-12 10:15:00  600519.SH       8.446992  1418.81  1421.99  1423.08
# ..                 ...        ...            ...      ...      ...      ...
# 13 2026-01-12 14:30:00  600519.SH       8.446992  1427.00  1426.04  1427.00
# 14 2026-01-12 14:45:00  600519.SH       8.446992  1426.20  1423.00  1426.75
# 15 2026-01-12 15:00:00  600519.SH       8.446992  1423.01  1423.23  1424.69
#
#         low  volume        amount
# 0   1417.10  813114  1.157823e+09
# 1   1418.50  407400  5.794283e+08
# 2   1418.81  149700  2.127605e+08
# ..      ...     ...           ...
# 13  1425.02  192801  2.749278e+08
# 14  1423.00  177567  2.529407e+08
# 15  1422.27  214763  3.056299e+08
#
# [16 rows x 9 columns]

# %%
dai.query("""
SELECT *
FROM cn_stock_bar15m_derived
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                   date    time  trading_day  total_10_bid_volume  \
# 0  2026-01-12 09:45:00   94500     20260112                 2000
# 1  2026-01-12 10:00:00  100000     20260112                 4700
# 2  2026-01-12 10:15:00  101500     20260112                21700
# ..                 ...     ...          ...                  ...
# 13 2026-01-12 14:30:00  143000     20260112                 1900
# 14 2026-01-12 14:45:00  144500     20260112                 3900
# 15 2026-01-12 15:00:00  150000     20260112                 7137
#
#     total_10_ask_volume instrument     open    close  deal_number      low  \
# 0                  2900  600519.SH  1419.10  1429.58         5442  1417.10
# 1                  3700  600519.SH  1429.09  1419.01         2750  1418.50
# 2                  3500  600519.SH  1418.81  1421.99         1104  1418.81
# ..                  ...        ...      ...      ...          ...      ...
# ...

# %% [markdown]
# ### 2.4 30-min Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_bar30m
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                   date instrument  adjust_factor     open    close     high  \
# 0  2026-01-12 10:00:00  600519.SH       8.446992  1419.10  1419.01  1431.00
# 1  2026-01-12 10:30:00  600519.SH       8.446992  1418.81  1419.02  1423.08
# 2  2026-01-12 11:00:00  600519.SH       8.446992  1419.02  1421.88  1421.88
# ..                 ...        ...            ...      ...      ...      ...
# 5  2026-01-12 14:00:00  600519.SH       8.446992  1426.07  1423.49  1426.10
# 6  2026-01-12 14:30:00  600519.SH       8.446992  1423.80  1426.04  1427.01
# 7  2026-01-12 15:00:00  600519.SH       8.446992  1426.20  1423.23  1426.75
#
#         low   volume        amount
# 0   1417.10  1220514  1.737251e+09
# 1   1418.81   357726  5.082309e+08
# 2   1419.00   212377  3.015430e+08
# ..      ...      ...           ...
# 5   1421.01   341643  4.860254e+08
# 6   1422.80   435901  6.212724e+08
# 7   1422.27   392330  5.585706e+08
#
# [8 rows x 9 columns]

# %%
dai.query("""
SELECT *
FROM cn_stock_bar30m_derived
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                   date    time  trading_day  total_10_bid_volume  \
# 0  2026-01-12 10:00:00  100000     20260112                 4700
# 1  2026-01-12 10:30:00  103000     20260112                13595
# 2  2026-01-12 11:00:00  110000     20260112                 3800
# ..                 ...     ...          ...                  ...
# 5  2026-01-12 14:00:00  140000     20260112                 1400
# 6  2026-01-12 14:30:00  143000     20260112                 1900
# 7  2026-01-12 15:00:00  150000     20260112                 7137
#
#     total_10_ask_volume instrument     open    close  deal_number      low  \
# 0                  3700  600519.SH  1419.10  1419.01         8192  1417.10
# 1                  1700  600519.SH  1418.81  1419.02         2451  1418.81
# 2                  3200  600519.SH  1419.02  1421.88         1580  1419.00
# ..                  ...        ...      ...      ...          ...      ...
# ...

# %% [markdown]
# ### 2.5 60-min Price-Volume Data

# %%
dai.query("""
SELECT *
FROM cn_stock_bar60m
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                  date instrument  adjust_factor     open    close     high  \
# 0 2026-01-12 10:30:00  600519.SH       8.446992  1419.10  1419.02  1431.00
# 1 2026-01-12 11:30:00  600519.SH       8.446992  1419.02  1424.99  1425.00
# 2 2026-01-12 14:00:00  600519.SH       8.446992  1424.97  1423.49  1428.54
# 3 2026-01-12 15:00:00  600519.SH       8.446992  1423.80  1423.23  1427.01
#
#        low   volume        amount
# 0  1417.10  1578240  2.245482e+09
# 1  1419.00   477577  6.785822e+08
# 2  1421.01   724218  1.031729e+09
# 3  1422.27   828231  1.179843e+09

# %%
dai.query("""
SELECT *
FROM cn_stock_bar60m_derived
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
# Out:
#                  date    time  trading_day  total_10_bid_volume  \
# 0 2026-01-12 10:30:00  103000     20260112                13595
# 1 2026-01-12 11:30:00  113000     20260112                 3700
# 2 2026-01-12 14:00:00  140000     20260112                 1400
# 3 2026-01-12 15:00:00  150000     20260112                 7137
#
#    total_10_ask_volume instrument     open    close  deal_number      low  \
# 0                 1700  600519.SH  1419.10  1419.02        10643  1417.10
# 1                 3000  600519.SH  1419.02  1424.99         3360  1419.00
# 2                 6300  600519.SH  1424.97  1423.49         5440  1421.01
# 3                 4800  600519.SH  1423.80  1423.23         5651  1422.27
#
#     volume        amount     high  total_ask_volume  total_bid_volume  \
# 0  1578240  2.245482e+09  1431.00            554586            249262
# 1   477577  6.785822e+08  1425.00            585586            309067
# ...

# %% [markdown]
# ### 2.6 Level 2 Snapshot Data

# %%
dai.query("""
SELECT *
FROM cn_stock_level2_snapshot
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 2.7 Level 2 Trade Data

# %%
dai.query("""
SELECT *
FROM cn_stock_level2_trade
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()

# %% [markdown]
# ### 2.8 Level 2 Order Data

# %%
dai.query("""
SELECT *
FROM cn_stock_level2_order
WHERE date BETWEEN '2026-01-12 00:00:00.000' AND '2026-01-12 23:59:59.999'
AND instrument = '600519.SH'
""").df()
