# %% [markdown]
# # Chinese (Mainland) Stock Data - Market Data - Money Flow Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Moneyflow - Stock Market

# %%
dai.query("""
SELECT *
FROM cn_stock_moneyflow_ns
WHERE date BETWEEN '2026-01-11 00:00:00' AND '2026-01-11 23:59:59'
""").df()
# Out:
#                    date      ggt_sh         ggt_sz       south  hgt  sgt  \
# 0   2026-01-11 09:00:00        0.00       0.000000        0.00  NaN  NaN
# 1   2026-01-11 09:01:00        0.00       0.000000        0.00  NaN  NaN
# 2   2026-01-11 09:02:00        0.00       0.000000        0.00  NaN  NaN
# ..                  ...         ...            ...         ...  ...  ...
# 368 2026-01-11 16:08:00  3429895.25  186012.656250  2416953.25  NaN  NaN
# 369 2026-01-11 16:09:00  3437203.25  165986.234375  2473019.25  NaN  NaN
# 370 2026-01-11 16:10:00  3437203.25  165986.234375  2473019.25  NaN  NaN
#
#      north
# 0      NaN
# 1      NaN
# 2      NaN
# ..     ...
# 368    NaN
# 369    NaN
# 370    NaN
#
# [371 rows x 7 columns]

# %% [markdown]
# ## 2. Moneyflow - Individual Stock

# %%
dai.query("""
SELECT *
FROM cn_stock_moneyflow
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument  active_buy_volume_large  passive_buy_volume_large  \
# 0 2026-02-13  600519.SH                 587820.0                  467259.0
#
#    active_sell_volume_large  passive_sell_volume_large  \
# 0                  556471.0                   535710.0
#
#    active_buy_amount_large  passive_buy_amount_large  \
# 0              878278656.0               696634752.0
#
#    active_sell_amount_large  passive_sell_amount_large  active_buy_volume_big  \
# 0               829974016.0                800068736.0               709336.0
#
#    passive_buy_volume_big  active_sell_volume_big  passive_sell_volume_big  \
# 0                765335.0                827786.0                 593539.0
#
#    active_buy_amount_big  passive_buy_amount_big  active_sell_amount_big  \
# 0           1.057769e+09            1.141039e+09            1.233796e+09
#
#    passive_sell_amount_big  active_buy_volume_mid  passive_buy_volume_mid  \
# ...
