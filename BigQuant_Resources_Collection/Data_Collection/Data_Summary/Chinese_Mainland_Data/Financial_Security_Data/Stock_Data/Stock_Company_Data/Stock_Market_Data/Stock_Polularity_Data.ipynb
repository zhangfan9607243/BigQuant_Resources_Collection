# %% [markdown]
# # Chinese (Mainland) Stock Data - Market Data - Popularity Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Top List

# %%
dai.query("""
SELECT *
FROM cn_stock_dragon_list
WHERE date = '2026-02-13'
""").df()
# Out:
#          date instrument                                             reason  \
# 0  2026-02-13  000004.SZ  连续三个交易日内，日均换手率与前五个交易日的日均换手率的比值达到30倍，且换手率累计达20%的证券
# 1  2026-02-13  000021.SZ                                   日涨幅偏离值达到7%的前5只证券
# 2  2026-02-13  000070.SZ                                   日跌幅偏离值达到7%的前5只证券
# ..        ...        ...                                                ...
# 50 2026-02-13  920180.BJ                                   当日换手率达到20%的前5只股票
# 51 2026-02-13  920305.BJ                                当日收盘价跌幅达到-20%的前5只股票
# 52 2026-02-13  920662.BJ                                   当日换手率达到20%的前5只股票
#
#     close  price_change  net_buy_amount    buy_amount   sell_amount  \
# 0    8.36        5.0251   -1.177739e+07  2.257986e+07  3.435724e+07
# 1   32.29       10.0170    1.833686e+08  1.127275e+09  9.439062e+08
# 2   17.55      -10.0000    5.771750e+07  8.214367e+08  7.637192e+08
# ..    ...           ...             ...           ...           ...
# 50  18.77       -2.5441   -9.287066e+06  9.476978e+06  1.876404e+07
# 51   7.04      -21.9512   -3.358061e+06  1.070048e+07  1.405854e+07
# 52  32.28        2.8025   -5.754293e+06  3.020303e+07  3.595732e+07
#
#      deal_amount  total_deal_amount  net_buy_ratio  deal_amount_ratio  \
# 0   5.693710e+07       2.197253e+08      -5.360051          25.912856
# 1   2.071181e+09       7.683214e+09       2.386614          26.957222
# 2   1.585156e+09       3.766276e+09       1.532482          42.088147
# ..           ...                ...            ...                ...
# 50  2.824102e+07       1.080976e+08      -8.591371          26.125485
# 51  2.475902e+07       9.583550e+07      -3.503984          25.834913
# 52  6.616034e+07       2.347044e+08      -2.451719          28.188796
#
#        turn  float_market_cap  price_change_1d  price_change_2d  \
# 0   22.5564      1.055766e+09              NaN              NaN
# 1   15.4499      5.074145e+10              NaN              NaN
# 2   23.0576      1.559631e+10              NaN              NaN
# ..      ...               ...              ...              ...
# 50  21.4859      4.988632e+08              NaN              NaN
# 51  15.3372      5.709502e+08              NaN              NaN
# 52  29.3042      8.144466e+08              NaN              NaN
#
#     price_change_5d
# 0               NaN
# 1               NaN
# 2               NaN
# ..              ...
# 50              NaN
# 51              NaN
# 52              NaN
#
# [53 rows x 17 columns]

# %% [markdown]
# ## 2. Hot Rank

# %%
dai.query("""
SELECT *
FROM cn_stock_hot_rank
WHERE date = '2026-02-13'
AND instrument = '600519.SH'
""").df()
# Out:
#         date instrument       score  rank  rank_change  rank_change_rank
# 0 2026-02-13  600519.SH  2417102.84    34           38              2327
