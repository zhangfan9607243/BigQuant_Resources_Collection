# %% [markdown]
# # Chinese (Mainland) Stock Industry Data - Market Data - Popularity Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. EM Stock Industry Market Data

# %%
dai.query("""
SELECT *
FROM em_industry_bar1m
WHERE date BETWEEN '2026-01-05 00:00:00.000' AND '2026-01-05 23:59:59.999'
AND instrument = 'BK0420'
""").df()

# %%
dai.query("""
SELECT *
FROM em_industry_bar5m
WHERE date BETWEEN '2026-01-05 00:00:00.000' AND '2026-01-05 23:59:59.999'
AND instrument = 'BK0420'
""").df()

# %%
dai.query("""
SELECT *
FROM em_industry_bar15m
WHERE date BETWEEN '2026-01-05 00:00:00.000' AND '2026-01-05 23:59:59.999'
AND instrument = 'BK0420'
""").df()

# %%
dai.query("""
SELECT *
FROM em_industry_bar30m
WHERE date BETWEEN '2026-01-05 00:00:00.000' AND '2026-01-05 23:59:59.999'
AND instrument = 'BK0420'
""").df()

# %%
dai.query("""
SELECT *
FROM em_industry_bar60m
WHERE date BETWEEN '2026-01-05 00:00:00.000' AND '2026-01-05 23:59:59.999'
AND instrument = 'BK0420'
""").df()

# %% [markdown]
# ## 2. EM Stock Industry Popolarity Data

# %%
dai.query("""
SELECT *
FROM em_industry_rank
WHERE date = '2026-02-13'
ORDER BY rank
""").df()
# Out:
#    instrument industry_name       date  rank     price  change_ratio   change  \
# 0      BK0729          船舶制造 2026-02-13     1   1478.84        0.0366    52.21
# 1      BK0480          航天航空 2026-02-13     2  68990.82        0.0221  1490.54
# 2      BK0539          综合行业 2026-02-13     3  14247.50        0.0063    88.71
# ..        ...           ...        ...   ...       ...           ...      ...
# 83     BK0546          玻璃玻纤 2026-02-13    84  63107.53       -0.0262 -1701.03
# 84     BK1027           小金属 2026-02-13    85   4002.91       -0.0297  -122.65
# 85     BK1031          光伏设备 2026-02-13    86   1617.60       -0.0306   -51.08
#
#       turn  total_market_cap  rising_stocks_count  falling_stocks_count  \
# 0   0.0584      5.604392e+11                    9                     1
# 1   0.0331      1.616112e+12                   35                    11
# 2   0.0238      2.940583e+11                   11                     8
# ...
