# %% [markdown]
# # Chinese (Mainland) Future Data - Market Data - Status Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_future_static_data
WHERE date = '2026-02-13'
AND instrument = 'rb2612.SHF'
""").df()
# Out:
#         date  trading_day  instrument     name exchange trading_code  \
# 0 2026-02-13     20260213  rb2612.SHF  螺纹钢2612     SHFE       rb2612
#
#   product_id product_class  delivery_year  delivery_month  \
# 0         rb             1           2026              12
#
#    max_market_order_volume  min_market_order_volume  max_limit_order_volume  \
# 0                       30                        1                     500
#
#    min_limit_order_volume  price_tick create_date  open_date expire_date  \
# 0                       1         1.0  2025-11-13 2025-12-16  2026-12-15
#
#   start_deliv_date end_deliv_date inst_life_phase  is_trading  position_type  \
# 0       2026-12-16     2026-12-17             1.0           1              2
#
#    position_date_type  long_margin_ratio  short_margin_ratio  \
# 0                   1               0.12                0.12
#
#    max_margin_side_algorithm  combination_type  volume_multiplier
# 0                          1                 0               10.0
