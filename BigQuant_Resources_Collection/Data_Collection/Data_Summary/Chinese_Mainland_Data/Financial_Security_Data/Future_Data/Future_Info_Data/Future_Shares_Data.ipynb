# %% [markdown]
# # Chinese (Mainland) Future Data - Information Data - Shares Information

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_future_member_position
WHERE date = '2026-02-13'
AND instrument LIKE 'rb2610.SHF'
""").df()
# Out:
#          date  instrument  name   volume  rank  change  kind
# 0  2026-02-13  rb2610.SHF  中信期货  12393.0     1  5099.0   all
# 1  2026-02-13  rb2610.SHF  国泰君安  16948.0     1   918.0   buy
# 2  2026-02-13  rb2610.SHF  中信期货  15007.0     1 -1851.0  sell
# ..        ...         ...   ...      ...   ...     ...   ...
# 57 2026-02-13  rb2610.SHF  银河期货    634.0    20 -1348.0   all
# 58 2026-02-13  rb2610.SHF  新湖期货   2227.0    20     0.0   buy
# 59 2026-02-13  rb2610.SHF  海证期货   2844.0    20   -70.0  sell
#
# [60 rows x 7 columns]
