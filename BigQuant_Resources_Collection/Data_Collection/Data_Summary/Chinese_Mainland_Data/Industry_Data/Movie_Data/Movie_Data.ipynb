# %% [markdown]
# # Chinese (Mainland) Industry Data - Movie Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_film_filings_record
""").df()
# Out:
#              rec_no   film_name                                       rec_org  \
# 0  影剧备字[2019]第1422号    南越宫词（粤剧）                           中国电影股份有限公司、广州市广播电视台
# 1  影剧备字[2016]第2922号  三重威胁之跨国大营救  上海极光联盟影业有限公司、Pure Time Films Company Limited
# 2  影剧备字[2019]第2188号       土团追踪记                             重庆市淘厨汇物联网科技有限责任公司
# 3   影纪备字[2018]第390号          一年                                   北京无戏言影业有限公司
# 4    影合立字（2019）第38号        凤争虎斗                  深圳市大百姓影业有限公司、RGV,THE COMPANY
#
#      script_writer rec_result    rec_area classified              date_range  \
# 0              王维忠       同意拍摄          直备       故事影片      2019年03月11日-03月20日
# 1             黄健闫磊       同意立项  2019-03-27        合拍片      2019年03月21日-03月29日
# 2              龙雪莹       同意拍摄         重庆市       故事影片      2019年04月01日-04月10日
# 3               周浩       同意拍摄         北京市       纪录影片      2019年04月11日-04月20日
# 4  Ram Gopal Varma       同意立项  2019-05-30        合拍片      2019年04月21日-04月30日
#
#             ann_date
# ...
