# %% [markdown]
# # Chinese (Mainland) Alternative Data - Text Data - Posts Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Weibo Posts

# %%
dai.query("""
SELECT *
FROM weibo_posts
WHERE posted_at BETWEEN '2025-12-01 00:00:00.000' AND '2025-12-01 23:59:59.999'
""").df()
# Out:
#     username                                         plain_text source region  \
# 0     每日经济新闻  #美人造肉第一股退出中国# 【太突然！曾获比尔·盖茨投资，#美人造肉第一股中国建厂不到5年停...  微博网页版
# 1     财联社APP  【美乌新一轮谈判结束 美称“富有成效”并谈及俄罗斯】财联社12月1日电，据央视新闻，当地时间...
# 2     财联社APP                 财联社12月1日电，现货白银首次触及57美元/盎司，日内涨超1%。
# ..       ...                                                ...    ...    ...
# 175   每日经济新闻  【创新药遭遇“窜天猴”：两个月大涨30%，#1只实验猴卖12万元仍有价无猴#，国内年缺口约1...  微博网页版
# 176     蓝鲸新闻                          【12月1日周一《新闻联播》要闻25条】网页链接
# 177   财联社APP  【比特币跌破84000美元】财联社12月1日电，行情显示，比特币跌至83973.9美元，过去...
#
#     at_users                              topics  reposts_count  \
# 0             #美人造肉第一股退出中国#, #美人造肉第一股中国建厂不到5年停产#              5
# 1                                                             5
# 2                                                             8
# ..       ...                                 ...            ...
# 175               #1只实验猴卖12万元仍有价无猴#, #创新药研发遭遇缺猴#             77
# ...

# %% [markdown]
# ## 2. Guba Posts

# %% [markdown]
# ### 2.1 Hot Concepts Posts

# %%
dai.query("""
SELECT *
FROM sentiment_hot_concept_bar
WHERE date BETWEEN '2025-12-01 00:00:00.000' AND '2025-12-01 23:59:59.999'
""").df()
# Out:
#     bar_code bar_name                date         update_time  \
# 0     bk0547     黄金概念 2025-12-01 00:19:49 2025-12-10 00:41:48
# 1     bk1127     AI芯片 2025-12-01 00:58:17 2025-12-01 09:23:35
# 2     bk1128    CPO概念 2025-12-01 01:12:33 2025-12-05 07:29:58
# ..       ...      ...                 ...                 ...
# 267   bk1193     海南自贸 2025-12-01 21:55:42 2025-12-02 05:08:54
# 268   bk1103     熔盐储能 2025-12-01 22:17:00 2025-12-05 06:46:05
# 269   bk1025    预制菜概念 2025-12-01 23:46:46 2025-12-02 18:56:07
#
#      article_click_count  article_comment_count            article_title  \
# 0                   3057                      6       2025年全球系统重要性银行名单出炉
# 1                     65                     15                       腊鸡
# 2                     15                      4                       转发
# ..                   ...                    ...                      ...
# 267                   66                     31                        好
# ...

# %% [markdown]
# ### 2.2 Hot Topic Posts

# %%
dai.query("""
SELECT *
FROM sentiment_hot_topic_bar
WHERE date BETWEEN '2025-12-01 00:00:00.000' AND '2025-12-01 23:59:59.999'
""").df()
# Out:
#      bar_code bar_name                date         update_time  \
# 0     ufsgxcn    A50期指 2025-12-01 00:06:14 2025-12-01 02:18:28
# 1        cjpl     财经评论 2025-12-01 00:06:30 2025-12-01 10:48:48
# 2        gssz     股市实战 2025-12-01 00:06:43 2025-12-01 11:52:04
# ...       ...      ...                 ...                 ...
# 2577   waihui       外汇 2025-12-01 23:56:04 2025-12-02 06:49:43
# 2578  zsgjndx     纳斯达克 2025-12-01 23:56:57 2025-12-02 00:14:39
# 2579  zsgjndx     纳斯达克 2025-12-01 23:56:58 2025-12-02 07:35:23
#
#       article_click_count  article_comment_count  \
# 0                     206                      2
# 1                     106                      1
# 2                      15                     22
# ...                   ...                    ...
# 2577                  120                      1
# 2578                  159                      2
# 2579                   52                     38
#
# ...

# %% [markdown]
# ### 2.3 Hot Stock Posts

# %%
dai.query("""
SELECT *
FROM sentiment_hot_stock_bar
WHERE date BETWEEN '2025-12-01 00:00:00.000' AND '2025-12-01 23:59:59.999'
""").df()
# Out:
#      bar_code bar_name                date         update_time  \
# 0      000547     航天发展 2025-12-01 00:00:00 2025-12-01 10:20:07
# 1      000547     航天发展 2025-12-01 00:09:49 2025-12-02 00:58:04
# 2      000547     航天发展 2025-12-01 00:11:56 2025-12-01 14:57:55
# ...       ...      ...                 ...                 ...
# 1404   000547     航天发展 2025-12-01 23:55:59 2025-12-02 01:15:50
# 1405   600828     茂业商业 2025-12-01 23:57:19 2025-12-02 11:44:43
# 1406   603778     国晟科技 2025-12-01 23:58:01 2025-12-02 05:08:58
#
#       article_click_count  article_comment_count  \
# 0                    2522                     17
# 1                    2962                     39
# 2                    6807                     18
# ...                   ...                    ...
# 1404                   68                      2
# 1405                  272                      6
# 1406                  370                      5
#
# ...
