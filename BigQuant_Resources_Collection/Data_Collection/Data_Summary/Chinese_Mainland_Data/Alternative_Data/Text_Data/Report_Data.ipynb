# %% [markdown]
# # Chinese (Mainland) Alternative Data - Text Data - Report Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Macroeconomy Research Report

# %%
dai.query("""
SELECT *
FROM cn_stock_macro_research_report
WHERE date > '2023-12-31'
""").df()
# Out:
#            date instrument researcher                             title  \
# 0    2024-01-04       中国银河     章俊,于金潼  美联储12月FOMC纪要：联储纪要未传达更鸽派信号，关注非农数据
# 1    2024-01-04       华泰期货     徐闻宇,高聪     美联储12月议息纪要点评：降息预期的修正，关注市场调整风险
# 2    2024-01-04       华福证券  燕翔,朱斌,章孟菲     12月全球经济观察：近四次加息-降息周期中主要大类资产表现
# ...         ...        ...        ...                               ...
# 3494 2024-07-10     第一上海证券         李倩                            宏观经济评论
# 3495 2024-07-10       致富证券         余琦           美劳动力市场持续放缓，维持联储9月首次降息判断
# 3496 2024-07-10       麦高证券    刘娟秀,钟奕昕              6月PMI数据点评：制造业景气度保持平稳
#
#           org_name  report_count_1m  \
# 0     中国银河证券股份有限公司               40
# 1         华泰期货有限公司               28
# 2       华福证券有限责任公司               20
# ...            ...              ...
# 3494    第一上海证券有限公司                5
# 3495          致富证券                2
# 3496    麦高证券有限责任公司               18
#
#                                                    text
# ...

# %% [markdown]
# ## 2. Stock Market Research

# %% [markdown]
# ### 2.1 Stock Market & Company Research

# %%
dai.query("""
SELECT *
FROM cn_stock_industry_research_report
WHERE date > '2024-07-01'
""").df()
# Out:
#           date instrument                                             author  \
# 0   2024-07-02         中药  11000296231.谭国超;11000324431.李昌幸;11000399837.李婵...
# 1   2024-07-02      互联网服务                     11000194227.熊莉;11000322239.库宏垚
# 2   2024-07-02         保险  11000210450.胡翔;11000258345.葛玉翔;11000454443.武欣姝...
# ..         ...        ...                                                ...
# 121 2024-07-05       软件开发                    11000347931.李行杰;11000301831.黄伯乐
# 122 2024-07-05       通信设备                      11000233936.彭毅;11000454332.张恬
# 123 2024-07-05       铁路公路                                     11000266434.杜冲
#
#                                                title    org_name org_sname  \
# 0                     医药生物行业周报：医药板块处于底部位置，建议加大对医药的配置  华安证券股份有限公司      华安证券
# 1                计算机行业2024年6月投资策略：深化电力体制改革，电力IT产业高景气  国信证券股份有限公司      国信证券
# 2    保险Ⅱ行业点评报告：央行“卖债”定调长端利率底部，利率反弹力度决定寿险修复高度，首推太保和新华  东吴证券股份有限公司      东吴证券
# ...

# %% [markdown]
# ### 2.2 Stock IPO Research

# %%
dai.query("""
SELECT *
FROM cn_stock_ipo_research_report
WHERE date > '2024-06-01'
""").df()
# Out:
#         date instrument          author  issue_price        title  list_date  \
# 0 2024-06-07  603381.SH  11000176307.李蕙        23.35  新股覆盖研究：永臻股份 2024-06-26
# 1 2024-06-10  301580.SZ  11000176307.李蕙        44.95   新股覆盖研究：爱迪特 2024-06-26
# 2 2024-06-17  603350.SH  11000176307.李蕙        20.56   新股覆盖研究：安乃达 2024-07-03
# 3 2024-06-19  603285.SH  11000176307.李蕙        18.65  新股覆盖研究：键邦股份 2024-07-05
# 4 2024-06-23  301603.SZ  11000176307.李蕙        26.50  新股覆盖研究：乔锋智能        NaT
# 5 2024-06-28  301552.SZ  11000176307.李蕙         0.00  新股覆盖研究：科力装备        NaT
#
#    pe_issue purchase_date    org_name org_sname industry_board  name
# 0     15.06    2024-06-17  华金证券股份有限公司      华金证券           光伏设备  永臻股份
# 1     25.49    2024-06-17  华金证券股份有限公司      华金证券           医疗器械   爱迪特
# 2     18.02    2024-06-24  华金证券股份有限公司      华金证券             电机   安乃达
# 3     16.43    2024-06-26  华金证券股份有限公司      华金证券           化学制品  键邦股份
# 4     19.96    2024-07-01  华金证券股份有限公司      华金证券           通用设备  乔锋智能
# ...
