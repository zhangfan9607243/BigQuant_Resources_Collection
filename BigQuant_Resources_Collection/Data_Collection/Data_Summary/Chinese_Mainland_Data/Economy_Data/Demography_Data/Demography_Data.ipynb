# %% [markdown]
# # Chinese (Mainland) Economic Data - Demography Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Population

# %%
dai.query("""
SELECT *
FROM cn_macro_population_yearly
""").df()
# Out:
#     year  population     male   female    urban    rural  birth_rate  \
# 0   2004    129988.0  66976.0  63012.0  54283.0  75705.0       12.29
# 1   2005    130756.0  67375.0  63381.0  56212.0  74544.0       12.40
# 2   2006    131448.0  67728.0  63720.0  58288.0  73160.0       12.09
# ..   ...         ...      ...      ...      ...      ...         ...
# 17  2021    141260.0  72311.0  68949.0  91425.0  49835.0        7.52
# 18  2022    141175.0  72206.0  68969.0  92071.0  49104.0        6.77
# 19  2023    140967.0  72032.0  68935.0  93267.0  47700.0        6.39
#
#     death_rate  growth_rate
# 0         6.42         5.87
# 1         6.51         5.89
# 2         6.81         5.28
# ..         ...          ...
# 17        7.18         0.34
# 18        7.37        -0.60
# 19        7.87        -1.48
#
# [20 rows x 9 columns]

# %% [markdown]
# ## 2. Population Segmentation

# %% [markdown]
# ### 2.1 Population Segmentation - Age & Dependency

# %%
dai.query("""
SELECT *
FROM cn_macro_population_age_dependency_yearly
""").df()
# Out:
#     year  population  age_between_0_and_14  age_between_15_and_64  \
# 0   2004    129988.0             27947.000              92184.000
# 1   2005    130756.0             26504.000              94197.000
# 2   2006    131448.0             25961.000              95068.000
# ..   ...         ...                   ...                    ...
# 17  2021    141260.0             24678.000              96526.000
# 18  2022    141175.0             23908.000              96289.000
# 19  2023    140967.0             22977.621              96280.461
#
#     age_over_65  dependency_ratio  children_dependency_ratio  \
# 0      9857.000              41.0                       30.3
# 1     10055.000              38.8                       28.1
# 2     10419.000              38.3                       27.3
# ..          ...               ...                        ...
# 17    20056.000              46.3                       25.6
# 18    20978.000              46.6                       24.8
# ...

# %% [markdown]
# ### 2.2 Population Segmentation - Age & Gender

# %%
# Absolute
dai.query("""
SELECT *
FROM cn_macro_population_age_gender_yearly
""").df()
# Out:
#     year  gender  population  age_between_0_and_4  age_between_5_and_9  \
# 0   2004    both   1253065.0              61874.0              76221.0
# 1   2004  female    615898.0              27784.0              34788.0
# 2   2004    male    637167.0              34089.0              41433.0
# ..   ...     ...         ...                  ...                  ...
# 57  2023    both         NaN                  NaN                  NaN
# 58  2023  female         NaN                  NaN                  NaN
# 59  2023    male         NaN                  NaN                  NaN
#
#     age_between_10_and_14  age_between_15_and_19  age_between_20_and_24  \
# 0                103771.0               109259.0                79604.0
# 1                 48850.0                52676.0                40440.0
# 2                 54921.0                56583.0                39164.0
# ..                    ...                    ...                    ...
# ...

# %%
# Ratio
dai.query("""
SELECT *
FROM cn_macro_age_gender_ratio_yearly
""").df()
# Out:
#     year  gender_ratio  age_between_0_and_4  age_between_5_and_9  \
# 0   2004        103.45               122.69               119.10
# 1   2005        102.19               122.66               119.30
# 2   2006        102.71               120.72               123.05
# ..   ...           ...                  ...                  ...
# 17  2021        104.61               110.37               112.96
# 18  2022        104.43               109.88               112.22
# 19  2023           NaN                  NaN                  NaN
#
#     age_between_10_and_14  age_between_15_and_19  age_between_20_and_24  \
# 0                  112.43                 107.42                  96.85
# 1                  114.20                 107.88                  93.13
# 2                  116.99                 111.99                  95.84
# ..                    ...                    ...                    ...
# 17                 114.86                 116.17                 113.20
# ...

# %% [markdown]
# ### 2.3 Population Segmentation - Marital

# %%
# Ratio
dai.query("""
SELECT *
FROM cn_macro_marital_population_yearly
""").df()
# Out:
#     year  age_over_15  male_age_over_15  female_age_over_15  never_married  \
# 0   2004    1011199.0          506724.0            504475.0       197561.0
# 1   2005   13664737.0         6786677.0           6878061.0      2619360.0
# 2   2006     972385.0          484183.0            488202.0       188559.0
# ..   ...          ...               ...                 ...            ...
# 17  2021    1232677.0          625238.0            607439.0       238753.0
# 18  2022    1199109.0          607967.0            591141.0       236783.0
# 19  2023          NaN               NaN                 NaN            NaN
#
#     male_never_married  female_never_married  first_married  \
# 0             114158.0               83403.0       728431.0
# 1            1524886.0             1094474.0      9824784.0
# 2             109508.0               79051.0       698582.0
# ..                 ...                   ...            ...
# 17            142861.0               95891.0            NaN
# ...

# %% [markdown]
# ### 2.4 Population Segmentation - Family

# %%
dai.query("""
SELECT *
FROM cn_macro_family_household_yearly
""").df()
# Out:
#     year  family_household  one_persons  two_persons  three_persons  \
# 0   2004          367617.0      28761.0      72225.0       115568.0
# 1   2005         5286554.0     567455.0    1294464.0      1577147.0
# 2   2006          368180.0      33646.0      89000.0       112944.0
# ..   ...               ...          ...          ...            ...
# 17  2021          510132.0      86969.0     124057.0       110090.0
# 18  2022          497176.0      83354.0     118606.0       105506.0
# 19  2023               NaN          NaN          NaN            NaN
#
#     four_persons  five_persons  six_persons  seven_persons  eight_persons  \
# 0        80242.0       45584.0      16183.0         5349.0         2149.0
# 1      1014177.0      538035.0     199448.0        58212.0        22028.0
# 2        73757.0       39697.0      13228.0         3732.0         1352.0
# ..           ...           ...          ...            ...            ...
# ...

# %% [markdown]
# ### 2.5 Population Segmentation - Household

# %%
dai.query("""
SELECT *
FROM cn_macro_household_population_yearly
""").df()
# Out:
#     year  household  family_household  collective_household  \
# 0   2004   370785.0          367617.0                3168.0
# 1   2005  5391013.0         5286554.0              104459.0
# 2   2006   374053.0          368180.0                5873.0
# ..   ...        ...               ...                   ...
# 17  2021   528365.0          510132.0               18233.0
# 18  2022   513643.0          497176.0               16467.0
# 19  2023        NaN               NaN                   NaN
#
#     family_household_population  family_household_male_population  \
# 0                     1236207.0                          628037.0
# 1                    16570406.0                         8354106.0
# 2                     1168454.0                          590787.0
# ..                          ...                               ...
# 17                    1412402.0                          717732.0
# 18                    1372731.0                          696819.0
# ...

# %% [markdown]
# ### 2.6 Population Segmentation - Household Register

# %%
dai.query("""
SELECT *
FROM cn_macro_household_register_population_yearly
""").df()
# Out:
#     year  population       male     female    residing  male_residing  \
# 0   2004   1253065.0   637167.0   615898.0   1143642.0       582302.0
# 1   2005  16985766.0  8584882.0  8400884.0  14956470.0      7559833.0
# 2   2006   1192666.0   604303.0   588363.0   1070090.0       543014.0
# ..   ...         ...        ...        ...         ...            ...
# 17  2021   1494054.0   763842.0   730212.0   1041754.0       530881.0
# 18  2022   1443996.0   737631.0   706364.0   1025198.0       521861.0
# 19  2023         NaN        NaN        NaN         NaN            NaN
#
#     female_residing  residing_6months  male_residing_6months  \
# 0          561340.0               NaN                    NaN
# 1         7396636.0         1945894.0               983525.0
# 2          527076.0               NaN                    NaN
# ..              ...               ...                    ...
# 17         510873.0          445361.0               229119.0
# ...

# %% [markdown]
# ### 2.7 Population Segmentation - Education

# %%
dai.query("""
SELECT *
FROM cn_macro_education_population_yearly
""").df()
# Out:
#     year  age_over_6  male_age_over_6  female_age_over_6  no_schooling  \
# 0   2004   1177817.0         595688.0           582128.0      107922.0
# 1   2005  15878355.0        7975386.0          7902969.0     1646360.0
# 2   2006   1118855.0         563752.0           555103.0       98335.0
# ..   ...         ...              ...                ...           ...
# 17  2021   1402340.0         715667.0           686673.0       51186.0
# 18  2022   1363035.0         695142.0           667894.0       51393.0
# 19  2023         NaN              NaN                NaN           NaN
#
#     male_no_schooling  female_no_schooling  primary_school  \
# 0             31281.0              76641.0        381371.0
# 1            450088.0            1196272.0       5285045.0
# 2             26886.0              71448.0        370014.0
# ..                ...                  ...             ...
# 17            14686.0              36501.0        365918.0
# ...

# %%
dai.query("""
SELECT *
FROM cn_macro_population_illiterate_yearly
""").df()
# Out:
#     year  age_over_15  male_age_over_15  female_age_over_15  illiterate  \
# 0   2004    1011199.0          506724.0            504475.0    104324.0
# 1   2005   13664737.0         6786677.0           6878061.0   1508706.0
# 2   2006     972385.0          484183.0            488202.0     90564.0
# ..   ...          ...               ...                 ...         ...
# 17  2021    1232677.0          625238.0            607439.0     39531.0
# 18  2022    1199109.0          607967.0            591141.0     40704.0
# 19  2023          NaN               NaN                 NaN         NaN
#
#     male_illiterate  female_illiterate
# 0           29338.0            74986.0
# 1          397877.0          1110828.0
# 2           23560.0            67004.0
# ..              ...                ...
# 17           9386.0            30145.0
# 18           9614.0            31089.0
# 19              NaN                NaN
#
# [20 rows x 7 columns]

# %% [markdown]
# ## 3. Life Expect

# %%
dai.query("""
SELECT *
FROM cn_macro_life_expect_yearly
""").df()
# Out:
#     year  life_expect  male_life_expect  female_life_expect
# 0   2004          NaN               NaN                 NaN
# 1   2005        72.95             70.83               75.25
# 2   2006          NaN               NaN                 NaN
# ..   ...          ...               ...                 ...
# 17  2021          NaN               NaN                 NaN
# 18  2022          NaN               NaN                 NaN
# 19  2023          NaN               NaN                 NaN
#
# [20 rows x 4 columns]
