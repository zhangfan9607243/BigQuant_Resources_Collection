# %% [markdown]
# # Chinese (Mainland) Economic Data - Living Standard Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Per-Capita Living Standards

# %% [markdown]
# ### 1.1 Per-Capita Income

# %% [markdown]
# #### 1.1.1 National Per-Capita Income

# %%
# Yearly
dai.query("""
SELECT *
FROM cn_macro_resident_income_yearly
""").df()
# Out:
#     year        income  income_added  median_income  median_income_added  \
# 0   2004   5660.903872      8.800000            NaN                  NaN
# 1   2005   6384.725375     10.800000            NaN                  NaN
# 2   2006   7228.820253     11.500000            NaN                  NaN
# ..   ...           ...           ...            ...                  ...
# 17  2021  35128.100000      8.100000   29975.000000             8.800000
# 18  2022  36883.283552      2.941176   31370.000000             4.654184
# 19  2023  39217.974700      6.087824   33035.555556             5.309390
#
#      wage_income  wage_income_added  business_income  business_income_added  \
# 0    3452.000000          12.800000      1277.000000              13.800000
# 1    3859.000000          11.800000      1410.000000              10.400000
# 2    4426.000000          14.700000      1511.000000               7.200000
# ..           ...                ...              ...                    ...
# ...

# %%
# Quarterly
dai.query("""
SELECT *
FROM cn_macro_pci
""").df()
# Out:
#     quarter kind  acc_pci  acc_pci_rate  median_pci  median_pci_rate  \
# 0     2013A   全国   5006.1           NaN      4117.2              NaN
# 1     2013A   城镇   7202.9           NaN         NaN              NaN
# 2     2013A   农村   2652.9           NaN         NaN              NaN
# ..      ...  ...      ...           ...         ...              ...
# 141   2024D   全国  41314.0         0.051     34706.9            0.051
# 142   2024D   城镇  54187.9         0.044     49302.3            0.046
# 143   2024D   农村  23118.5         0.063     19604.6            0.046
#
#      salary_pci  salary_pci_rate  operating_pci  operating_pci_rate  \
# 0        2849.4              NaN          968.3                 NaN
# 1        4498.7              NaN          907.4                 NaN
# 2        1082.7              NaN         1033.5                 NaN
# ..          ...              ...            ...                 ...
# 141     23327.4            0.058         6907.6               0.056
# ...

# %% [markdown]
# #### 1.1.2 Urban Per-Capita Income

# %%
dai.query("""
SELECT *
FROM cn_macro_urban_resident_income_yearly
""").df()
# Out:
#     year        income  income_added  median_income  median_income_added  \
# 0   2004   9334.844208      7.500000            NaN                  NaN
# 1   2005  10382.337718      9.500000            NaN                  NaN
# 2   2006  11619.680461     10.300000            NaN                  NaN
# ..   ...           ...           ...            ...                  ...
# 17  2021  47411.900000      7.100000   43504.000000             7.700000
# 18  2022  49282.937114      1.862745   45123.157895             3.721228
# 19  2023  51820.748400      4.785643   47121.597000             4.428855
#
#      wage_income  wage_income_added  business_income  business_income_added  \
# 0    6900.000000          10.800000       520.000000              23.100000
# 1    7456.000000           8.100000       719.000000              38.200000
# 2    8305.000000          11.400000       860.000000              19.500000
# ..           ...                ...              ...                    ...
# ...

# %% [markdown]
# #### 1.1.3 Rural Per-Capita Income

# %%
dai.query("""
SELECT *
FROM cn_macro_rural_resident_income_yearly
""").df()
# Out:
#     year        income  income_added  median_income  median_income_added  \
# 0   2004   3026.567532      7.300000            NaN                  NaN
# 1   2005   3370.212928      6.700000            NaN                  NaN
# 2   2006   3730.962875      7.900000            NaN                  NaN
# ..   ...           ...           ...            ...                  ...
# 17  2021  18930.900000      9.700000   16902.000000            11.200000
# 18  2022  20132.825505      4.215686   17733.750000             4.920782
# 19  2023  21690.872900      7.592408   18748.020917             5.719438
#
#     wage_income  wage_income_added  business_income  business_income_added  \
# 0    980.000000           8.300000       1820.00000              13.800000
# 1   1147.000000          17.100000       1931.00000               6.100000
# 2   1336.000000          16.500000       2030.00000               5.100000
# ..          ...                ...              ...                    ...
# ...

# %% [markdown]
# ### 1.2 Per-Capita Expense

# %% [markdown]
# #### 1.2.1 National Per-Capita Expense

# %%
# Yearly
dai.query("""
SELECT *
FROM cn_macro_resident_expense_yearly
""").df()
# Out:
#     year       expense  expense_added  service_expense  service_expense_added  \
# 0   2004   4395.000000       8.800000              NaN                    NaN
# 1   2005   5035.000000      12.500000              NaN                    NaN
# 2   2006   5634.000000      10.200000              NaN                    NaN
# ..   ...           ...            ...              ...                    ...
# 17  2021  24100.100000      12.600000     10644.500000              17.800000
# 18  2022  24538.224188      -0.196078     10589.958748              -0.512483
# 19  2023  26795.679000       8.982036     12113.823500              14.389714
#
#     food_alcohol_expense  food_alcohol_expense_added  clothes_expense  \
# 0            1704.000000                   14.900000        339.00000
# 1            1877.000000                   10.100000        404.00000
# 2            2002.000000                    6.700000        459.00000
# ...

# %%
# Yearly Grouped
dai.query("""
SELECT *
FROM cn_macro_resident_quintuplet_income_yearly
""").df()
# Out:
#     year  low_income  middle_lower_income  middle_income  middle_upper_income  \
# 0   2004         NaN                  NaN            NaN                  NaN
# 1   2005         NaN                  NaN            NaN                  NaN
# 2   2006         NaN                  NaN            NaN                  NaN
# ..   ...         ...                  ...            ...                  ...
# 17  2021     8332.80             18445.50       29053.30             44948.90
# 18  2022     8601.13             19302.71       30598.30             47397.41
# 19  2023     9214.66             20442.34       32194.85             50219.89
#
#     high_income
# 0           NaN
# 1           NaN
# 2           NaN
# ..          ...
# 17     85835.80
# 18     90116.29
# 19     95055.27
#
# [20 rows x 6 columns]

# %%
# Quarterly
dai.query("""
SELECT *
FROM cn_macro_pce
""").df()
# Out:
#     quarter kind     pce  pce_rate  food_pce  food_pce_rate  clothing_pce  \
# 0     2013A   全国  3370.0       NaN    1120.0            NaN         350.0
# 1     2013A   城镇  4725.0       NaN    1561.0            NaN         516.0
# 2     2013A   农村  1919.0       NaN     647.0            NaN         172.0
# ..      ...  ...     ...       ...       ...            ...           ...
# 144   2025A   全国  7681.0     0.053    2420.0          0.028         498.0
# 145   2025A   城镇  9363.0     0.048    2863.0          0.022         616.0
# 146   2025A   农村  5333.0     0.059    1803.0          0.035         333.0
#
#      clothing_pce_rate  housing_pce  housing_pce_rate  living_pce  \
# 0                  NaN        695.0               NaN       205.0
# 1                  NaN       1008.0               NaN       270.0
# 2                  NaN        359.0               NaN       135.0
# ..                 ...          ...               ...         ...
# ...

# %% [markdown]
# #### 1.2.2 Urban Per-Capita Expense

# %%
dai.query("""
SELECT *
FROM cn_macro_urban_resident_expense_yearly
""").df()
# Out:
#     year       expense  expense_added  service_expense  service_expense_added  \
# 0   2004   7280.000000       7.000000              NaN                    NaN
# 1   2005   8068.000000       9.100000              NaN                    NaN
# 2   2006   8851.000000       8.100000              NaN                    NaN
# ..   ...           ...            ...              ...                    ...
# 17  2021  30307.200000      11.100000     14058.500000              17.028744
# 18  2022  30390.801705      -1.666667     13722.770749              -2.388018
# 19  2023  32994.230700       8.275174     15673.002500              14.211647
#
#     food_alcohol_expense  food_alcohol_expense_added  clothes_expense  \
# 0            2609.000000                   11.600000       641.000000
# 1            2786.000000                    6.800000       737.000000
# 2            2948.000000                    5.800000       818.000000
# ...

# %% [markdown]
# #### 1.2.3 Rural Per-Capita Expense

# %%
dai.query("""
SELECT *
FROM cn_macro_rural_resident_expense_yearly
""").df()
# Out:
#     year       expense  expense_added  service_expense  service_expense_added  \
# 0   2004   2326.000000       8.300000              NaN                    NaN
# 1   2005   2749.000000      12.600000              NaN                    NaN
# 2   2006   3072.000000      10.100000              NaN                    NaN
# ..   ...           ...            ...              ...                    ...
# 17  2021  15915.600000      15.300000      6142.900000              18.363673
# 18  2022  16632.087644       2.450980      6357.902124               3.499673
# 19  2023  18175.144500       9.190809      7163.953500              12.677946
#
#     food_alcohol_expense  food_alcohol_expense_added  clothes_expense  \
# 0            1055.000000                   17.100000       123.000000
# 1            1191.000000                   12.900000       153.000000
# 2            1249.000000                    4.900000       173.000000
# ...

# %% [markdown]
# # 2. Household Consumption

# %%
dai.query("""
SELECT *
FROM cn_macro_household_consume_yearly
""").df()
# Out:
#     year     household  rural_household  citizen_household  household_index  \
# 0   2004   5071.061086      2521.378397        8717.911256       106.625141
# 1   2005   5687.855238      2783.640223        9636.951594       109.537850
# 2   2006   6318.924813      3065.530604       10515.774928       107.974211
# ..   ...           ...              ...                ...              ...
# 17  2021  31012.998507     18433.674433       37995.494631       111.407206
# 18  2022  31898.886584     19519.547322       38573.688472       100.906081
# 19  2023  34964.462071     21397.849628       42050.447411              NaN
#
#     rural_household_index  citizen_household_index  household_1978_index  \
# 0              103.940957               105.240829            632.698951
# 1              106.783498               108.302726            693.044827
# 2              107.319094               105.947404            748.309685
# ...
