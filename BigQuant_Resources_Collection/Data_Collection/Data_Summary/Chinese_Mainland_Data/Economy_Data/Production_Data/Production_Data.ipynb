# %% [markdown]
# # Chinese (Mainland) Economic Data - Production Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %%
dai.query("""
SELECT *
FROM cn_macro_per_capita_production_yearly
""").df()
# Out:
#     year        food    cotton        oil      sugar       tea       fruit  \
# 0   2004  362.224018  4.878969  23.655340  73.843347  0.644431  118.364153
# 1   2005  371.262161  4.382980  23.602729  72.499538  0.717069  123.646910
# 2   2006  379.889148  5.745745  20.139393  79.784975  0.784171  130.447800
# ..   ...         ...       ...        ...        ...       ...         ...
# 17  2021  483.479776  4.057700  25.582531  81.101489       NaN  212.199435
# 18  2022  486.149151  4.234731  25.876470  79.568398       NaN  221.617298
# 19  2023         NaN       NaN        NaN        NaN       NaN         NaN
#
#          meat  aquatic_product  raw_coal   crude_oil       yarn      cloth  \
# 0   40.390000        32.760000  1.637722  135.696854   9.963467  37.196921
# 1   41.980000        33.900000  1.814152  139.104179  11.126162  37.154450
# 2   42.778980        34.960000  1.960101  140.932785  13.294687  45.655291
# ...
