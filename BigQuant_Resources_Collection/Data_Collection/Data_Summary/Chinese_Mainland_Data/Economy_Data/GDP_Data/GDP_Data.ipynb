# %% [markdown]
# # Chinese (Mainland) Economic Data - GDP Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. GDP Data

# %% [markdown]
# ### 1.1 GDP Data - Income Approach

# %% [markdown]
# #### 1.1.1 GDP Yearly Data - Income Approach

# %%
dai.query("""
SELECT *
FROM cn_macro_gdp_yearly
""").df()
# Out:
#     year           gni           gdp  primary_industry_added_value  \
# 0   2004  1.618402e+05  1.614154e+05                  20904.324177
# 1   2005  1.873189e+05  1.859989e+05                  21806.721870
# 2   2006  2.194385e+05  2.190285e+05                  23317.006840
# ..   ...           ...           ...                           ...
# 17  2021  1.149237e+06  1.141231e+06                  83216.450386
# 18  2022  1.204724e+06  1.194401e+06                  88207.000000
# 19  2023  1.260582e+06  1.249991e+06                  89755.200000
#
#     secondary_industry_added_value  tertiary_industry_added_value  \
# 0                     74284.976418                   66650.860312
# 1                     88082.178227                   77430.003021
# 2                    104359.227879                   91762.240097
# ..                             ...                            ...
# 17                   451544.081045                  614476.447180
# ...

# %%
dai.query("""
SELECT *
FROM cn_macro_gdp_index_yearly
""").df()
# Out:
#     year         gni         gdp  primary_industry_added  \
# 0   2004  110.504757  110.113621              106.105020
# 1   2005  110.900667  111.394592              105.073914
# 2   2006  113.308799  112.720956              104.755278
# ..   ...         ...         ...                     ...
# 17  2021  108.562224  108.448469              107.073796
# 18  2022  102.800000  103.000000              104.200000
# 19  2023  105.300000  105.200000              104.100000
#
#     secondary_industry_added  tertiary_industry_added  real_gdp_per_capita  \
# 0                 111.145922               110.120036           109.461559
# 1                 112.128391               112.357949           110.741375
# 2                 113.450696               114.134209           112.093305
# ..                       ...                      ...                  ...
# 17                108.674305               108.485871           108.351720
# ...

# %% [markdown]
# #### 1.1.2 GDP Quarterly Data - Income Approach

# %%
dai.query("""
SELECT *
FROM cn_macro_gdp
""").df()
# Out:
#    quarter       gdp  primary_industry_gdp  secondary_industry_gdp  \
# 0    2005A   41079.2                2884.0                 18159.0
# 1    2005B   45399.8                4438.6                 21425.3
# 2    2005C   48681.7                6527.7                 22774.0
# ..     ...       ...                   ...                     ...
# 77   2024B  328837.6               19010.1                124975.6
# 78   2024C  341758.0               26894.8                123239.0
# 79   2024D  373726.2               34050.3                135595.1
#
#     tertiary_industry_gdp    yoy    acc_gdp  acc_primary_industry_gdp  \
# 0                 20036.2  111.2    41079.2                    2884.0
# 1                 19536.0  111.1    86479.1                    7322.6
# 2                 19379.9  110.9   135160.7                   13850.3
# ..                    ...    ...        ...                       ...
# 77               184851.9  104.7   633599.4                   30468.8
# ...

# %% [markdown]
# ### 1.2 GDP Data - Expenditure Approach

# %%
dai.query("""
SELECT *
FROM cn_macro_gdp_expend_yearly
""").df()
# Out:
#     year    gdp_expend  gdp_final_consume_expend  gdp_household_expend  \
# 0   2004  1.613556e+05              89394.432491          65724.754970
# 1   2005  1.876575e+05             101872.525476          74153.706314
# 2   2006  2.195975e+05             115364.282244          82842.368079
# ..   ...           ...                       ...                   ...
# 17  2021  1.145283e+06             619688.157888         438015.185719
# 18  2022  1.202471e+06             643827.835009         450468.101614
# 19  2023  1.258647e+06             701360.580321         493247.162881
#
#     gdp_rural_household_expend  gdp_citizen_household_expend  gdp_gov_expend  \
# 0                 19232.570139                  46492.184832    23669.677520
# 1                 20911.957993                  53241.748321    27718.819161
# 2                 22639.556613                  60202.811466    32521.914165
# ..                         ...                           ...             ...
# ...

# %% [markdown]
# ## 2. GDP Sector & Industry Components

# %% [markdown]
# ### 2.1 GDP Sector Components

# %%
dai.query("""
SELECT *
FROM cn_macro_gdp_industry_yearly
""").df()
# Out:
#     year           gdp  agro_added_value  industry_added_value  \
# 0   2004  1.618402e+05      21410.734681          65774.896846
# 1   2005  1.873189e+05      22416.234801          77958.312597
# 2   2006  2.194385e+05      24036.361346          92235.796995
# ..   ...           ...               ...                   ...
# 17  2021  1.149237e+06      86994.785320         374545.576632
# 18  2022  1.204724e+06      92576.800000         395043.700000
# 19  2023  1.260582e+06      94462.600000         399103.100000
#
#     construction_added_value  sale_added_value  transport_added_value  \
# 0                8720.499875      12455.797350            9306.456376
# 1               10400.457932      13968.529100           10668.771578
# 2               12450.103324      16533.429178           12186.250539
# ..                       ...               ...                    ...
# 17              78741.184633     110147.046862           48423.874765
# ...

# %%
dai.query("""
SELECT *
FROM cn_macro_gdp_industry_index_yearly
""").df()
# Out:
#     year         gdp  agro_added_value  industry_added_value  \
# 0   2004  110.113621        106.299247            111.553732
# 1   2005  111.394592        105.233407            111.646371
# 2   2006  112.720956        105.000549            112.928587
# ..   ...         ...               ...                   ...
# 17  2021  108.448469        107.084545            110.376195
# 18  2022  103.000000        104.400000            102.700000
# 19  2023  105.200000        104.200000            104.200000
#
#     construction_added_value  sale_added_value  transport_added_value  \
# 0                 108.150194        106.567742             114.476882
# 1                 116.002637        113.026599             111.205063
# 2                 117.228093        119.463069             109.969858
# ..                       ...               ...                    ...
# 17                101.058679        110.967943             115.130431
# ...

# %% [markdown]
# ### 2.2 GDP Industry Components

# %%
dai.query("""
SELECT *
FROM cn_macro_industry_gdp_contribution_momentum_yearly
""").df()
# Out:
#     year  overall_contribution  primary_industry_contribution  \
# 0   2004                 100.0                       7.348221
# 1   2005                 100.0                       5.223253
# 2   2006                 100.0                       4.351760
# ..   ...                   ...                            ...
# 17  2021                 100.0                       6.445976
# 18  2022                 100.0                      10.800000
# 19  2023                 100.0                       5.900000
#
#     secondary_industry_contribution  tertiary_industry_contribution  \
# 0                         51.815706                       40.836072
# 1                         50.513681                       44.263066
# 2                         49.720037                       45.928203
# ..                              ...                             ...
# 17                        38.854397                       54.699627
# ...

# %% [markdown]
# ## 3. GDP Demand Components

# %%
dai.query("""
SELECT *
FROM cn_macro_demand_gdp_contribution_momentum_yearly
""").df()
# Out:
#     year  final_consume_expend_contribution  final_consume_expend_momentum  \
# 0   2004                          42.887563                       4.337486
# 1   2005                          56.819243                       6.474321
# 2   2006                          43.219631                       5.497950
# ..   ...                                ...                            ...
# 17  2021                          58.261397                       4.922196
# 18  2022                          39.385127                       1.162137
# 19  2023                          82.513111                       4.331608
#
#     gross_capital_format_contribution  gross_capital_format_momentum  \
# 0                           62.006901                       6.271143
# 1                           33.116397                       3.773478
# 2                           42.481185                       5.404013
# ..                                ...                            ...
# ...
