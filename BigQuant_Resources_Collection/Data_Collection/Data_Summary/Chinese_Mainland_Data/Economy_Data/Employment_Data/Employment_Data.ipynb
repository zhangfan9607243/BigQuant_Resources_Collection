# %% [markdown]
# # Chinese (Mainland) Economic Data - Employment Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Employment

# %%
dai.query("""
SELECT *
FROM cn_macro_employment_yearly
""").df()
# Out:
#     year  workforce   employ  primary_industry_employ  \
# 0   2004    75290.0  74264.0                34829.816
# 1   2005    76120.0  74647.0                33441.856
# 2   2006    76315.0  74978.0                31940.628
# ..   ...        ...      ...                      ...
# 17  2021    78024.0  74652.0                17072.000
# 18  2022    76863.0  73351.0                17663.000
# 19  2023        NaN  74041.0                16882.000
#
#     secondary_industry_employ  tertiary_industry_employ  urban_employ  \
# 0                   16709.400                 22724.784       27293.0
# 1                   17765.986                 23439.158       28389.0
# 2                   18894.456                 24142.916       29630.0
# ..                        ...                       ...           ...
# 17                  21712.000                 35868.000       46773.0
# 18                  21105.000                 34583.000       45931.0
# ...

# %% [markdown]
# ## 2. Unemployment

# %%
dai.query("""
SELECT *
FROM cn_macro_urban_unemploy_yearly
""").df()
# Out:
#     year  unemploy  unemploy_rate
# 0   2004     827.0           4.20
# 1   2005     839.0           4.20
# 2   2006     847.0           4.10
# ..   ...       ...            ...
# 17  2021    1040.0           3.96
# 18  2022    1203.0            NaN
# 19  2023    1074.0            NaN
#
# [20 rows x 3 columns]

# %% [markdown]
# ## 3. Wages

# %% [markdown]
# ### 3.1 Wages

# %%
dai.query("""
SELECT *
FROM cn_macro_urban_employ_wage_yearly
""").df()
# Out:
#     year           wage  state_owned_wage  collective_wage    others_wage  \
# 0   2004   17615.000000      11038.200000       876.200000    5700.600000
# 1   2005   20627.065730      12291.700000       906.400000    7429.000000
# 2   2006   24262.323070      13920.626290       983.792700    9357.904080
# ..   ...            ...               ...              ...            ...
# 17  2021  180817.525218      64547.855187      1920.008707  114349.661324
# 18  2022  190820.220941      69000.168207      1809.274980  120010.777754
# 19  2023  197416.700000               NaN              NaN            NaN
#
#     wage_index  state_owned_wage_index  collective_wage_index  \
# 0   114.908412              111.363109             101.049475
# 1   117.099631              111.356018             103.446702
# 2   117.623530              113.252246             108.538471
# ..         ...                     ...                    ...
# 17  110.169342              108.250733             104.246319
# ...

# %% [markdown]
# ### 3.2 Wages by Industry

# %%
# Total Wage
dai.query("""
SELECT *
FROM cn_macro_urban_industry_wage_yearly
""").df()
# Out:
#     year           wage       agro      mining          mfg     utility  \
# 0   2004   17615.000000  351.15724   831.84185   4316.44061   646.78144
# 1   2005   20627.065730  368.65081  1031.24673   5056.62724   741.82231
# 2   2006   24262.323070  403.33504  1259.56912   6035.77386   858.00161
# ..   ...            ...        ...         ...          ...         ...
# 17  2021  180817.525218  471.38679  3742.27431  35232.76659  4784.36308
# 18  2022  190820.220941  463.69384  4162.76084  36978.38697  4994.90488
# 19  2023  197416.700000        NaN         NaN          NaN         NaN
#
#     construction   transport           it        sale       hotel  \
# 0     1081.27447  1144.72140    404.32372   770.51954   221.22808
# 1     1324.67621  1279.50378    491.82788   831.95536   249.80960
# 2     1612.06319  1471.53963    587.40948   919.99830   280.04675
# ..           ...         ...          ...         ...         ...
# ...

# %%
# Average Wage
dai.query("""
SELECT *
FROM cn_macro_urban_industry_avg_wage_yearly
""").df()
# Out:
#     year      wage     agro    mining      mfg   utility  construction  \
# 0   2004   15920.0   7497.0   16774.0  14251.0   21543.0       12578.0
# 1   2005   18200.0   8207.0   20449.0  15934.0   24750.0       14112.0
# 2   2006   20856.0   9269.0   24125.0  18225.0   28424.0       16164.0
# ..   ...       ...      ...       ...      ...       ...           ...
# 17  2021  106837.0  53819.0  108467.0  92459.0  125332.0       75762.0
# 18  2022  114029.0  58976.0  121522.0  97528.0  132964.0       78295.0
# 19  2023  120698.0      NaN       NaN      NaN       NaN           NaN
#
#     transport        it      sale    hotel  financial   estate     lease  \
# 0     18071.0   33449.0   13012.0  12618.0    24299.0  18467.0   18723.0
# 1     20911.0   38799.0   15256.0  13876.0    29229.0  20253.0   21233.0
# 2     24111.0   43435.0   17796.0  15236.0    35495.0  22238.0   24510.0
# ..        ...       ...       ...      ...        ...      ...       ...
# ...

# %% [markdown]
# ### 3.3 Wages by Registered Type

# %%
dai.query("""
SELECT *
FROM cn_macro_registered_avg_wage_yearly
""").df()
# Out:
#     year  avg_wage  state_owned_avg_wage  collective_avg_wage  \
# 0   2004   15920.0               16445.0               9723.0
# 1   2005   18200.0               18978.0              11176.0
# 2   2006   20856.0               21706.0              12866.0
# ..   ...       ...                   ...                  ...
# 17  2021  106837.0              115583.0              74491.0
# 18  2022  114029.0              123623.0              77868.0
# 19  2023  120698.0                   NaN                  NaN
#
#     stock_cooperate_avg_wage  joint_ownership_avg_wage  limited_avg_wage  \
# 0                    11710.0                   15218.0           15103.0
# 1                    13808.0                   17476.0           17010.0
# 2                    15190.0                   19883.0           19366.0
# ..                       ...                       ...               ...
# 17                   90241.0                   92825.0           93209.0
# ...
