# %% [markdown]
# # Chinese (Mainland) Economic Data - Foreign Economy - Foreign Trade Data

# %%
import dai
import pandas as pd
pd.set_option('display.max_row', 6)
pd.set_option('display.max_column', None)

# %% [markdown]
# ## 1. Foreign Trade

# %%
dai.query("""
SELECT *
FROM cn_macro_trade_value_yearly
""").df()
# Out:
#     year  total_rmb  export_rmb  import_rmb  balance_rmb  total_dollar  \
# 0   2004    95539.1     49103.3     46435.8       2667.6     1154550.0
# 1   2005   116921.8     62648.1     54273.7       8374.4     1421910.0
# 2   2006   140974.7     77597.9     63376.9      14221.0     1760440.0
# ..   ...        ...         ...         ...          ...           ...
# 17  2021   387414.6    214255.2    173159.4      41095.9     5995790.0
# 18  2022   418011.6    237411.5    180600.1      56811.5     6270110.0
# 19  2023   417568.3    237725.9    179842.4      57883.0     5936830.0
#
#     export_dollar  import_dollar  balance_dollar
# 0        593330.0       561230.0         32100.0
# 1        761950.0       659950.0        102000.0
# 2        968980.0       791460.0        177520.0
# ..            ...            ...             ...
# 17      3316020.0      2679770.0        636250.0
# 18      3560539.0      2709574.0        850970.0
# 19      3380020.0      2556800.0             NaN
#
# ...

# %% [markdown]
# ## 2. Foreign Trade by SITC

# %% [markdown]
# ### 2.1 Export

# %%
dai.query("""
SELECT *
FROM cn_macro_export_value_sitc_yearly
""").df()
# Out:
#     year  export_dollar  primary_products  food_live_animal  drinks_tobacco  \
# 0   2004       593330.0           40549.0           18864.0          1214.0
# 1   2005       761950.0           49037.0           22480.0          1183.0
# 2   2006       968980.0           52919.0           25723.0          1193.0
# ..   ...            ...               ...               ...             ...
# 17  2021      3316020.0          140072.0           69846.0          2750.0
# 18  2022      3560539.0          169118.0           73498.0          3069.0
# 19  2023      3380020.0          164100.0           73320.0          3780.0
#
#     nonfood_raw_materials  mineral_fuel_lubricant_materials  oils_waxes  \
# 0                  5843.2                           14480.0       148.0
# 1                  7484.0                           17622.0       268.0
# 2                  7860.0                           17770.0       373.0
# ...

# %% [markdown]
# ### 2.2 Import

# %%
dai.query("""
SELECT *
FROM cn_macro_import_value_sitc_yearly
""").df()
# Out:
#     year  import_dollar  primary_products  food_live_animal  drinks_tobacco  \
# 0   2004       561230.0        117267.000          9154.000         548.000
# 1   2005       659950.0        147714.000          9388.000         783.000
# 2   2006       791460.0        187128.569          9994.272        1040.618
# ..   ...            ...               ...               ...             ...
# 17  2021      2679770.0        976631.000        122837.000        7626.000
# 18  2022      2709574.0       1089148.000        131145.000        7026.000
# 19  2023      2556800.0       1085410.000        129040.000        7900.000
#
#     nonfood_raw_materials  mineral_fuel_lubricant_materials  oils_waxes  \
# 0               55358.000                         47993.000    4214.000
# 1               70226.000                         63947.000    3370.000
# 2               83156.652                         89000.589    3936.437
# ...
