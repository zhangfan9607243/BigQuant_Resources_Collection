# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Resources_Collection/BigQuant_Resources_Collection/00_General_Resources/General_Tool")
from cn_general_tool import *

from bigcharts import Kline

# %%
sd, ed, = get_sd_ed('2024-11-28', '2024-11-28')

# %% [markdown]
# ### 1 Minute

# %%
sql_01m = """ 
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
)
SELECT * 
FROM data_base
"""

df_01m = get_dai_df(sql_01m, sd, ed, lag_min=240)
df_01m
# Out:
#                    date instrument     open    close     high      low  \
# 0   2024-11-28 09:25:00  600519.SH  1522.00  1522.00  1522.00  1522.00
# 1   2024-11-28 09:31:00  600519.SH  1522.00  1511.06  1522.00  1510.01
# 2   2024-11-28 09:32:00  600519.SH  1511.30  1513.95  1513.95  1511.05
# 3   2024-11-28 09:33:00  600519.SH  1514.00  1517.55  1517.83  1513.85
# 4   2024-11-28 09:34:00  600519.SH  1516.28  1516.85  1516.94  1513.94
# ..                  ...        ...      ...      ...      ...      ...
# 236 2024-11-28 14:56:00  600519.SH  1514.00  1513.00  1515.00  1512.51
# 237 2024-11-28 14:57:00  600519.SH  1512.60  1514.94  1514.95  1512.00
# 238 2024-11-28 14:58:00  600519.SH  1514.90  1514.90  1514.90  1514.90
# 239 2024-11-28 14:59:00  600519.SH  1514.90  1514.90  1514.90  1514.90
# 240 2024-11-28 15:00:00  600519.SH  1514.90  1518.00  1518.00  1514.90
#
#      volume        amount
# 0     31200  4.748640e+07
# 1     90100  1.366267e+08
# 2     56900  8.601926e+07
# 3     38400  5.815474e+07
# 4     19400  2.940162e+07
# ..      ...           ...
# 236   17760  2.689244e+07
# 237   11301  1.710923e+07
# 238     100  1.514900e+05
# 239       0  0.000000e+00
# 240   99300  1.507374e+08
#
# [241 rows x 8 columns]

# %%
Kline(df_01m)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=b7983df4af0c4a0b9415885abe06194a></div><script>require([`echarts`],(a=>{let ce=1512.58,d0=5,r=1515,bO=1508.01,c9=1512.42,t=1516.9,b8=1510.7,am=1513.21,aF=1513.5,aC=1512.95,aZ=1512.32,cJ=1517.53,d8=`solid`,bW=1506.64,S=1519.29,bR=1506.99,aM=1512.89,K=1521.93,bH=1505.33,cq=1517.56,c2=1511,y=1519.1,bN=1507.55,e=`b7983df4af0c4a0b9415885abe06194a`,by=1503.34,i=1522,aH=1513.63,ck=1514.75,d9=`blank`,bz=1503,C=1521.77,aX=1514.03,bM=1507.09,bS=1506.09,ci=1513.4,c6=1511.8,ap=1514.51,bw=1504.91,aQ=1512.34,cn=1516.87,a$=1512.33,o=1517.83,a7=1515.01,bc=1508.18,R=1519.83,c3=1512.23,bp=1505.01,bT=1508.19,ay=1514.14,p=1516.85,a
p=1518.01,aT=1512.1,B=1520.88;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[i,i,i,i],[i,1511.06,j,i],[1511.3,k,1511.05,k],[l,m,n,o],[1516.28,p,1513.94,1516.94],[p,q,r,q],[s,1517.99,t,1518.5],[u,v,u,w],[w,x,1519.13,w],[x,y,y,x],[z,A,z,A],[A,v,v,1523.23],[B,C,B,1522.28],[C,1524.57,C,1524.66],[1524.6,1524.16,1523.16,1524.99],[1524.8,D,D,1524.91],[E,F,F,E],[1522.32,G,H,G],[I,J,1521.02,I],[J,H,1521.94,J],[H,K,K,H],[K,i,v,1522.14],[i,L,i,L],[M,N,N,1522.55],[N,O,O,N],[P,1522.42,P,M],[1521.36,1520.79,1520.72,1522.29],[1520.91,1520.76,x,1521.2],[Q,R,R,Q],[R,S,1519.2,O],[S,T,1519.25,1519.81],[T,U,U,1519.8],[1517.54,1517.11,V,W],[X,1517.85,1517.05,X],[Y,q,Z,_],[$,$,_,$],[$,1518.78,1518.59 ...

# %% [markdown]
# ### 5 Minute

# %%
sql_05m = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
)
SELECT 
    date,
    instrument,
    DATE_TRUNC('hour', date) + INTERVAL '5 min' * CAST(FLOOR(EXTRACT(minute FROM date) / 5) AS BIGINT) AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    row_number() OVER (PARTITION BY _period ORDER BY date) AS _rn,
FROM data_base
QUALIFY _rn = 1
ORDER BY date, instrument
"""

df_05m = get_dai_df(sql_05m, sd, ed, lag_min=240)
df_05m
# Out:
#                   date instrument     open    close     high      low  \
# 0  2024-11-28 09:25:00  600519.SH  1522.00  1522.00  1522.00  1522.00
# 1  2024-11-28 09:31:00  600519.SH  1522.00  1516.85  1522.00  1510.01
# 37 2024-11-28 13:55:00  600519.SH  1517.97  1515.00  1517.97  1515.00
# 38 2024-11-28 14:00:00  600519.SH  1515.00  1514.45  1515.63  1513.20
# 39 2024-11-28 14:05:00  600519.SH  1514.08  1514.77  1515.17  1513.10
# 40 2024-11-28 14:10:00  600519.SH  1514.52  1517.50  1517.80  1514.52
# 41 2024-11-28 14:15:00  600519.SH  1517.43  1518.00  1518.66  1517.43
# 42 2024-11-28 14:20:00  600519.SH  1518.08  1516.72  1518.40  1516.31
# 43 2024-11-28 14:25:00  600519.SH  1516.87  1516.76  1517.00  1516.30
# 44 2024-11-28 14:30:00  600519.SH  1516.76  1515.89  1516.98  1514.00
# 45 2024-11-28 14:35:00  600519.SH  1515.07  1515.25  1516.91  1515.01
# 46 2024-11-28 14:40:00  600519.SH  1515.25  1515.00  1516.38  1514.50
# 47 2024-11-28 14:45:00  600519.SH  1515.49  1514.56  1516.80  1514.00
# 48 2024-11-28 14:50:00  600519.SH  1514.51  1513.93  1514.88  1511.02
# 49 2024-11-28 14:55:00  600519.SH  1512.50  1514.90  1515.00  1512.00
# 50 2024-11-28 15:00:00  600519.SH  1514.90  1518.00  1518.00  1514.90
#
#           amount  volume
# 0   4.748640e+07   31200
# 1   3.102023e+08  204800
# 2   1.439652e+08   94793
# 3   1.715926e+08  112700
# 4   1.043314e+08   68504
# 5   8.034414e+07   52800
# 6   8.866461e+07   58300
# 7   7.348013e+07   48400
# 8   6.102164e+07   40200
# 9   7.387700e+07   48718
# 10  8.313830e+07   54897
# 11  5.253242e+07   34700
# 12  5.573091e+07   36800
# 13  6.083638e+07   40200
# 14  5.297691e+07   35000
# 15  6.186702e+07   40900
# 16  5.613462e+07   37100
# 17  4.947416e+07   32700
# 18  5.221852e+07   34500
# 19  9.499509e+07   62829
# 20  1.080974e+08   71600
# 21  6.426564e+07   42600
# 22  9.373028e+07   62200
# 23  7.721374e+07   51300
# 24  6.568531e+07   43700
# 25  1.323266e+07    8800
# 26  6.468748e+07   43000
# 27  5.965473e+07   39600
# 28  2.471999e+07   16400
# 29  3.617938e+07   24007
# 30  2.592302e+07   17200
# 31  4.135128e+07   27400
# 32  3.506549e+07   23200
# 33  4.278925e+07   28300
# 34  4.628066e+07   30600
# 35  4.540571e+07   30000
# 36  1.149088e+08   75770
# 37  3.503710e+07   23100
# 38  4.119390e+07   27200
# 39  3.907655e+07   25800
# 40  5.321260e+07   35100
# 41  5.040732e+07   33200
# 42  7.587747e+07   50000
# 43  3.109328e+07   20500
# 44  5.440682e+07   35900
# 45  5.505447e+07   36311
# 46  6.334401e+07   41800
# 47  8.697530e+07   57403
# 48  9.002088e+07   59510
# 49  6.716477e+07   44361
# 50  1.507374e+08   99300

# %%
Kline(df_05m)
# Out:
ccc`,"borderRadius":g,"pageButtonItemGap":T,"pageButtonPosition":W,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":X,"animationDurationUpdate":800,"selector":!1,"selectorPosition":Y,"selectorItemGap":7,"selectorButtonGap":U,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":Z,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":V},"borderWidth":g,"padding":T,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":W,"nameGap":X,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":T,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":_,"opacity":_,"curveness":g,"type":$}},"data":[`2024-11-28T09:25:00`,`2024-11-28T09:31:00`,`2024-11-28T09:35:00`,`2024-11-28T09:40:00`,`2024-11-28T09:45:00`,`2024-11-28T09:50:00`,`2024-11-28T09:55:00`,`2024-11-28T10:00:00`,`2024-11-28T10:05:00`,`2024-11-28T10:10:00`,`2024-11-28T10:15:00`,`2024-11-28T10:20:00`,`2024-11-28T10:25:00`,`2024-11-28T10:30:00`,`2024-11-28T10:35:00`,`2024-11-28T10:40:00`,`2024-11-28T10:45:00`,`2024-11-28T10:50:00`,`2024-11-28T10:55:00`,`2024-11-28T11:00:00`,`2024-11-28T11:05:00`,`2024-11-28T11:10:00`,`2024-11-28T11:15:00`,`2024-11-28T11:20:00`,`2024-11-28T11:25:00`,`2024-11-28T11:30:00`,`2024-1 ...

# %% [markdown]
# ### 10 Minute

# %%
sql_10m = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
)
SELECT 
    date,
    instrument,
    DATE_TRUNC('hour', date) + INTERVAL '10 min' * CAST(FLOOR(EXTRACT(minute FROM date) / 10) AS BIGINT) AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    row_number() OVER (PARTITION BY _period ORDER BY date) AS _rn,
FROM data_base
QUALIFY _rn = 1
ORDER BY date, instrument
"""

df_10m = get_dai_df(sql_10m, sd, ed, lag_min=240)
df_10m
# Out:
# 21  1.036199e+08   68300
# 22  1.069707e+08   70500
# 23  1.094613e+08   72211
# 24  1.503193e+08   99203
# 25  1.571856e+08  103871
# 26  1.507374e+08   99300

# %%
Kline(df_10m)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=57c78a28da694493bad8948dd03384b4></div><script>require([`echarts`],(a=>{let A=5,u=1515,j=1519.4,t=1512.42,B=10,h=`Kline`,z=1514.9,F=`auto`,I=`solid`,l=1519.29,r=1503.21,H=1,y=1515.25,i=1522,G=100,w=1518,E=15,J=`blank`,g=0,f=`cubicOut`,m=1516.98,D=`end`,e=`57c78a28da694493bad8948dd03384b4`,s=1511.2,p=1514.14,k=1522.16,o=1513,v=1514.52,n=1517.96,q=1514,C=14,x=1516.76;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[i,i,i,i],[i,1519.1,1510.01,i],[j,k,j,1524.99],[k,l,1519.2,1522.6],[l,1517.35,m,1519.81],[n,1514.13,o,n],[1513.97,1514.12,o,1515.45],[p,1513.8,1512.95,p],[1513.74,1513.27,1512.06,1514.03],[1513.3,1513.35,1512.32,q],[1513.15,1508.78,1508,1513.59],[1508.97,1505.07,1505.01,1509.29],[1505.39,1504.29,1502,1506.49],[1504.3,r,1503.03,1504.57],[r,1508.41,r,1508.49],[1508.4,1508.15,1505.21,1508.48],[1507.01,s,1506.64,1511.4],[s,t,1510.46,o],[t,1514.75,1511.55,1514.97],[1515.39,u,1514.5,1518.85],[u,1514.77,1513.1,1515.63],[v,w,v,1518.66],[1518.08,x,1516.3,1518.4],[x,y,q,m],[y,1514.56,q,1516.8],[1514.51,z,1511.02,u],[z,w,z,w]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":A,"itemGap":B,"itemWidth":25,"itemHeight":C,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":A,"pageButtonPosition":D,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":E,"animationDurationUpdate":800,"selector":!1,"selectorPosition":F,"selectorItemGap":7,"selectorButtonGap":B,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":G,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":C},"borderWidth":g,"padding":A,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":D,"nameGap":E,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":A,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":H,"opacity":H,"curveness":g,"type":I}},"data":[`2024-11-28T09:25:00`,`2024-11-28T09:31:00`,`2024-11-28T09:40:00`,`2024-11-28T09:50:00`,`2024-11-28T10:00:00`,`2024-11-28T10:10:00`,`2024-11-28T10:20:00`,`2024-11-28T10:30:00`,`2024-11-28T10:40:00`,`2024-11-28T10:50:00`,`2024-11-28T11:00:00`,`2024-11-28T11:10:00`,`2024-11-28T11:20:00`,`2024-11-28T11:30:00`,`2024-11-28T13:01:00`,`2024-11-28T13:10:00`,`2024-11-28T13:20:00`,`2024-11-28T13:30:00`,`2024-11-28T13:40:00`,`2024-11-28T13:50:00`,`2024-11-28T14:00:00`,`2024-11-28T14:10:00`,`2024-11-28T14:20:00`,`2024-11-28T14:30:00`,`2024-11-28T14:40:00`,`2024-11-28T14:50:00`,`2024-11-28T15:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":D,"nameGap":E,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":A,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":H,"opacity":H,"curveness":g,"type":I}}}],"title":[{"show":!0,"target":J,"subtarget":J,"padding":A,"itemGap":B,"textAlign":F,"textVerticalAlign":F,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":G,"orient":`horizontal`,"xAxisIndex":[g,H],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### 15 Minute

# %%
sql_15m = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
)
SELECT 
    date,
    instrument,
    DATE_TRUNC('hour', date) + INTERVAL '15 min' * CAST(FLOOR(EXTRACT(minute FROM date) / 15) AS BIGINT) AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    row_number() OVER (PARTITION BY _period ORDER BY date) AS _rn,
FROM data_base
QUALIFY _rn = 1
ORDER BY date, instrument
"""

df_15m = get_dai_df(sql_15m, sd, ed, lag_min=240)
df_15m
# Out:
#                   date instrument     open    close     high      low  \
# 0  2024-11-28 09:25:00  600519.SH  1522.00  1522.00  1522.00  1522.00
# 1  2024-11-28 09:31:00  600519.SH  1522.00  1524.16  1524.99  1510.01
# 2  2024-11-28 09:45:00  600519.SH  1524.80  1519.29  1524.91  1519.20
# 3  2024-11-28 10:00:00  600519.SH  1519.29  1515.01  1519.81  1515.00
# 4  2024-11-28 10:15:00  600519.SH  1515.00  1514.12  1515.52  1513.00
# 5  2024-11-28 10:30:00  600519.SH  1514.14  1512.20  1514.14  1512.06
# 6  2024-11-28 10:45:00  600519.SH  1512.18  1513.35  1514.03  1512.10
# 7  2024-11-28 11:00:00  600519.SH  1513.15  1508.10  1513.59  1508.00
# 8  2024-11-28 11:15:00  600519.SH  1508.18  1504.29  1509.20  1502.00
# 9  2024-11-28 11:30:00  600519.SH  1504.30  1503.21  1504.57  1503.03
# 10 2024-11-28 13:01:00  600519.SH  1503.21  1506.00  1508.49  1503.21
# 11 2024-11-28 13:15:00  600519.SH  1505.90  1511.20  1511.40  1505.21
# 12 2024-11-28 13:30:00  600519.SH  1511.20  1512.58  1513.00  1510.46
# 13 2024-11-28 13:45:00  600519.SH  1512.58  1515.00  1518.85  1512.58
# 14 2024-11-28 14:00:00  600519.SH  1515.00  1517.50  1517.80  1513.10
# 15 2024-11-28 14:15:00  600519.SH  1517.43  1516.76  1518.66  1516.30
# 16 2024-11-28 14:30:00  600519.SH  1516.76  1515.00  1516.98  1514.00
# 17 2024-11-28 14:45:00  600519.SH  1515.49  1514.90  1516.80  1511.02
# 18 2024-11-28 15:00:00  600519.SH  1514.90  1518.00  1518.00  1514.90
#
#           amount  volume
# 0   4.748640e+07   31200
# 1   6.257600e+08  412293
# 2   2.733401e+08  179604
# 3   2.083788e+08  137318
# 4   1.914016e+08  126397
# 5   1.756803e+08  116100
# 6   1.578273e+08  104300
# 7   2.673581e+08  177029
# 8   2.366293e+08  157200
# 9   1.323266e+07    8800
# 10  1.490622e+08   99000
# 11  1.034537e+08   68607
# 12  1.241354e+08   82100
# 13  1.953517e+08  128870
# 14  1.334831e+08   88100
# 15  1.573781e+08  103700
# 16  1.728053e+08  114011
# 17  2.441609e+08  161274
# 18  1.507374e+08   99300

# %%
Kline(df_15m)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=d43239442623401a96861453d5a3bfaf></div><script>require([`echarts`],(a=>{let p=1512.58,t=5,k=1515,u=10,h=`Kline`,r=1514.9,y=`auto`,B=`solid`,j=1519.29,n=1503.21,A=1,z=100,i=1522,s=1518,x=15,C=`blank`,g=0,f=`cubicOut`,w=`end`,o=1511.2,m=1514.14,l=1513,v=14,q=1516.76,e=`d43239442623401a96861453d5a3bfaf`;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[i,i,i,i],[i,1524.16,1510.01,1524.99],[1524.8,j,1519.2,1524.91],[j,1515.01,k,1519.81],[k,1514.12,l,1515.52],[m,1512.2,1512.06,m],[1512.18,1513.35,1512.1,1514.03],[1513.15,1508.1,1508,1513.59],[1508.18,1504.29,1502,1509.2],[1504.3,n,1503.03,1504.57],[n,1506,n,1508.49],[1505.9,o,1505.21,1511.4],[o,p,1510.46,l],[p,k,p,1518.85],[k,1517.5,1513.1,1517.8],[1517.43,q,1516.3,1518.66],[q,k,1514,1516.98],[1515.49,r,1511.02,1516.8],[r,s,r,s]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":t,"itemGap":u,"itemWidth":25,"itemHeight":v,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":t,"pageButtonPosition":w,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":x,"animationDurationUpdate":800,"selector":!1,"selectorPosition":y,"selectorItemGap":7,"selectorButtonGap":u,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":z,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":v},"borderWidth":g,"padding":t,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":w,"nameGap":x,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":t,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":A,"opacity":A,"curveness":g,"type":B}},"data":[`2024-11-28T09:25:00`,`2024-11-28T09:31:00`,`2024-11-28T09:45:00`,`2024-11-28T10:00:00`,`2024-11-28T10:15:00`,`2024-11-28T10:30:00`,`2024-11-28T10:45:00`,`2024-11-28T11:00:00`,`2024-11-28T11:15:00`,`2024-11-28T11:30:00`,`2024-11-28T13:01:00`,`2024-11-28T13:15:00`,`2024-11-28T13:30:00`,`2024-11-28T13:45:00`,`2024-11-28T14:00:00`,`2024-11-28T14:15:00`,`2024-11-28T14:30:00`,`2024-11-28T14:45:00`,`2024-11-28T15:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":w,"nameGap":x,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":t,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":A,"opacity":A,"curveness":g,"type":B}}}],"title":[{"show":!0,"target":C,"subtarget":C,"padding":t,"itemGap":u,"textAlign":y,"textVerticalAlign":y,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":z,"orient":`horizontal`,"xAxisIndex":[g,A],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### 20 Minute

# %%
sql_20m = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
),
data_periods AS (
    SELECT
        *,
        CASE 
            WHEN EXTRACT(minute FROM date) BETWEEN 11 AND 30 THEN DATE_TRUNC('hour', date) + INTERVAL '11 minute'
            WHEN EXTRACT(minute FROM date) BETWEEN 31 AND 50 THEN DATE_TRUNC('hour', date) + INTERVAL '31 minute'
            ELSE DATE_TRUNC('hour', date) + INTERVAL '51 minute'
        END AS period
    FROM data_base
)
SELECT 
    date,
    instrument,
    period AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    row_number() OVER (PARTITION BY _period ORDER BY date) AS _rn,
FROM data_periods
QUALIFY _rn = 1
ORDER BY date, instrument
"""

df_20m = get_dai_df(sql_20m, sd, ed, lag_min=240)
df_20m
# Out:
#                   date instrument     open    close     high      low  \
# 0  2024-11-28 09:25:00  600519.SH  1522.00  1522.00  1522.00  1522.00
# 1  2024-11-28 09:31:00  600519.SH  1522.00  1521.93  1524.99  1510.01
# 2  2024-11-28 09:51:00  600519.SH  1521.93  1519.29  1522.60  1519.20
# 3  2024-11-28 10:00:00  600519.SH  1519.29  1513.35  1519.81  1512.32
# 4  2024-11-28 10:11:00  600519.SH  1517.51  1513.30  1517.90  1513.00
# 5  2024-11-28 10:31:00  600519.SH  1513.31  1513.09  1514.14  1512.06
# 6  2024-11-28 11:00:00  600519.SH  1513.15  1509.00  1513.59  1508.00
# 7  2024-11-28 11:11:00  600519.SH  1509.04  1503.21  1509.29  1502.00
# 8  2024-11-28 13:01:00  600519.SH  1503.21  1515.00  1518.85  1503.21
# 9  2024-11-28 13:11:00  600519.SH  1508.00  1511.18  1511.40  1505.21
# 10 2024-11-28 13:31:00  600519.SH  1511.18  1516.86  1516.87  1510.46
# 11 2024-11-28 14:00:00  600519.SH  1515.00  1514.90  1515.63  1511.02
# 12 2024-11-28 14:11:00  600519.SH  1514.88  1516.61  1518.66  1514.70
# 13 2024-11-28 14:31:00  600519.SH  1516.79  1513.00  1516.91  1513.00
# 14 2024-11-28 15:00:00  600519.SH  1514.90  1518.00  1518.00  1514.90
#
#           amount  volume
# 0   4.748640e+07   31200
# 1   7.478995e+08  492497
# 2   1.512007e+08   99400
# 3   2.354598e+08  155300
# 4   2.708594e+08  178815
# 5   2.269688e+08  150000
# 6   2.169742e+08  143629
# 7   3.002459e+08  199400
# 8   2.496815e+08  165256
# 9   1.265216e+08   83907
# 10  1.957999e+08  129414
# 11  2.288326e+08  151171
# 12  2.084773e+08  137400
# 13  2.705174e+08  178514
# 14  1.507374e+08   99300

# %%
Kline(df_20m)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=58c64513026742dfb57ec6e262a45eb4></div><script>require([`echarts`],(a=>{let g=0,s=5,f=`cubicOut`,o=1515,v=`end`,t=10,p=1511.18,h=`Kline`,q=1514.9,x=`auto`,A=`solid`,k=1519.29,j=1521.93,e=`58c64513026742dfb57ec6e262a45eb4`,n=1503.21,m=1508,z=1,l=1513,y=100,i=1522,r=1518,u=14,w=15,B=`blank`;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[i,i,i,i],[i,j,1510.01,1524.99],[j,k,1519.2,1522.6],[k,1513.35,1512.32,1519.81],[1517.51,1513.3,l,1517.9],[1513.31,1513.09,1512.06,1514.14],[1513.15,1509,m,1513.59],[1509.04,n,1502,1509.29],[n,o,n,1518.85],[m,p,1505.21,1511.4],[p,1516.86,1510.46,1516.87],[o,q,1511.02,1515.63],[1514.88,1516.61,1514.7,1518.66],[1516.79,l,l,1516.91],[q,r,q,r]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":s,"itemGap":t,"itemWidth":25,"itemHeight":u,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":s,"pageButtonPosition":v,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":w,"animationDurationUpdate":800,"selector":!1,"selectorPosition":x,"selectorItemGap":7,"selectorButtonGap":t,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":y,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":u},"borderWidth":g,"padding":s,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":v,"nameGap":w,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":s,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":z,"opacity":z,"curveness":g,"type":A}},"data":[`2024-11-28T09:25:00`,`2024-11-28T09:31:00`,`2024-11-28T09:51:00`,`2024-11-28T10:00:00`,`2024-11-28T10:11:00`,`2024-11-28T10:31:00`,`2024-11-28T11:00:00`,`2024-11-28T11:11:00`,`2024-11-28T13:01:00`,`2024-11-28T13:11:00`,`2024-11-28T13:31:00`,`2024-11-28T14:00:00`,`2024-11-28T14:11:00`,`2024-11-28T14:31:00`,`2024-11-28T15:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":v,"nameGap":w,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":s,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":z,"opacity":z,"curveness":g,"type":A}}}],"title":[{"show":!0,"target":B,"subtarget":B,"padding":s,"itemGap":t,"textAlign":x,"textVerticalAlign":x,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":y,"orient":`horizontal`,"xAxisIndex":[g,z],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### 30 Minute

# %%
sql_30m = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount,
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
)
SELECT 
    date,
    instrument,
    DATE_TRUNC('hour', date) + INTERVAL '30 min' * CAST(FLOOR(EXTRACT(minute FROM date) / 30) AS BIGINT) AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    row_number() OVER (PARTITION BY _period ORDER BY date) AS _rn,
FROM data_base
QUALIFY _rn = 1
ORDER BY date, instrument
"""

df_30m = get_dai_df(sql_30m, sd, ed, lag_min=240)
df_30m
# Out:
#                   date instrument     open    close     high      low  \
# 0  2024-11-28 09:25:00  600519.SH  1522.00  1522.00  1522.00  1522.00
# 1  2024-11-28 09:31:00  600519.SH  1522.00  1519.29  1524.99  1510.01
# 2  2024-11-28 10:00:00  600519.SH  1519.29  1514.12  1519.81  1513.00
# 3  2024-11-28 10:30:00  600519.SH  1514.14  1513.35  1514.14  1512.06
# 4  2024-11-28 11:00:00  600519.SH  1513.15  1504.29  1513.59  1502.00
# 5  2024-11-28 11:30:00  600519.SH  1504.30  1503.21  1504.57  1503.03
# 6  2024-11-28 13:01:00  600519.SH  1503.21  1511.20  1511.40  1503.21
# 7  2024-11-28 13:30:00  600519.SH  1511.20  1515.00  1518.85  1510.46
# 8  2024-11-28 14:00:00  600519.SH  1515.00  1516.76  1518.66  1513.10
# 9  2024-11-28 14:30:00  600519.SH  1516.76  1514.90  1516.98  1511.02
# 10 2024-11-28 15:00:00  600519.SH  1514.90  1518.00  1518.00  1514.90
#
#           amount  volume
# 0   4.748640e+07   31200
# 1   8.991002e+08  591897
# 2   3.997804e+08  263715
# 3   3.335076e+08  220400
# 4   5.039874e+08  334229
# 5   1.323266e+07    8800
# 6   2.525159e+08  167607
# 7   3.194871e+08  210970
# 8   2.908611e+08  191800
# 9   4.169662e+08  275285
# 10  1.507374e+08   99300

# %%
Kline(df_30m)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=c268a7c41bd8414789696895c140ca50></div><script>require([`echarts`],(a=>{let g=0,r=5,f=`cubicOut`,n=1515,u=`end`,s=10,h=`Kline`,p=1514.9,w=`auto`,e=`c268a7c41bd8414789696895c140ca50`,z=`solid`,j=1519.29,l=1503.21,y=1,m=1511.2,k=1514.14,x=100,i=1522,q=1518,t=14,v=15,o=1516.76,A=`blank`;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[i,i,i,i],[i,j,1510.01,1524.99],[j,1514.12,1513,1519.81],[k,1513.35,1512.06,k],[1513.15,1504.29,1502,1513.59],[1504.3,l,1503.03,1504.57],[l,m,l,1511.4],[m,n,1510.46,1518.85],[n,o,1513.1,1518.66],[o,p,1511.02,1516.98],[p,q,p,q]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":r,"itemGap":s,"itemWidth":25,"itemHeight":t,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":r,"pageButtonPosition":u,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":v,"animationDurationUpdate":800,"selector":!1,"selectorPosition":w,"selectorItemGap":7,"selectorButtonGap":s,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":x,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":t},"borderWidth":g,"padding":r,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":u,"nameGap":v,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":r,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":y,"opacity":y,"curveness":g,"type":z}},"data":[`2024-11-28T09:25:00`,`2024-11-28T09:31:00`,`2024-11-28T10:00:00`,`2024-11-28T10:30:00`,`2024-11-28T11:00:00`,`2024-11-28T11:30:00`,`2024-11-28T13:01:00`,`2024-11-28T13:30:00`,`2024-11-28T14:00:00`,`2024-11-28T14:30:00`,`2024-11-28T15:00:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":u,"nameGap":v,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":r,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":y,"opacity":y,"curveness":g,"type":z}}}],"title":[{"show":!0,"target":A,"subtarget":A,"padding":r,"itemGap":s,"textAlign":w,"textVerticalAlign":w,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":x,"orient":`horizontal`,"xAxisIndex":[g,y],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### 1 Hour

# %%
sql_1h = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
),
data_periods AS (
    SELECT
        *,
        CASE 
            WHEN date::time >= TIME '09:25:00' AND date::time <= TIME '10:30:00' THEN DATE_TRUNC('day', date) + INTERVAL '09:25:00'
            WHEN date::time >= TIME '10:30:00' AND date::time <= TIME '11:30:00' THEN DATE_TRUNC('day', date) + INTERVAL '10:30:00'
            WHEN date::time >= TIME '13:01:00' AND date::time <= TIME '14:00:00' THEN DATE_TRUNC('day', date) + INTERVAL '13:01:00'
            WHEN date::time >= TIME '14:00:00' AND date::time <= TIME '15:00:00' THEN DATE_TRUNC('day', date) + INTERVAL '14:00:00'
        END AS period
    FROM data_base
    WHERE date::time >= TIME '09:25:00' AND date::time <= TIME '15:00:00'
)
SELECT 
    date,
    instrument,
    period AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    ROW_NUMBER()      OVER (PARTITION BY _period ORDER BY date) AS _rn
FROM data_periods
QUALIFY _rn = 1
ORDER BY _period, instrument
"""

df_1h = get_dai_df(sql_1h, sd, ed, lag_min=240)
df_1h
# Out:
#                  date instrument     open    close     high      low  \
# 0 2024-11-28 09:25:00  600519.SH  1522.00  1513.30  1524.99  1510.01
# 1 2024-11-28 10:31:00  600519.SH  1513.31  1503.21  1514.14  1502.00
# 2 2024-11-28 13:01:00  600519.SH  1503.21  1515.01  1518.85  1503.21
# 3 2024-11-28 14:01:00  600519.SH  1515.55  1518.00  1518.66  1511.02
#
#          amount  volume
# 0  1.359537e+09  895512
# 1  8.375581e+08  554729
# 2  5.804874e+08  384177
# 3  8.500803e+08  560785

# %%
Kline(df_1h)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=a587e2feaea74a6a9af79fa51cf2ba12></div><script>require([`echarts`],(a=>{let g=0,j=5,f=`cubicOut`,m=`end`,k=10,h=`Kline`,o=`auto`,r=`solid`,i=1503.21,q=1,e=`a587e2feaea74a6a9af79fa51cf2ba12`,p=100,l=14,n=15,s=`blank`;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[1522,1513.3,1510.01,1524.99],[1513.31,i,1502,1514.14],[i,1515.01,i,1518.85],[1515.55,1518,1511.02,1518.66]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":j,"itemGap":k,"itemWidth":25,"itemHeight":l,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":j,"pageButtonPosition":m,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":n,"animationDurationUpdate":800,"selector":!1,"selectorPosition":o,"selectorItemGap":7,"selectorButtonGap":k,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":p,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":l},"borderWidth":g,"padding":j,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":m,"nameGap":n,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":j,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":q,"opacity":q,"curveness":g,"type":r}},"data":[`2024-11-28T09:25:00`,`2024-11-28T10:31:00`,`2024-11-28T13:01:00`,`2024-11-28T14:01:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":m,"nameGap":n,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":j,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":q,"opacity":q,"curveness":g,"type":r}}}],"title":[{"show":!0,"target":s,"subtarget":s,"padding":j,"itemGap":k,"textAlign":o,"textVerticalAlign":o,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":p,"orient":`horizontal`,"xAxisIndex":[g,q],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>

# %% [markdown]
# ### 2 Hour

# %%
sql_2h = """
WITH 
data_base AS (
    SELECT
        date,
        instrument,
        open,
        close,
        high,
        low,
        volume,
        amount
    FROM cn_stock_bar1m
    WHERE instrument = '600519.SH'
),
data_periods AS (
    SELECT
        *,
        CASE 
            WHEN date::time >= TIME '09:25:00' AND date::time <= TIME '11:30:00' THEN DATE_TRUNC('day', date) + INTERVAL '09:25:00'
            WHEN date::time >= TIME '13:01:00' AND date::time <= TIME '15:00:00' THEN DATE_TRUNC('day', date) + INTERVAL '13:01:00'
        END AS period
    FROM data_base
    WHERE date::time >= TIME '09:25:00' AND date::time <= TIME '15:00:00'
)
SELECT 
    date,
    instrument,
    period AS _period,
    FIRST_VALUE(open) OVER (PARTITION BY _period, instrument ORDER BY date) AS open,
    LAST_VALUE(close) OVER (PARTITION BY _period, instrument ORDER BY date ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS close,
    MAX(high)         OVER (PARTITION BY _period, instrument) AS high,
    MIN(low)          OVER (PARTITION BY _period, instrument) AS low,
    SUM(amount)       OVER (PARTITION BY _period, instrument) AS amount,
    SUM(volume)       OVER (PARTITION BY _period, instrument) AS volume,
    ROW_NUMBER()      OVER (PARTITION BY _period ORDER BY date) AS _rn
FROM data_periods
QUALIFY _rn = 1
ORDER BY _period, instrument
"""

df_2h = get_dai_df(sql_2h, sd, ed, lag_min=240)
df_2h
# Out:
#                  date instrument     open    close     high      low  \
# 0 2024-11-28 09:25:00  600519.SH  1522.00  1503.21  1524.99  1502.00
# 1 2024-11-28 13:01:00  600519.SH  1503.21  1518.00  1518.85  1503.21
#
#          amount   volume
# 0  2.197095e+09  1450241
# 1  1.430568e+09   944962

# %%
Kline(df_2h)
# Out:
# <script>require.config({paths:{'echarts':`https://cdn.bigquant.com/aistatic/aistudio/lib/echarts/assets/echarts.min`}})</script><div style="width:100%; height:500px;"id=30ab0d3bd33b40f5a0bc746ece79d2bc></div><script>require([`echarts`],(a=>{let g=0,j=5,f=`cubicOut`,m=`end`,k=10,h=`Kline`,o=`auto`,r=`solid`,i=1503.21,q=1,p=100,e=`30ab0d3bd33b40f5a0bc746ece79d2bc`,s=`blank`,l=14,n=15;var b=a.init(document.getElementById(e),`white`,{renderer:`canvas`});var c=a.init(document.getElementById(e));window.addEventListener(`resize`,(()=>{c.resize()}));var d={"animation":!0,"animationThreshold":2000,"animationDuration":1000,"animationEasing":f,"animationDelay":g,"animationDurationUpdate":300,"animationEasingUpdate":f,"animationDelayUpdate":g,"aria":{"enabled":!1},"color":[`#5470c6`,`#91cc75`,`#fac858`,`#ee6666`,`#73c0de`,`#3ba272`,`#fc8452`,`#9a60b4`,`#ea7ccc`],"series":[{"type":`candlestick`,"name":h,"colorBy":`series`,"data":[[1522,i,1502,1524.99],[i,1518,i,1518.85]]}],"legend":[{"data":[h],"selected":{},"show":!0,"padding":j,"itemGap":k,"itemWidth":25,"itemHeight":l,"backgroundColor":`transparent`,"borderColor":`#ccc`,"borderRadius":g,"pageButtonItemGap":j,"pageButtonPosition":m,"pageFormatter":`{current}/{total}`,"pageIconColor":`#2f4554`,"pageIconInactiveColor":`#aaa`,"pageIconSize":n,"animationDurationUpdate":800,"selector":!1,"selectorPosition":o,"selectorItemGap":7,"selectorButtonGap":k,"left":`center`,"icon":`circle`,"borderWidth":g}],"tooltip":{"show":!0,"trigger":`axis`,"triggerOn":`mousemove|click`,"axisPointer":{"type":`line`},"showContent":!0,"alwaysShowContent":!1,"showDelay":g,"hideDelay":p,"enterable":!1,"confine":!1,"appendToBody":!1,"transitionDuration":0.4,"textStyle":{"fontSize":l},"borderWidth":g,"padding":j,"order":`seriesAsc`},"xAxis":[{"show":!0,"scale":!0,"nameLocation":m,"nameGap":n,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":j,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":q,"opacity":q,"curveness":g,"type":r}},"data":[`2024-11-28T09:25:00`,`2024-11-28T13:01:00`]}],"yAxis":[{"show":!0,"scale":!0,"nameLocation":m,"nameGap":n,"gridIndex":g,"inverse":!1,"offset":g,"splitNumber":j,"minInterval":g,"splitLine":{"show":!0,"lineStyle":{"show":!0,"width":q,"opacity":q,"curveness":g,"type":r}}}],"title":[{"show":!0,"target":s,"subtarget":s,"padding":j,"itemGap":k,"textAlign":o,"textVerticalAlign":o,"triggerEvent":!1}],"dataZoom":{"show":!0,"type":`slider`,"showDetail":!0,"showDataShadow":!0,"realtime":!0,"start":g,"end":p,"orient":`horizontal`,"xAxisIndex":[g,q],"zoomLock":!1,"top":`85%`,"filterMode":`filter`}};b.setOption(d)}))</script>
