# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Research_Frameworks")
from BQCN.DT.FACT.FAMA.STAD1.STAD1 import *

# %%
ed = dai.query(f"SELECT DISTINCT date FROM cn_stock_bar1d WHERE date >= '2024-01-01' ORDER BY date DESC").df()['date'].iloc[0].strftime("%Y-%m-%d")
sd = '2023-07-01'

# %%
alpha_generator = CNDT_FACT_FAMA_STAD1(sd, ed)
df = alpha_generator.ff3_factors_d1()
df
# Out:
#               date instrument    Return       MKT       SMB       HML
# 0       2023-07-03  000001.SZ  0.023152  0.010906 -0.007980  0.005812
# 1       2023-07-03  000002.SZ  0.009272  0.010906 -0.007980  0.005812
# 2       2023-07-03  000004.SZ -0.093115  0.010906 -0.007980  0.005812
# 3       2023-07-03  000005.SZ  0.031496  0.010906 -0.007980  0.005812
# 4       2023-07-03  000006.SZ  0.011442  0.010906 -0.007980  0.005812
# ...            ...        ...       ...       ...       ...       ...
# 1704981 2024-11-18  688799.SH -0.011660 -0.007705 -0.019071  0.031790
# 1704982 2024-11-18  688800.SH -0.026261 -0.007705 -0.019071  0.031790
# 1704983 2024-11-18  688819.SH -0.001003 -0.007705 -0.019071  0.031790
# 1704984 2024-11-18  688981.SH -0.027500 -0.007705 -0.019071  0.031790
# 1704985 2024-11-18  689009.SH -0.053008 -0.007705 -0.019071  0.031790
#
# [1704986 rows x 6 columns]
