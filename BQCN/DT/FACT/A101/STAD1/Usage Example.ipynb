# %%
import sys
sys.path.append("/home/aiuser/work/userlib/BigQuant_Research_Frameworks")
from BQCN.DT.FACT.A101.STAD1.STAD1 import *

# %%
ed = dai.query(f"SELECT DISTINCT date FROM cn_stock_bar1d WHERE date >= '2024-01-01' ORDER BY date DESC").df()['date'].iloc[0].strftime("%Y-%m-%d")
sd = '2024-10-01'

# %%
data_generator = CNDT_FACT_A101_STAD1(sd, ed)

# %%
data_generator.alpha_a101_f0001()
# Out:
#              date instrument  alpha_a101_f0001
# 0      2024-10-08  000001.SZ          0.029649
# 1      2024-10-08  000002.SZ          0.029649
# 2      2024-10-08  000004.SZ          0.029649
# 3      2024-10-08  000006.SZ         -0.468662
# 4      2024-10-08  000007.SZ          0.029649
# ...           ...        ...               ...
# 171532 2024-11-20  920066.BJ               NaN
# 171533 2024-11-20  920088.BJ               NaN
# 171534 2024-11-20  920099.BJ         -0.357571
# 171535 2024-11-20  920111.BJ               NaN
# 171536 2024-11-20  920118.BJ         -0.357571
#
# [171537 rows x 3 columns]
