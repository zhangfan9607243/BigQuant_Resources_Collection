# %%
import dai
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
ed = dai.query(f"SELECT DISTINCT date FROM cn_stock_bar1d WHERE date >= '2024-01-01' ORDER BY date DESC").df()['date'].iloc[0].strftime("%Y-%m-%d")
sd = '2024-10-01'

# %%
from cn_stock_factors_a191_d1 import CNStockFactorsA191D1

alpha_generator = CNStockFactorsA191D1(sd, ed)
df = alpha_generator.alpha_a191_f0001()
df
# Out:
#              date instrument  alpha_a191_f0001
# 0      2024-10-08  000001.SZ         -0.454666
# 1      2024-10-08  000002.SZ         -0.641249
# 2      2024-10-08  000004.SZ          0.602959
# 3      2024-10-08  000006.SZ         -0.759459
# 4      2024-10-08  000007.SZ         -0.468887
# ...           ...        ...               ...
# 150065 2024-11-14  920066.BJ               NaN
# 150066 2024-11-14  920088.BJ               NaN
# 150067 2024-11-14  920099.BJ               NaN
# 150068 2024-11-14  920111.BJ               NaN
# 150069 2024-11-14  920118.BJ               NaN
#
# [150070 rows x 3 columns]
