# %%
import dai
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
ed = dai.query(f"SELECT DISTINCT date FROM cn_stock_bar1d WHERE date >= '2024-01-01' ORDER BY date DESC").df()['date'].iloc[0].strftime("%Y-%m-%d")
sd = '2024-10-01'

# %%
from cn_stock_factors_ff3_d1 import CNStockFactorsFFD1
alpha_generator = CNStockFactorsFFD1(sd, ed)
alpha_generator.ff3_factors_d1()
# Out:
#              date instrument    Return       MKT       SMB       HML
# 0      2024-10-08  000001.SZ  0.054873  0.062314  0.020624 -0.051098
# 1      2024-10-08  000002.SZ  0.067901  0.062314  0.020624 -0.051098
# 2      2024-10-08  000004.SZ  0.100000  0.062314  0.020624 -0.051098
# 3      2024-10-08  000006.SZ -0.017889  0.062314  0.020624 -0.051098
# 4      2024-10-08  000007.SZ  0.072378  0.062314  0.020624 -0.051098
# ...           ...        ...       ...       ...       ...       ...
# 148037 2024-11-15  688799.SH -0.017788 -0.017065 -0.001955  0.012975
# 148038 2024-11-15  688800.SH -0.059289 -0.017065 -0.001955  0.012975
# 148039 2024-11-15  688819.SH -0.037657 -0.017065 -0.001955  0.012975
# 148040 2024-11-15  688981.SH -0.020233 -0.017065 -0.001955  0.012975
# 148041 2024-11-15  689009.SH  0.005925 -0.017065 -0.001955  0.012975
#
# [148042 rows x 6 columns]
