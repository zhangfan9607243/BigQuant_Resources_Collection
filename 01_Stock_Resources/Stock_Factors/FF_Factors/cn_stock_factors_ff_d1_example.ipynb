# %%
import dai
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
ed = dai.query(f"SELECT DISTINCT date FROM cn_stock_bar1d WHERE date >= '2024-01-01' ORDER BY date DESC").df()['date'].iloc[0].strftime("%Y-%m-%d")
sd = '2023-07-01'

# %%
from cn_stock_factors_ff_d1 import CNStockFactorsFFD1
alpha_generator = CNStockFactorsFFD1(sd, ed)
df = alpha_generator.ff3_factors_d1()
df
# Out:
#               date instrument    Return       MKT       SMB       HML
# 0       2023-07-03  000001.SZ  0.023152  0.010906 -0.007980  0.005812
# 1       2023-07-03  000002.SZ  0.009272  0.010906 -0.007980  0.005812
# 2       2023-07-03  000004.SZ -0.093115  0.010906 -0.007980  0.005812
# 3       2023-07-03  000005.SZ  0.031496  0.010906 -0.007980  0.005812
# 4       2023-07-03  000006.SZ  0.011442  0.010906 -0.007980  0.005812
# ...            ...        ...       ...       ...       ...       ...
# 1699872 2024-11-15  688799.SH -0.017788 -0.017065 -0.001955  0.012975
# 1699873 2024-11-15  688800.SH -0.059289 -0.017065 -0.001955  0.012975
# 1699874 2024-11-15  688819.SH -0.037657 -0.017065 -0.001955  0.012975
# 1699875 2024-11-15  688981.SH -0.020233 -0.017065 -0.001955  0.012975
# 1699876 2024-11-15  689009.SH  0.005925 -0.017065 -0.001955  0.012975
#
# [1699877 rows x 6 columns]
